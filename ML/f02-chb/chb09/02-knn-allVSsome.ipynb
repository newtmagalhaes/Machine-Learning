# %% [markdown]
# # KNN CHB09 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb09_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9629629629629629
#               precision    recall  f1-score   support
#
#     negative     0.9318    1.0000    0.9647        41
#     positive     1.0000    0.9250    0.9610        40
#
#     accuracy                         0.9630        81
#    macro avg     0.9659    0.9625    0.9629        81
# weighted avg     0.9655    0.9630    0.9629        81
# Rodada: 1	Seed: 8968	Score: 0.9629629629629629
#               precision    recall  f1-score   support
#
#     negative     0.9302    1.0000    0.9639        40
#     positive     1.0000    0.9268    0.9620        41
#
#     accuracy                         0.9630        81
#    macro avg     0.9651    0.9634    0.9629        81
# weighted avg     0.9655    0.9630    0.9629        81
# Rodada: 2	Seed: 8442	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9583    1.0000    0.9787        46
#     positive     1.0000    0.9429    0.9706        35
#
#     accuracy                         0.9753        81
#    macro avg     0.9792    0.9714    0.9747        81
# weighted avg     0.9763    0.9753    0.9752        81
# Rodada: 3	Seed: 1729	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9444    1.0000    0.9714        34
#     positive     1.0000    0.9574    0.9783        47
#
#     accuracy                         0.9753        81
#    macro avg     0.9722    0.9787    0.9748        81
# weighted avg     0.9767    0.9753    0.9754        81
# Rodada: 4	Seed: 290	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9524    1.0000    0.9756        40
#     positive     1.0000    0.9512    0.9750        41
#
#     accuracy                         0.9753        81
#    macro avg     0.9762    0.9756    0.9753        81
# weighted avg     0.9765    0.9753    0.9753        81
# Rodada: 5	Seed: 490	Score: 0.9506172839506173
#               precision    recall  f1-score   support
#
#     negative     0.9024    1.0000    0.9487        37
#     positive     1.0000    0.9091    0.9524        44
#
#     accuracy                         0.9506        81
#    macro avg     0.9512    0.9545    0.9505        81
# weighted avg     0.9554    0.9506    0.9507        81
# Rodada: 6	Seed: 2128	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9500    1.0000    0.9744        38
#     positive     1.0000    0.9535    0.9762        43
#
#     accuracy                         0.9753        81
#    macro avg     0.9750    0.9767    0.9753        81
# weighted avg     0.9765    0.9753    0.9753        81
# Rodada: 7	Seed: 1167	Score: 0.9876543209876543
#               precision    recall  f1-score   support
#
#     negative     0.9778    1.0000    0.9888        44
#     positive     1.0000    0.9730    0.9863        37
#
#     accuracy                         0.9877        81
#    macro avg     0.9889    0.9865    0.9875        81
# weighted avg     0.9879    0.9877    0.9876        81
# Rodada: 8	Seed: 8900	Score: 0.9629629629629629
#               precision    recall  f1-score   support
#
#     negative     0.9211    1.0000    0.9589        35
#     positive     1.0000    0.9348    0.9663        46
#
#     accuracy                         0.9630        81
#    macro avg     0.9605    0.9674    0.9626        81
# weighted avg     0.9659    0.9630    0.9631        81
# Rodada: 9	Seed: 5078	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        46
#     positive     1.0000    1.0000    1.0000        35
#
#     accuracy                         1.0000        81
#    macro avg     1.0000    1.0000    1.0000        81
# weighted avg     1.0000    1.0000    1.0000        81
# Rodada: 10	Seed: 1359	Score: 0.9629629629629629
#               precision    recall  f1-score   support
#
#     negative     0.9333    1.0000    0.9655        42
#     positive     1.0000    0.9231    0.9600        39
#
#     accuracy                         0.9630        81
#    macro avg     0.9667    0.9615    0.9628        81
# weighted avg     0.9654    0.9630    0.9629        81
# Rodada: 11	Seed: 894	Score: 0.9629629629629629
#               precision    recall  f1-score   support
#
#     negative     0.9362    1.0000    0.9670        44
#     positive     1.0000    0.9189    0.9577        37
#
#     accuracy                         0.9630        81
#    macro avg     0.9681    0.9595    0.9624        81
# weighted avg     0.9653    0.9630    0.9628        81
# Rodada: 12	Seed: 7809	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        38
#     positive     1.0000    1.0000    1.0000        43
#
#     accuracy                         1.0000        81
#    macro avg     1.0000    1.0000    1.0000        81
# weighted avg     1.0000    1.0000    1.0000        81
# Rodada: 13	Seed: 6990	Score: 0.9506172839506173
#               precision    recall  f1-score   support
#
#     negative     0.9111    1.0000    0.9535        41
#     positive     1.0000    0.9000    0.9474        40
#
#     accuracy                         0.9506        81
#    macro avg     0.9556    0.9500    0.9504        81
# weighted avg     0.9550    0.9506    0.9505        81
# Rodada: 14	Seed: 3623	Score: 0.9876543209876543
#               precision    recall  f1-score   support
#
#     negative     0.9762    1.0000    0.9880        41
#     positive     1.0000    0.9750    0.9873        40
#
#     accuracy                         0.9877        81
#    macro avg     0.9881    0.9875    0.9876        81
# weighted avg     0.9879    0.9877    0.9877        81
# Rodada: 15	Seed: 5906	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9512    1.0000    0.9750        39
#     positive     1.0000    0.9524    0.9756        42
#
#     accuracy                         0.9753        81
#    macro avg     0.9756    0.9762    0.9753        81
# weighted avg     0.9765    0.9753    0.9753        81
# Rodada: 16	Seed: 1687	Score: 0.9876543209876543
#               precision    recall  f1-score   support
#
#     negative     0.9677    1.0000    0.9836        30
#     positive     1.0000    0.9804    0.9901        51
#
#     accuracy                         0.9877        81
#    macro avg     0.9839    0.9902    0.9869        81
# weighted avg     0.9881    0.9877    0.9877        81
# Rodada: 17	Seed: 7080	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9535    1.0000    0.9762        41
#     positive     1.0000    0.9500    0.9744        40
#
#     accuracy                         0.9753        81
#    macro avg     0.9767    0.9750    0.9753        81
# weighted avg     0.9765    0.9753    0.9753        81
# Rodada: 18	Seed: 5473	Score: 0.9629629629629629
#               precision    recall  f1-score   support
#
#     negative     0.9412    1.0000    0.9697        48
#     positive     1.0000    0.9091    0.9524        33
#
#     accuracy                         0.9630        81
#    macro avg     0.9706    0.9545    0.9610        81
# weighted avg     0.9651    0.9630    0.9626        81
# Rodada: 19	Seed: 7854	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9500    1.0000    0.9744        38
#     positive     1.0000    0.9535    0.9762        43
#
#     accuracy                         0.9753        81
#    macro avg     0.9750    0.9767    0.9753        81
# weighted avg     0.9765    0.9753    0.9753        81

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9535    1.0000    0.9762        41
#     positive     1.0000    0.9500    0.9744        40
#
#     accuracy                         0.9753        81
#    macro avg     0.9767    0.9750    0.9753        81
# weighted avg     0.9765    0.9753    0.9753        81
# Rodada: 1	Seed: 8968	Score: 0.9876543209876543
#               precision    recall  f1-score   support
#
#     negative     0.9756    1.0000    0.9877        40
#     positive     1.0000    0.9756    0.9877        41
#
#     accuracy                         0.9877        81
#    macro avg     0.9878    0.9878    0.9877        81
# weighted avg     0.9880    0.9877    0.9877        81
# Rodada: 2	Seed: 8442	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        46
#     positive     1.0000    1.0000    1.0000        35
#
#     accuracy                         1.0000        81
#    macro avg     1.0000    1.0000    1.0000        81
# weighted avg     1.0000    1.0000    1.0000        81
# Rodada: 3	Seed: 1729	Score: 0.9876543209876543
#               precision    recall  f1-score   support
#
#     negative     0.9714    1.0000    0.9855        34
#     positive     1.0000    0.9787    0.9892        47
#
#     accuracy                         0.9877        81
#    macro avg     0.9857    0.9894    0.9874        81
# weighted avg     0.9880    0.9877    0.9877        81
# Rodada: 4	Seed: 290	Score: 0.9876543209876543
#               precision    recall  f1-score   support
#
#     negative     0.9756    1.0000    0.9877        40
#     positive     1.0000    0.9756    0.9877        41
#
#     accuracy                         0.9877        81
#    macro avg     0.9878    0.9878    0.9877        81
# weighted avg     0.9880    0.9877    0.9877        81
# Rodada: 5	Seed: 490	Score: 0.9629629629629629
#               precision    recall  f1-score   support
#
#     negative     0.9250    1.0000    0.9610        37
#     positive     1.0000    0.9318    0.9647        44
#
#     accuracy                         0.9630        81
#    macro avg     0.9625    0.9659    0.9629        81
# weighted avg     0.9657    0.9630    0.9630        81
# Rodada: 6	Seed: 2128	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9500    1.0000    0.9744        38
#     positive     1.0000    0.9535    0.9762        43
#
#     accuracy                         0.9753        81
#    macro avg     0.9750    0.9767    0.9753        81
# weighted avg     0.9765    0.9753    0.9753        81
# Rodada: 7	Seed: 1167	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9565    1.0000    0.9778        44
#     positive     1.0000    0.9459    0.9722        37
#
#     accuracy                         0.9753        81
#    macro avg     0.9783    0.9730    0.9750        81
# weighted avg     0.9764    0.9753    0.9752        81
# Rodada: 8	Seed: 8900	Score: 0.9506172839506173
#               precision    recall  f1-score   support
#
#     negative     0.8974    1.0000    0.9459        35
#     positive     1.0000    0.9130    0.9545        46
#
#     accuracy                         0.9506        81
#    macro avg     0.9487    0.9565    0.9502        81
# weighted avg     0.9557    0.9506    0.9508        81
# Rodada: 9	Seed: 5078	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        46
#     positive     1.0000    1.0000    1.0000        35
#
#     accuracy                         1.0000        81
#    macro avg     1.0000    1.0000    1.0000        81
# weighted avg     1.0000    1.0000    1.0000        81
# Rodada: 10	Seed: 1359	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        42
#     positive     1.0000    1.0000    1.0000        39
#
#     accuracy                         1.0000        81
#    macro avg     1.0000    1.0000    1.0000        81
# weighted avg     1.0000    1.0000    1.0000        81
# Rodada: 11	Seed: 894	Score: 0.9629629629629629
#               precision    recall  f1-score   support
#
#     negative     0.9362    1.0000    0.9670        44
#     positive     1.0000    0.9189    0.9577        37
#
#     accuracy                         0.9630        81
#    macro avg     0.9681    0.9595    0.9624        81
# weighted avg     0.9653    0.9630    0.9628        81
# Rodada: 12	Seed: 7809	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        38
#     positive     1.0000    1.0000    1.0000        43
#
#     accuracy                         1.0000        81
#    macro avg     1.0000    1.0000    1.0000        81
# weighted avg     1.0000    1.0000    1.0000        81
# Rodada: 13	Seed: 6990	Score: 0.9382716049382716
#               precision    recall  f1-score   support
#
#     negative     0.8913    1.0000    0.9425        41
#     positive     1.0000    0.8750    0.9333        40
#
#     accuracy                         0.9383        81
#    macro avg     0.9457    0.9375    0.9379        81
# weighted avg     0.9450    0.9383    0.9380        81
# Rodada: 14	Seed: 3623	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9535    1.0000    0.9762        41
#     positive     1.0000    0.9500    0.9744        40
#
#     accuracy                         0.9753        81
#    macro avg     0.9767    0.9750    0.9753        81
# weighted avg     0.9765    0.9753    0.9753        81
# Rodada: 15	Seed: 5906	Score: 0.9753086419753086
#               precision    recall  f1-score   support
#
#     negative     0.9512    1.0000    0.9750        39
#     positive     1.0000    0.9524    0.9756        42
#
#     accuracy                         0.9753        81
#    macro avg     0.9756    0.9762    0.9753        81
# weighted avg     0.9765    0.9753    0.9753        81
# Rodada: 16	Seed: 1687	Score: 0.9876543209876543
#               precision    recall  f1-score   support
#
#     negative     0.9677    1.0000    0.9836        30
#     positive     1.0000    0.9804    0.9901        51
#
#     accuracy                         0.9877        81
#    macro avg     0.9839    0.9902    0.9869        81
# weighted avg     0.9881    0.9877    0.9877        81
# Rodada: 17	Seed: 7080	Score: 0.9629629629629629
#               precision    recall  f1-score   support
#
#     negative     0.9318    1.0000    0.9647        41
#     positive     1.0000    0.9250    0.9610        40
#
#     accuracy                         0.9630        81
#    macro avg     0.9659    0.9625    0.9629        81
# weighted avg     0.9655    0.9630    0.9629        81
# Rodada: 18	Seed: 5473	Score: 0.9876543209876543
#               precision    recall  f1-score   support
#
#     negative     0.9796    1.0000    0.9897        48
#     positive     1.0000    0.9697    0.9846        33
#
#     accuracy                         0.9877        81
#    macro avg     0.9898    0.9848    0.9872        81
# weighted avg     0.9879    0.9877    0.9876        81
# Rodada: 19	Seed: 7854	Score: 0.9629629629629629
#               precision    recall  f1-score   support
#
#     negative     0.9268    1.0000    0.9620        38
#     positive     1.0000    0.9302    0.9639        43
#
#     accuracy                         0.9630        81
#    macro avg     0.9634    0.9651    0.9629        81
# weighted avg     0.9657    0.9630    0.9630        81

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.962963       0.975309
# 1       0.962963       0.987654
# 2       0.975309       1.000000
# 3       0.975309       0.987654
# 4       0.975309       0.987654
# 5       0.950617       0.962963
# 6       0.975309       0.975309
# 7       0.987654       0.975309
# 8       0.962963       0.950617
# 9       1.000000       1.000000
# 10      0.962963       1.000000
# 11      0.962963       0.962963
# 12      1.000000       1.000000
# 13      0.950617       0.938272
# 14      0.987654       0.975309
# 15      0.975309       0.975309
# 16      0.987654       0.987654
# 17      0.975309       0.962963
# 18      0.962963       0.987654
# 19      0.975309       0.962963

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.973457       0.977778
# std        0.014033       0.017275
# min        0.950617       0.938272
# 25%        0.962963       0.962963
# 50%        0.975309       0.975309
# 75%        0.978395       0.987654
# max        1.000000       1.000000
