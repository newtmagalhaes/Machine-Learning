# %% [markdown]
# # Standard KNN
#
# Explorando 15 rodadas de classificação com KNN em sua configuração padrão com os datasets `chb01.csv` e `chb01dwt.csv`.
#
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix

# %%
chb_v1_DF = pd.read_csv('./chb01.csv')
target_v1_S = chb_v1_DF.pop('target')

print(f'chb_v1 shape: {chb_v1_DF.shape}')

seed_array = np.random.randint(0, 8000, 15)
print(f'seeds: {seed_array}')

X, y = chb_v1_DF.values, target_v1_S.values
v1_acc = []

target_v1_S.hist()
target_v1_S.value_counts()
# Out:
# chb_v1 shape: (432, 126)
# seeds: [2889 7650  539 3563 7491 7483 6832 7252  400 2476 7630 7039 2346 6346
#  7672]
# 1.0    216
# 0.0    216
# Name: target, dtype: int64

# %%
for rodada, seed in enumerate(seed_array):
    # Distribuindo os dados
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    classifier = KNeighborsClassifier()
    classifier.fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Gerando resultados
    accuracy = classifier.score(X_test, y_test)

    # Adicionando resultados às respectivas listas
    v1_acc.append(accuracy)

    # Exibindo resultados
    print(f'Rodada: {rodada} - seed: {seed} - acurácia: {accuracy}\n')

    print(classification_report(y_test, y_pred, target_names=['negativo', 'positivo']))
    
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negativo', 'positivo']
    )
    plt.show()
# Out:
# Rodada: 0 - seed: 2889 - acurácia: 0.9461538461538461
#
#               precision    recall  f1-score   support
#
#     negativo       0.91      0.98      0.95        63
#     positivo       0.98      0.91      0.95        67
#
#     accuracy                           0.95       130
#    macro avg       0.95      0.95      0.95       130
# weighted avg       0.95      0.95      0.95       130
# Rodada: 1 - seed: 7650 - acurácia: 0.9692307692307692
#
#               precision    recall  f1-score   support
#
#     negativo       0.94      1.00      0.97        64
#     positivo       1.00      0.94      0.97        66
#
#     accuracy                           0.97       130
#    macro avg       0.97      0.97      0.97       130
# weighted avg       0.97      0.97      0.97       130
# Rodada: 2 - seed: 539 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.94      0.98      0.96        59
#     positivo       0.99      0.94      0.96        71
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# Rodada: 3 - seed: 3563 - acurácia: 0.9769230769230769
#
#               precision    recall  f1-score   support
#
#     negativo       0.96      1.00      0.98        73
#     positivo       1.00      0.95      0.97        57
#
#     accuracy                           0.98       130
#    macro avg       0.98      0.97      0.98       130
# weighted avg       0.98      0.98      0.98       130
# Rodada: 4 - seed: 7491 - acurácia: 0.9230769230769231
#
#               precision    recall  f1-score   support
#
#     negativo       0.88      0.98      0.93        66
#     positivo       0.98      0.86      0.92        64
#
#     accuracy                           0.92       130
#    macro avg       0.93      0.92      0.92       130
# weighted avg       0.93      0.92      0.92       130
# Rodada: 5 - seed: 7483 - acurácia: 0.9461538461538461
#
#               precision    recall  f1-score   support
#
#     negativo       0.91      0.98      0.95        65
#     positivo       0.98      0.91      0.94        65
#
#     accuracy                           0.95       130
#    macro avg       0.95      0.95      0.95       130
# weighted avg       0.95      0.95      0.95       130
# Rodada: 6 - seed: 6832 - acurácia: 0.9538461538461539
#
#               precision    recall  f1-score   support
#
#     negativo       0.91      1.00      0.95        60
#     positivo       1.00      0.91      0.96        70
#
#     accuracy                           0.95       130
#    macro avg       0.95      0.96      0.95       130
# weighted avg       0.96      0.95      0.95       130
# Rodada: 7 - seed: 7252 - acurácia: 0.9461538461538461
#
#               precision    recall  f1-score   support
#
#     negativo       0.90      1.00      0.95        62
#     positivo       1.00      0.90      0.95        68
#
#     accuracy                           0.95       130
#    macro avg       0.95      0.95      0.95       130
# weighted avg       0.95      0.95      0.95       130
# Rodada: 8 - seed: 400 - acurácia: 0.9538461538461539
#
#               precision    recall  f1-score   support
#
#     negativo       0.91      1.00      0.96        64
#     positivo       1.00      0.91      0.95        66
#
#     accuracy                           0.95       130
#    macro avg       0.96      0.95      0.95       130
# weighted avg       0.96      0.95      0.95       130
# Rodada: 9 - seed: 2476 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.94      0.99      0.96        69
#     positivo       0.98      0.93      0.96        61
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# Rodada: 10 - seed: 7630 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.92      1.00      0.96        61
#     positivo       1.00      0.93      0.96        69
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# Rodada: 11 - seed: 7039 - acurácia: 0.9461538461538461
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      0.97      0.95        67
#     positivo       0.97      0.92      0.94        63
#
#     accuracy                           0.95       130
#    macro avg       0.95      0.95      0.95       130
# weighted avg       0.95      0.95      0.95       130
# Rodada: 12 - seed: 2346 - acurácia: 0.9538461538461539
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      0.99      0.96        71
#     positivo       0.98      0.92      0.95        59
#
#     accuracy                           0.95       130
#    macro avg       0.96      0.95      0.95       130
# weighted avg       0.96      0.95      0.95       130
# Rodada: 13 - seed: 6346 - acurácia: 0.9384615384615385
#
#               precision    recall  f1-score   support
#
#     negativo       0.91      0.99      0.94        68
#     positivo       0.98      0.89      0.93        62
#
#     accuracy                           0.94       130
#    macro avg       0.94      0.94      0.94       130
# weighted avg       0.94      0.94      0.94       130
# Rodada: 14 - seed: 7672 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.97      0.96      0.97        73
#     positivo       0.95      0.96      0.96        57
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130

# %%
accuracy = pd.DataFrame(data=v1_acc, columns=['Acurácia'])
accuracy.boxplot()
accuracy.describe()
# Out:
#         Acurácia
# count  15.000000
# mean    0.953333
# std     0.013153
# min     0.923077
# 25%     0.946154
# 50%     0.953846
# 75%     0.961538
# max     0.976923

# %%
accuracy
# Out:
#     Acurácia
# 0   0.946154
# 1   0.969231
# 2   0.961538
# 3   0.976923
# 4   0.923077
# 5   0.946154
# 6   0.953846
# 7   0.946154
# 8   0.953846
# 9   0.961538
# 10  0.961538
# 11  0.946154
# 12  0.953846
# 13  0.938462
# 14  0.961538
