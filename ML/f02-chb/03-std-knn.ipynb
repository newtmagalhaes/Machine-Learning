# %% [markdown]
# # Standard KNN
#
# Explorando 15 rodadas de classificação com KNN em sua configuração padrão com os datasets `chb01.csv` e `chb01dwt.csv`.
#
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix

seed_array = np.random.randint(0, 8000, 15)
print(f'seeds: {seed_array}')
# Out:
# seeds: [ 431 1021 6637  550 3621 7293 5753 6708  724 7568  525 3226 1571 3543
#  3319]

# %% [markdown]
# ## 15 rodadas com `chb01`

# %%
chb_v1_DF = pd.read_csv('./chb01.csv')
target_v1_S = chb_v1_DF.pop('target')

print(f'chb_v1 shape: {chb_v1_DF.shape}')

X, y = chb_v1_DF.values, target_v1_S.values
v1_acc = []

for rodada, seed in enumerate(seed_array):
    # Distribuindo os dados
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    classifier = KNeighborsClassifier()
    classifier.fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Gerando resultados
    accuracy = classifier.score(X_test, y_test)

    # Adicionando resultados às respectivas listas
    v1_acc.append(accuracy)

    # Exibindo resultados
    print(f'Rodada: {rodada} - seed: {seed} - acurácia: {accuracy}\n')

    print(classification_report(y_test, y_pred, target_names=['negativo', 'positivo']))
    
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negativo', 'positivo']
    )
    plt.show()
# Out:
# chb_v1 shape: (432, 126)
# Rodada: 0 - seed: 431 - acurácia: 0.9384615384615385
#
#               precision    recall  f1-score   support
#
#     negativo       0.89      1.00      0.94        65
#     positivo       1.00      0.88      0.93        65
#
#     accuracy                           0.94       130
#    macro avg       0.95      0.94      0.94       130
# weighted avg       0.95      0.94      0.94       130
# Rodada: 1 - seed: 1021 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      1.00      0.96        62
#     positivo       1.00      0.93      0.96        68
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# Rodada: 2 - seed: 6637 - acurácia: 0.9384615384615385
#
#               precision    recall  f1-score   support
#
#     negativo       0.88      1.00      0.94        60
#     positivo       1.00      0.89      0.94        70
#
#     accuracy                           0.94       130
#    macro avg       0.94      0.94      0.94       130
# weighted avg       0.95      0.94      0.94       130
# Rodada: 3 - seed: 550 - acurácia: 0.9461538461538461
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      0.97      0.95        71
#     positivo       0.96      0.92      0.94        59
#
#     accuracy                           0.95       130
#    macro avg       0.95      0.94      0.95       130
# weighted avg       0.95      0.95      0.95       130
# Rodada: 4 - seed: 3621 - acurácia: 0.9076923076923077
#
#               precision    recall  f1-score   support
#
#     negativo       0.83      1.00      0.90        57
#     positivo       1.00      0.84      0.91        73
#
#     accuracy                           0.91       130
#    macro avg       0.91      0.92      0.91       130
# weighted avg       0.92      0.91      0.91       130
# Rodada: 5 - seed: 7293 - acurácia: 0.9307692307692308
#
#               precision    recall  f1-score   support
#
#     negativo       0.88      1.00      0.93        63
#     positivo       1.00      0.87      0.93        67
#
#     accuracy                           0.93       130
#    macro avg       0.94      0.93      0.93       130
# weighted avg       0.94      0.93      0.93       130
# Rodada: 6 - seed: 5753 - acurácia: 0.9307692307692308
#
#               precision    recall  f1-score   support
#
#     negativo       0.88      1.00      0.93        63
#     positivo       1.00      0.87      0.93        67
#
#     accuracy                           0.93       130
#    macro avg       0.94      0.93      0.93       130
# weighted avg       0.94      0.93      0.93       130
# Rodada: 7 - seed: 6708 - acurácia: 0.9384615384615385
#
#               precision    recall  f1-score   support
#
#     negativo       0.89      1.00      0.94        68
#     positivo       1.00      0.87      0.93        62
#
#     accuracy                           0.94       130
#    macro avg       0.95      0.94      0.94       130
# weighted avg       0.94      0.94      0.94       130
# Rodada: 8 - seed: 724 - acurácia: 0.9307692307692308
#
#               precision    recall  f1-score   support
#
#     negativo       0.88      1.00      0.94        65
#     positivo       1.00      0.86      0.93        65
#
#     accuracy                           0.93       130
#    macro avg       0.94      0.93      0.93       130
# weighted avg       0.94      0.93      0.93       130
# Rodada: 9 - seed: 7568 - acurácia: 0.9538461538461539
#
#               precision    recall  f1-score   support
#
#     negativo       0.92      1.00      0.96        70
#     positivo       1.00      0.90      0.95        60
#
#     accuracy                           0.95       130
#    macro avg       0.96      0.95      0.95       130
# weighted avg       0.96      0.95      0.95       130
# Rodada: 10 - seed: 525 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.92      1.00      0.96        59
#     positivo       1.00      0.93      0.96        71
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# Rodada: 11 - seed: 3226 - acurácia: 0.9769230769230769
#
#               precision    recall  f1-score   support
#
#     negativo       0.96      1.00      0.98        65
#     positivo       1.00      0.95      0.98        65
#
#     accuracy                           0.98       130
#    macro avg       0.98      0.98      0.98       130
# weighted avg       0.98      0.98      0.98       130
# Rodada: 12 - seed: 1571 - acurácia: 0.9461538461538461
#
#               precision    recall  f1-score   support
#
#     negativo       0.91      1.00      0.95        70
#     positivo       1.00      0.88      0.94        60
#
#     accuracy                           0.95       130
#    macro avg       0.95      0.94      0.95       130
# weighted avg       0.95      0.95      0.95       130
# Rodada: 13 - seed: 3543 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      1.00      0.96        63
#     positivo       1.00      0.93      0.96        67
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# Rodada: 14 - seed: 3319 - acurácia: 0.9384615384615385
#
#               precision    recall  f1-score   support
#
#     negativo       0.91      0.97      0.94        65
#     positivo       0.97      0.91      0.94        65
#
#     accuracy                           0.94       130
#    macro avg       0.94      0.94      0.94       130
# weighted avg       0.94      0.94      0.94       130

# %% [markdown]
# ## 15 rodadas com `chb01dwt`

# %%
chb_v2_DF = pd.read_csv('./chb01dwt.csv')
target_v2_S = chb_v2_DF.pop('target')

print(f'chb_v2 shape: {chb_v2_DF.shape}')

X, y = chb_v2_DF.values, target_v2_S.values
v2_acc = []

for rodada, seed in enumerate(seed_array):
    # Distribuindo os dados
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    classifier = KNeighborsClassifier()
    classifier.fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Gerando resultados
    accuracy = classifier.score(X_test, y_test)

    # Adicionando resultados às respectivas listas
    v2_acc.append(accuracy)

    # Exibindo resultados
    print(f'Rodada: {rodada} - seed: {seed} - acurácia: {accuracy}\n')

    print(classification_report(y_test, y_pred, target_names=['negativo', 'positivo']))
    
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negativo', 'positivo']
    )
    plt.show()

accuracyDF['com DWT'] = v2_acc
accuracyDF
# Out:
# chb_v2 shape: (432, 756)
# Rodada: 0 - seed: 431 - acurácia: 0.9307692307692308
#
#               precision    recall  f1-score   support
#
#     negativo       0.89      0.98      0.93        65
#     positivo       0.98      0.88      0.93        65
#
#     accuracy                           0.93       130
#    macro avg       0.94      0.93      0.93       130
# weighted avg       0.94      0.93      0.93       130
# Rodada: 1 - seed: 1021 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      1.00      0.96        62
#     positivo       1.00      0.93      0.96        68
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# Rodada: 2 - seed: 6637 - acurácia: 0.9692307692307692
#
#               precision    recall  f1-score   support
#
#     negativo       0.95      0.98      0.97        60
#     positivo       0.99      0.96      0.97        70
#
#     accuracy                           0.97       130
#    macro avg       0.97      0.97      0.97       130
# weighted avg       0.97      0.97      0.97       130
# Rodada: 3 - seed: 550 - acurácia: 0.9846153846153847
#
#               precision    recall  f1-score   support
#
#     negativo       0.97      1.00      0.99        71
#     positivo       1.00      0.97      0.98        59
#
#     accuracy                           0.98       130
#    macro avg       0.99      0.98      0.98       130
# weighted avg       0.99      0.98      0.98       130
# Rodada: 4 - seed: 3621 - acurácia: 0.9384615384615385
#
#               precision    recall  f1-score   support
#
#     negativo       0.89      0.98      0.93        57
#     positivo       0.99      0.90      0.94        73
#
#     accuracy                           0.94       130
#    macro avg       0.94      0.94      0.94       130
# weighted avg       0.94      0.94      0.94       130
# Rodada: 5 - seed: 7293 - acurácia: 0.9538461538461539
#
#               precision    recall  f1-score   support
#
#     negativo       0.91      1.00      0.95        63
#     positivo       1.00      0.91      0.95        67
#
#     accuracy                           0.95       130
#    macro avg       0.96      0.96      0.95       130
# weighted avg       0.96      0.95      0.95       130
# Rodada: 6 - seed: 5753 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      1.00      0.96        63
#     positivo       1.00      0.93      0.96        67
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# Rodada: 7 - seed: 6708 - acurácia: 0.9461538461538461
#
#               precision    recall  f1-score   support
#
#     negativo       0.92      0.99      0.95        68
#     positivo       0.98      0.90      0.94        62
#
#     accuracy                           0.95       130
#    macro avg       0.95      0.94      0.95       130
# weighted avg       0.95      0.95      0.95       130
# Rodada: 8 - seed: 724 - acurácia: 0.9538461538461539
#
#               precision    recall  f1-score   support
#
#     negativo       0.92      1.00      0.96        65
#     positivo       1.00      0.91      0.95        65
#
#     accuracy                           0.95       130
#    macro avg       0.96      0.95      0.95       130
# weighted avg       0.96      0.95      0.95       130
# Rodada: 9 - seed: 7568 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      1.00      0.97        70
#     positivo       1.00      0.92      0.96        60
#
#     accuracy                           0.96       130
#    macro avg       0.97      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# Rodada: 10 - seed: 525 - acurácia: 0.9769230769230769
#
#               precision    recall  f1-score   support
#
#     negativo       0.95      1.00      0.98        59
#     positivo       1.00      0.96      0.98        71
#
#     accuracy                           0.98       130
#    macro avg       0.98      0.98      0.98       130
# weighted avg       0.98      0.98      0.98       130
# Rodada: 11 - seed: 3226 - acurácia: 0.9769230769230769
#
#               precision    recall  f1-score   support
#
#     negativo       0.96      1.00      0.98        65
#     positivo       1.00      0.95      0.98        65
#
#     accuracy                           0.98       130
#    macro avg       0.98      0.98      0.98       130
# weighted avg       0.98      0.98      0.98       130
# Rodada: 12 - seed: 1571 - acurácia: 0.9461538461538461
#
#               precision    recall  f1-score   support
#
#     negativo       0.91      1.00      0.95        70
#     positivo       1.00      0.88      0.94        60
#
#     accuracy                           0.95       130
#    macro avg       0.95      0.94      0.95       130
# weighted avg       0.95      0.95      0.95       130
# Rodada: 13 - seed: 3543 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      1.00      0.96        63
#     positivo       1.00      0.93      0.96        67
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# Rodada: 14 - seed: 3319 - acurácia: 0.9615384615384616
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      1.00      0.96        65
#     positivo       1.00      0.92      0.96        65
#
#     accuracy                           0.96       130
#    macro avg       0.96      0.96      0.96       130
# weighted avg       0.96      0.96      0.96       130
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3683eaaa3068> in <module>
#      38     plt.show()
#      39
# ---> 40 accuracyDF['com DWT'] = v2_acc
#      41 accuracyDF
#
# NameError: name 'accuracyDF' is not defined

# %%
accuracyDF = pd.DataFrame(data=[v1_acc, v2_acc], index=['sem DWT', 'com DWT']).transpose()
accuracyDF
# Out:
#      sem DWT   com DWT
# 0   0.938462  0.930769
# 1   0.961538  0.961538
# 2   0.938462  0.969231
# 3   0.946154  0.984615
# 4   0.907692  0.938462
# 5   0.930769  0.953846
# 6   0.930769  0.961538
# 7   0.938462  0.946154
# 8   0.930769  0.953846
# 9   0.953846  0.961538
# 10  0.961538  0.976923
# 11  0.976923  0.976923
# 12  0.946154  0.946154
# 13  0.961538  0.961538
# 14  0.938462  0.961538

# %%
accuracyDF.boxplot()
accuracyDF.describe()
# Out:
#          sem DWT    com DWT
# count  15.000000  15.000000
# mean    0.944103   0.958974
# std     0.017069   0.014730
# min     0.907692   0.930769
# 25%     0.934615   0.950000
# 50%     0.938462   0.961538
# 75%     0.957692   0.965385
# max     0.976923   0.984615
