# %% [markdown]
# # Standard SVC
#
# Explorando 15 rodadas de classificação com `SVC` em sua configuração padrão com os datasets `chb01.csv` e `chb01dwt.csv`.
#
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix

seed_array = np.random.randint(0, 8000, 15)
print(f'seeds: {seed_array}')
# Out:
# seeds: [ 840 1603 1016 1210 7562 4751  847 4353 4403 7547 2107 7685 4760 1655
#  4866]

# %% [markdown]
# ## 15 rodadas com `chb01`

# %%
chb_v1_DF = pd.read_csv('./chb01.csv')
target_v1_S = chb_v1_DF.pop('target')

print(f'chb_v1 shape: {chb_v1_DF.shape}')

X, y = chb_v1_DF.values, target_v1_S.values
v1_acc = []

for rodada, seed in enumerate(seed_array):
    # Distribuindo os dados
    X_pre_train, X_pre_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Pré-processando dados
    sc = StandardScaler().fit(X_pre_train)
    X_train = sc.transform(X_pre_train)
    X_test = sc.transform(X_pre_test)

    # Instanciando e treinando classificador
    classifier = SVC().fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Gerando resultados
    accuracy = classifier.score(X_test, y_test)

    # Adicionando resultados às respectivas listas
    v1_acc.append(accuracy)

    # Exibindo resultados
    print(f'Rodada: {rodada} - seed: {seed} - acurácia: {accuracy}\n')

    print(classification_report(y_test, y_pred, target_names=['negativo', 'positivo']))
    
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negativo', 'positivo']
    )
    plt.show()
# Out:
# chb_v1 shape: (432, 126)
# Rodada: 0 - seed: 840 - acurácia: 0.9538461538461539
#
#               precision    recall  f1-score   support
#
#     negativo       0.93      0.99      0.96        71
#     positivo       0.98      0.92      0.95        59
#
#     accuracy                           0.95       130
#    macro avg       0.96      0.95      0.95       130
# weighted avg       0.96      0.95      0.95       130
# Rodada: 1 - seed: 1603 - acurácia: 0.9692307692307692
#
#               precision    recall  f1-score   support
#
#     negativo       0.99      0.96      0.97        75
#     positivo       0.95      0.98      0.96        55
#
#     accuracy                           0.97       130
#    macro avg       0.97      0.97      0.97       130
# weighted avg       0.97      0.97      0.97       130
# Rodada: 2 - seed: 1016 - acurácia: 0.9769230769230769
#
#               precision    recall  f1-score   support
#
#     negativo       0.97      0.98      0.98        66
# ...

# %% [markdown]
# ## 15 rodadas com `chb01dwt`

# %%
chb_v2_DF = pd.read_csv('./chb01dwt.csv')
target_v2_S = chb_v2_DF.pop('target')

print(f'chb_v2 shape: {chb_v2_DF.shape}')

X, y = chb_v2_DF.values, target_v2_S.values
v2_acc = []

for rodada, seed in enumerate(seed_array):
    # Distribuindo os dados
    X_pre_train, X_pre_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Pré-processando dados
    sc = StandardScaler().fit(X_pre_train)
    X_train = sc.transform(X_pre_train)
    X_test = sc.transform(X_pre_test)

    # Instanciando e treinando classificador
    classifier = SVC().fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Gerando resultados
    accuracy = classifier.score(X_test, y_test)

    # Adicionando resultados às respectivas listas
    v2_acc.append(accuracy)

    # Exibindo resultados
    print(f'Rodada: {rodada} - seed: {seed} - acurácia: {accuracy}\n')

    print(classification_report(y_test, y_pred, target_names=['negativo', 'positivo']))
    
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negativo', 'positivo']
    )
    plt.show()

accuracyDF['com DWT'] = v2_acc
accuracyDF
# Out:
# chb_v2 shape: (432, 756)
# Rodada: 0 - seed: 840 - acurácia: 1.0
#
#               precision    recall  f1-score   support
#
#     negativo       1.00      1.00      1.00        71
#     positivo       1.00      1.00      1.00        59
#
#     accuracy                           1.00       130
#    macro avg       1.00      1.00      1.00       130
# weighted avg       1.00      1.00      1.00       130
# Rodada: 1 - seed: 1603 - acurácia: 1.0
#
#               precision    recall  f1-score   support
#
#     negativo       1.00      1.00      1.00        75
#     positivo       1.00      1.00      1.00        55
#
#     accuracy                           1.00       130
#    macro avg       1.00      1.00      1.00       130
# weighted avg       1.00      1.00      1.00       130
# Rodada: 2 - seed: 1016 - acurácia: 0.9923076923076923
#
#               precision    recall  f1-score   support
#
#     negativo       0.99      1.00      0.99        66
# ...

# %%
accuracyDF = pd.DataFrame(data=[v1_acc, v2_acc], index=['sem DWT', 'com DWT']).transpose()
accuracyDF
# Out:
#      sem DWT   com DWT
# 0   0.953846  1.000000
# 1   0.969231  1.000000
# 2   0.976923  0.992308
# 3   0.976923  0.992308
# 4   0.976923  1.000000
# 5   0.976923  1.000000
# 6   0.946154  1.000000
# 7   0.992308  1.000000
# 8   0.953846  1.000000
# 9   0.992308  0.992308
# 10  0.976923  1.000000
# 11  0.961538  0.992308
# 12  0.961538  1.000000
# 13  0.976923  1.000000
# 14  0.992308  0.992308

# %%
accuracyDF.boxplot()
accuracyDF.describe()
# Out:
#          sem DWT    com DWT
# count  15.000000  15.000000
# mean    0.972308   0.997436
# std     0.014479   0.003753
# min     0.946154   0.992308
# 25%     0.961538   0.992308
# 50%     0.976923   1.000000
# 75%     0.976923   1.000000
# max     0.992308   1.000000
