# %% [markdown]
# # KNN CHB16 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb16_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.4444    0.6154         9
#     positive     0.7059    1.0000    0.8276        12
#
#     accuracy                         0.7619        21
#    macro avg     0.8529    0.7222    0.7215        21
# weighted avg     0.8319    0.7619    0.7366        21
# Rodada: 1	Seed: 8968	Score: 0.8095238095238095
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.6923    0.8182        13
#     positive     0.6667    1.0000    0.8000         8
#
#     accuracy                         0.8095        21
#    macro avg     0.8333    0.8462    0.8091        21
# weighted avg     0.8730    0.8095    0.8113        21
# Rodada: 2	Seed: 8442	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     0.9000    0.6923    0.7826        13
#     positive     0.6364    0.8750    0.7368         8
#
#     accuracy                         0.7619        21
#    macro avg     0.7682    0.7837    0.7597        21
# weighted avg     0.7996    0.7619    0.7652        21
# Rodada: 3	Seed: 1729	Score: 0.7142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.8571    0.5455    0.6667        11
#     positive     0.6429    0.9000    0.7500        10
#
#     accuracy                         0.7143        21
#    macro avg     0.7500    0.7227    0.7083        21
# weighted avg     0.7551    0.7143    0.7063        21
# Rodada: 4	Seed: 290	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.8000    0.8889        10
#     positive     0.8462    1.0000    0.9167        11
#
#     accuracy                         0.9048        21
#    macro avg     0.9231    0.9000    0.9028        21
# weighted avg     0.9194    0.9048    0.9034        21
# Rodada: 5	Seed: 490	Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#     negative     0.7273    1.0000    0.8421         8
#     positive     1.0000    0.7692    0.8696        13
#
#     accuracy                         0.8571        21
#    macro avg     0.8636    0.8846    0.8558        21
# weighted avg     0.8961    0.8571    0.8591        21
# Rodada: 6	Seed: 2128	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.8333    0.9091        12
#     positive     0.8182    1.0000    0.9000         9
#
#     accuracy                         0.9048        21
#    macro avg     0.9091    0.9167    0.9045        21
# weighted avg     0.9221    0.9048    0.9052        21
# Rodada: 7	Seed: 1167	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.5455    0.7059        11
#     positive     0.6667    1.0000    0.8000        10
#
#     accuracy                         0.7619        21
#    macro avg     0.8333    0.7727    0.7529        21
# weighted avg     0.8413    0.7619    0.7507        21
# Rodada: 8	Seed: 8900	Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.7692    0.8696        13
#     positive     0.7273    1.0000    0.8421         8
#
#     accuracy                         0.8571        21
#    macro avg     0.8636    0.8846    0.8558        21
# weighted avg     0.8961    0.8571    0.8591        21
# Rodada: 9	Seed: 5078	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     0.6667    0.7500    0.7059         8
#     positive     0.8333    0.7692    0.8000        13
#
#     accuracy                         0.7619        21
#    macro avg     0.7500    0.7596    0.7529        21
# weighted avg     0.7698    0.7619    0.7641        21
# Rodada: 10	Seed: 1359	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     0.7778    0.7000    0.7368        10
#     positive     0.7500    0.8182    0.7826        11
#
#     accuracy                         0.7619        21
#    macro avg     0.7639    0.7591    0.7597        21
# weighted avg     0.7632    0.7619    0.7608        21
# Rodada: 11	Seed: 894	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     0.8000    0.7273    0.7619        11
#     positive     0.7273    0.8000    0.7619        10
#
#     accuracy                         0.7619        21
#    macro avg     0.7636    0.7636    0.7619        21
# weighted avg     0.7654    0.7619    0.7619        21
# Rodada: 12	Seed: 7809	Score: 0.7142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.7273    0.7273    0.7273        11
#     positive     0.7000    0.7000    0.7000        10
#
#     accuracy                         0.7143        21
#    macro avg     0.7136    0.7136    0.7136        21
# weighted avg     0.7143    0.7143    0.7143        21
# Rodada: 13	Seed: 6990	Score: 0.7142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.8000    0.6667    0.7273        12
#     positive     0.6364    0.7778    0.7000         9
#
#     accuracy                         0.7143        21
#    macro avg     0.7182    0.7222    0.7136        21
# weighted avg     0.7299    0.7143    0.7156        21
# Rodada: 14	Seed: 3623	Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.7273    0.8421        11
#     positive     0.7692    1.0000    0.8696        10
#
#     accuracy                         0.8571        21
#    macro avg     0.8846    0.8636    0.8558        21
# weighted avg     0.8901    0.8571    0.8552        21
# Rodada: 15	Seed: 5906	Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#     negative     0.8889    0.8000    0.8421        10
#     positive     0.8333    0.9091    0.8696        11
#
#     accuracy                         0.8571        21
#    macro avg     0.8611    0.8545    0.8558        21
# weighted avg     0.8598    0.8571    0.8565        21
# Rodada: 16	Seed: 1687	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.8182    0.9000        11
#     positive     0.8333    1.0000    0.9091        10
#
#     accuracy                         0.9048        21
#    macro avg     0.9167    0.9091    0.9045        21
# weighted avg     0.9206    0.9048    0.9043        21
# Rodada: 17	Seed: 7080	Score: 0.7142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.7143    0.5556    0.6250         9
#     positive     0.7143    0.8333    0.7692        12
#
#     accuracy                         0.7143        21
#    macro avg     0.7143    0.6944    0.6971        21
# weighted avg     0.7143    0.7143    0.7074        21
# Rodada: 18	Seed: 5473	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     0.7500    0.8182    0.7826        11
#     positive     0.7778    0.7000    0.7368        10
#
#     accuracy                         0.7619        21
#    macro avg     0.7639    0.7591    0.7597        21
# weighted avg     0.7632    0.7619    0.7608        21
# Rodada: 19	Seed: 7854	Score: 0.8095238095238095
#               precision    recall  f1-score   support
#
#     negative     0.9000    0.7500    0.8182        12
#     positive     0.7273    0.8889    0.8000         9
#
#     accuracy                         0.8095        21
#    macro avg     0.8136    0.8194    0.8091        21
# weighted avg     0.8260    0.8095    0.8104        21

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.6667    0.8000         9
#     positive     0.8000    1.0000    0.8889        12
#
#     accuracy                         0.8571        21
#    macro avg     0.9000    0.8333    0.8444        21
# weighted avg     0.8857    0.8571    0.8508        21
# Rodada: 1	Seed: 8968	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     0.9000    0.6923    0.7826        13
#     positive     0.6364    0.8750    0.7368         8
#
#     accuracy                         0.7619        21
#    macro avg     0.7682    0.7837    0.7597        21
# weighted avg     0.7996    0.7619    0.7652        21
# Rodada: 2	Seed: 8442	Score: 0.6666666666666666
#               precision    recall  f1-score   support
#
#     negative     0.8000    0.6154    0.6957        13
#     positive     0.5455    0.7500    0.6316         8
#
#     accuracy                         0.6667        21
#    macro avg     0.6727    0.6827    0.6636        21
# weighted avg     0.7030    0.6667    0.6712        21
# Rodada: 3	Seed: 1729	Score: 0.7142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.7778    0.6364    0.7000        11
#     positive     0.6667    0.8000    0.7273        10
#
#     accuracy                         0.7143        21
#    macro avg     0.7222    0.7182    0.7136        21
# weighted avg     0.7249    0.7143    0.7130        21
# Rodada: 4	Seed: 290	Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#     negative     0.8889    0.8000    0.8421        10
#     positive     0.8333    0.9091    0.8696        11
#
#     accuracy                         0.8571        21
#    macro avg     0.8611    0.8545    0.8558        21
# weighted avg     0.8598    0.8571    0.8565        21
# Rodada: 5	Seed: 490	Score: 0.8095238095238095
#               precision    recall  f1-score   support
#
#     negative     0.7000    0.8750    0.7778         8
#     positive     0.9091    0.7692    0.8333        13
#
#     accuracy                         0.8095        21
#    macro avg     0.8045    0.8221    0.8056        21
# weighted avg     0.8294    0.8095    0.8122        21
# Rodada: 6	Seed: 2128	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     0.9167    0.9167    0.9167        12
#     positive     0.8889    0.8889    0.8889         9
#
#     accuracy                         0.9048        21
#    macro avg     0.9028    0.9028    0.9028        21
# weighted avg     0.9048    0.9048    0.9048        21
# Rodada: 7	Seed: 1167	Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#     negative     0.9000    0.8182    0.8571        11
#     positive     0.8182    0.9000    0.8571        10
#
#     accuracy                         0.8571        21
#    macro avg     0.8591    0.8591    0.8571        21
# weighted avg     0.8610    0.8571    0.8571        21
# Rodada: 8	Seed: 8900	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.8462    0.9167        13
#     positive     0.8000    1.0000    0.8889         8
#
#     accuracy                         0.9048        21
#    macro avg     0.9000    0.9231    0.9028        21
# weighted avg     0.9238    0.9048    0.9061        21
# Rodada: 9	Seed: 5078	Score: 0.8095238095238095
#               precision    recall  f1-score   support
#
#     negative     0.7500    0.7500    0.7500         8
#     positive     0.8462    0.8462    0.8462        13
#
#     accuracy                         0.8095        21
#    macro avg     0.7981    0.7981    0.7981        21
# weighted avg     0.8095    0.8095    0.8095        21
# Rodada: 10	Seed: 1359	Score: 0.8095238095238095
#               precision    recall  f1-score   support
#
#     negative     0.8000    0.8000    0.8000        10
#     positive     0.8182    0.8182    0.8182        11
#
#     accuracy                         0.8095        21
#    macro avg     0.8091    0.8091    0.8091        21
# weighted avg     0.8095    0.8095    0.8095        21
# Rodada: 11	Seed: 894	Score: 0.8095238095238095
#               precision    recall  f1-score   support
#
#     negative     0.8182    0.8182    0.8182        11
#     positive     0.8000    0.8000    0.8000        10
#
#     accuracy                         0.8095        21
#    macro avg     0.8091    0.8091    0.8091        21
# weighted avg     0.8095    0.8095    0.8095        21
# Rodada: 12	Seed: 7809	Score: 0.7142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.6923    0.8182    0.7500        11
#     positive     0.7500    0.6000    0.6667        10
#
#     accuracy                         0.7143        21
#    macro avg     0.7212    0.7091    0.7083        21
# weighted avg     0.7198    0.7143    0.7103        21
# Rodada: 13	Seed: 6990	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     0.7692    0.8333    0.8000        12
#     positive     0.7500    0.6667    0.7059         9
#
#     accuracy                         0.7619        21
#    macro avg     0.7596    0.7500    0.7529        21
# weighted avg     0.7610    0.7619    0.7597        21
# Rodada: 14	Seed: 3623	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        11
#     positive     1.0000    1.0000    1.0000        10
#
#     accuracy                         1.0000        21
#    macro avg     1.0000    1.0000    1.0000        21
# weighted avg     1.0000    1.0000    1.0000        21
# Rodada: 15	Seed: 5906	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     0.8333    1.0000    0.9091        10
#     positive     1.0000    0.8182    0.9000        11
#
#     accuracy                         0.9048        21
#    macro avg     0.9167    0.9091    0.9045        21
# weighted avg     0.9206    0.9048    0.9043        21
# Rodada: 16	Seed: 1687	Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.7273    0.8421        11
#     positive     0.7692    1.0000    0.8696        10
#
#     accuracy                         0.8571        21
#    macro avg     0.8846    0.8636    0.8558        21
# weighted avg     0.8901    0.8571    0.8552        21
# Rodada: 17	Seed: 7080	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     0.7000    0.7778    0.7368         9
#     positive     0.8182    0.7500    0.7826        12
#
#     accuracy                         0.7619        21
#    macro avg     0.7591    0.7639    0.7597        21
# weighted avg     0.7675    0.7619    0.7630        21
# Rodada: 18	Seed: 5473	Score: 0.7619047619047619
#               precision    recall  f1-score   support
#
#     negative     0.7500    0.8182    0.7826        11
#     positive     0.7778    0.7000    0.7368        10
#
#     accuracy                         0.7619        21
#    macro avg     0.7639    0.7591    0.7597        21
# weighted avg     0.7632    0.7619    0.7608        21
# Rodada: 19	Seed: 7854	Score: 0.8095238095238095
#               precision    recall  f1-score   support
#
#     negative     0.8333    0.8333    0.8333        12
#     positive     0.7778    0.7778    0.7778         9
#
#     accuracy                         0.8095        21
#    macro avg     0.8056    0.8056    0.8056        21
# weighted avg     0.8095    0.8095    0.8095        21

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.761905       0.857143
# 1       0.809524       0.761905
# 2       0.761905       0.666667
# 3       0.714286       0.714286
# 4       0.904762       0.857143
# 5       0.857143       0.809524
# 6       0.904762       0.904762
# 7       0.761905       0.857143
# 8       0.857143       0.904762
# 9       0.761905       0.809524
# 10      0.761905       0.809524
# 11      0.761905       0.809524
# 12      0.714286       0.714286
# 13      0.714286       0.761905
# 14      0.857143       1.000000
# 15      0.857143       0.904762
# 16      0.904762       0.857143
# 17      0.714286       0.761905
# 18      0.761905       0.761905
# 19      0.809524       0.809524

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.797619       0.816667
# std        0.067122       0.079194
# min        0.714286       0.666667
# 25%        0.761905       0.761905
# 50%        0.761905       0.809524
# 75%        0.857143       0.857143
# max        0.904762       1.000000
