# %% [markdown]
# # KNN CHB21 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb21_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.8684    0.9706    0.9167        34
#     positive     0.9500    0.7917    0.8636        24
#
#     accuracy                         0.8966        58
#    macro avg     0.9092    0.8811    0.8902        58
# weighted avg     0.9022    0.8966    0.8947        58
# Rodada: 1	Seed: 8968	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.8462    0.8800    0.8627        25
#     positive     0.9062    0.8788    0.8923        33
#
#     accuracy                         0.8793        58
#    macro avg     0.8762    0.8794    0.8775        58
# weighted avg     0.8803    0.8793    0.8796        58
# Rodada: 2	Seed: 8442	Score: 0.8275862068965517
#               precision    recall  f1-score   support
#
#     negative     0.7895    0.9375    0.8571        32
#     positive     0.9000    0.6923    0.7826        26
#
#     accuracy                         0.8276        58
#    macro avg     0.8447    0.8149    0.8199        58
# weighted avg     0.8390    0.8276    0.8237        58
# Rodada: 3	Seed: 1729	Score: 0.8103448275862069
#               precision    recall  f1-score   support
#
#     negative     0.8621    0.7812    0.8197        32
#     positive     0.7586    0.8462    0.8000        26
#
#     accuracy                         0.8103        58
#    macro avg     0.8103    0.8137    0.8098        58
# weighted avg     0.8157    0.8103    0.8109        58
# Rodada: 4	Seed: 290	Score: 0.9310344827586207
#               precision    recall  f1-score   support
#
#     negative     0.9487    0.9487    0.9487        39
#     positive     0.8947    0.8947    0.8947        19
#
#     accuracy                         0.9310        58
#    macro avg     0.9217    0.9217    0.9217        58
# weighted avg     0.9310    0.9310    0.9310        58
# Rodada: 5	Seed: 490	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.8065    0.9615    0.8772        26
#     positive     0.9630    0.8125    0.8814        32
#
#     accuracy                         0.8793        58
#    macro avg     0.8847    0.8870    0.8793        58
# weighted avg     0.8928    0.8793    0.8795        58
# Rodada: 6	Seed: 2128	Score: 0.8275862068965517
#               precision    recall  f1-score   support
#
#     negative     0.7667    0.8846    0.8214        26
#     positive     0.8929    0.7812    0.8333        32
#
#     accuracy                         0.8276        58
#    macro avg     0.8298    0.8329    0.8274        58
# weighted avg     0.8363    0.8276    0.8280        58
# Rodada: 7	Seed: 1167	Score: 0.8620689655172413
#               precision    recall  f1-score   support
#
#     negative     0.7778    1.0000    0.8750        28
#     positive     1.0000    0.7333    0.8462        30
#
#     accuracy                         0.8621        58
#    macro avg     0.8889    0.8667    0.8606        58
# weighted avg     0.8927    0.8621    0.8601        58
# Rodada: 8	Seed: 8900	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.8919    0.9167    0.9041        36
#     positive     0.8571    0.8182    0.8372        22
#
#     accuracy                         0.8793        58
#    macro avg     0.8745    0.8674    0.8707        58
# weighted avg     0.8787    0.8793    0.8787        58
# Rodada: 9	Seed: 5078	Score: 0.8448275862068966
#               precision    recall  f1-score   support
#
#     negative     0.8333    0.9091    0.8696        33
#     positive     0.8636    0.7600    0.8085        25
#
#     accuracy                         0.8448        58
#    macro avg     0.8485    0.8345    0.8390        58
# weighted avg     0.8464    0.8448    0.8432        58
# Rodada: 10	Seed: 1359	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.8485    0.9333    0.8889        30
#     positive     0.9200    0.8214    0.8679        28
#
#     accuracy                         0.8793        58
#    macro avg     0.8842    0.8774    0.8784        58
# weighted avg     0.8830    0.8793    0.8788        58
# Rodada: 11	Seed: 894	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.8824    0.9091    0.8955        33
#     positive     0.8750    0.8400    0.8571        25
#
#     accuracy                         0.8793        58
#    macro avg     0.8787    0.8745    0.8763        58
# weighted avg     0.8792    0.8793    0.8790        58
# Rodada: 12	Seed: 7809	Score: 0.8448275862068966
#               precision    recall  f1-score   support
#
#     negative     0.7692    1.0000    0.8696        30
#     positive     1.0000    0.6786    0.8085        28
#
#     accuracy                         0.8448        58
#    macro avg     0.8846    0.8393    0.8390        58
# weighted avg     0.8806    0.8448    0.8401        58
# Rodada: 13	Seed: 6990	Score: 0.8620689655172413
#               precision    recall  f1-score   support
#
#     negative     0.8333    0.8929    0.8621        28
#     positive     0.8929    0.8333    0.8621        30
#
#     accuracy                         0.8621        58
#    macro avg     0.8631    0.8631    0.8621        58
# weighted avg     0.8641    0.8621    0.8621        58
# Rodada: 14	Seed: 3623	Score: 0.8448275862068966
#               precision    recall  f1-score   support
#
#     negative     0.8857    0.8611    0.8732        36
#     positive     0.7826    0.8182    0.8000        22
#
#     accuracy                         0.8448        58
#    macro avg     0.8342    0.8396    0.8366        58
# weighted avg     0.8466    0.8448    0.8455        58
# Rodada: 15	Seed: 5906	Score: 0.7413793103448276
#               precision    recall  f1-score   support
#
#     negative     0.6111    0.9565    0.7458        23
#     positive     0.9545    0.6000    0.7368        35
#
#     accuracy                         0.7414        58
#    macro avg     0.7828    0.7783    0.7413        58
# weighted avg     0.8184    0.7414    0.7404        58
# Rodada: 16	Seed: 1687	Score: 0.7413793103448276
#               precision    recall  f1-score   support
#
#     negative     0.6286    0.9167    0.7458        24
#     positive     0.9130    0.6176    0.7368        34
#
#     accuracy                         0.7414        58
#    macro avg     0.7708    0.7672    0.7413        58
# weighted avg     0.7953    0.7414    0.7405        58
# Rodada: 17	Seed: 7080	Score: 0.8620689655172413
#               precision    recall  f1-score   support
#
#     negative     0.8438    0.9000    0.8710        30
#     positive     0.8846    0.8214    0.8519        28
#
#     accuracy                         0.8621        58
#    macro avg     0.8642    0.8607    0.8614        58
# weighted avg     0.8635    0.8621    0.8617        58
# Rodada: 18	Seed: 5473	Score: 0.8620689655172413
#               precision    recall  f1-score   support
#
#     negative     0.8571    0.9091    0.8824        33
#     positive     0.8696    0.8000    0.8333        25
#
#     accuracy                         0.8621        58
#    macro avg     0.8634    0.8545    0.8578        58
# weighted avg     0.8625    0.8621    0.8612        58
# Rodada: 19	Seed: 7854	Score: 0.8620689655172413
#               precision    recall  f1-score   support
#
#     negative     0.8235    0.9333    0.8750        30
#     positive     0.9167    0.7857    0.8462        28
#
#     accuracy                         0.8621        58
#    macro avg     0.8701    0.8595    0.8606        58
# weighted avg     0.8685    0.8621    0.8611        58

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9482758620689655
#               precision    recall  f1-score   support
#
#     negative     0.9429    0.9706    0.9565        34
#     positive     0.9565    0.9167    0.9362        24
#
#     accuracy                         0.9483        58
#    macro avg     0.9497    0.9436    0.9463        58
# weighted avg     0.9485    0.9483    0.9481        58
# Rodada: 1	Seed: 8968	Score: 0.8103448275862069
#               precision    recall  f1-score   support
#
#     negative     0.7917    0.7600    0.7755        25
#     positive     0.8235    0.8485    0.8358        33
#
#     accuracy                         0.8103        58
#    macro avg     0.8076    0.8042    0.8057        58
# weighted avg     0.8098    0.8103    0.8098        58
# Rodada: 2	Seed: 8442	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.8378    0.9688    0.8986        32
#     positive     0.9524    0.7692    0.8511        26
#
#     accuracy                         0.8793        58
#    macro avg     0.8951    0.8690    0.8748        58
# weighted avg     0.8892    0.8793    0.8773        58
# Rodada: 3	Seed: 1729	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.9310    0.8438    0.8852        32
#     positive     0.8276    0.9231    0.8727        26
#
#     accuracy                         0.8793        58
#    macro avg     0.8793    0.8834    0.8790        58
# weighted avg     0.8847    0.8793    0.8796        58
# Rodada: 4	Seed: 290	Score: 0.9482758620689655
#               precision    recall  f1-score   support
#
#     negative     0.9737    0.9487    0.9610        39
#     positive     0.9000    0.9474    0.9231        19
#
#     accuracy                         0.9483        58
#    macro avg     0.9368    0.9480    0.9421        58
# weighted avg     0.9495    0.9483    0.9486        58
# Rodada: 5	Seed: 490	Score: 0.8620689655172413
#               precision    recall  f1-score   support
#
#     negative     0.8214    0.8846    0.8519        26
#     positive     0.9000    0.8438    0.8710        32
#
#     accuracy                         0.8621        58
#    macro avg     0.8607    0.8642    0.8614        58
# weighted avg     0.8648    0.8621    0.8624        58
# Rodada: 6	Seed: 2128	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.8276    0.9231    0.8727        26
#     positive     0.9310    0.8438    0.8852        32
#
#     accuracy                         0.8793        58
#    macro avg     0.8793    0.8834    0.8790        58
# weighted avg     0.8847    0.8793    0.8796        58
# Rodada: 7	Seed: 1167	Score: 0.8620689655172413
#               precision    recall  f1-score   support
#
#     negative     0.7941    0.9643    0.8710        28
#     positive     0.9583    0.7667    0.8519        30
#
#     accuracy                         0.8621        58
#    macro avg     0.8762    0.8655    0.8614        58
# weighted avg     0.8791    0.8621    0.8611        58
# Rodada: 8	Seed: 8900	Score: 0.9655172413793104
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9444    0.9714        36
#     positive     0.9167    1.0000    0.9565        22
#
#     accuracy                         0.9655        58
#    macro avg     0.9583    0.9722    0.9640        58
# weighted avg     0.9684    0.9655    0.9658        58
# Rodada: 9	Seed: 5078	Score: 0.9482758620689655
#               precision    recall  f1-score   support
#
#     negative     0.9412    0.9697    0.9552        33
#     positive     0.9583    0.9200    0.9388        25
#
#     accuracy                         0.9483        58
#    macro avg     0.9498    0.9448    0.9470        58
# weighted avg     0.9486    0.9483    0.9481        58
# Rodada: 10	Seed: 1359	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.8485    0.9333    0.8889        30
#     positive     0.9200    0.8214    0.8679        28
#
#     accuracy                         0.8793        58
#    macro avg     0.8842    0.8774    0.8784        58
# weighted avg     0.8830    0.8793    0.8788        58
# Rodada: 11	Seed: 894	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.8824    0.9091    0.8955        33
#     positive     0.8750    0.8400    0.8571        25
#
#     accuracy                         0.8793        58
#    macro avg     0.8787    0.8745    0.8763        58
# weighted avg     0.8792    0.8793    0.8790        58
# Rodada: 12	Seed: 7809	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.8529    0.9667    0.9062        30
#     positive     0.9583    0.8214    0.8846        28
#
#     accuracy                         0.8966        58
#    macro avg     0.9056    0.8940    0.8954        58
# weighted avg     0.9038    0.8966    0.8958        58
# Rodada: 13	Seed: 6990	Score: 0.8448275862068966
#               precision    recall  f1-score   support
#
#     negative     0.7879    0.9286    0.8525        28
#     positive     0.9200    0.7667    0.8364        30
#
#     accuracy                         0.8448        58
#    macro avg     0.8539    0.8476    0.8444        58
# weighted avg     0.8562    0.8448    0.8441        58
# Rodada: 14	Seed: 3623	Score: 0.8103448275862069
#               precision    recall  f1-score   support
#
#     negative     0.8378    0.8611    0.8493        36
#     positive     0.7619    0.7273    0.7442        22
#
#     accuracy                         0.8103        58
#    macro avg     0.7999    0.7942    0.7968        58
# weighted avg     0.8090    0.8103    0.8094        58
# Rodada: 15	Seed: 5906	Score: 0.8275862068965517
#               precision    recall  f1-score   support
#
#     negative     0.7097    0.9565    0.8148        23
#     positive     0.9630    0.7429    0.8387        35
#
#     accuracy                         0.8276        58
#    macro avg     0.8363    0.8497    0.8268        58
# weighted avg     0.8625    0.8276    0.8292        58
# Rodada: 16	Seed: 1687	Score: 0.8103448275862069
#               precision    recall  f1-score   support
#
#     negative     0.7241    0.8750    0.7925        24
#     positive     0.8966    0.7647    0.8254        34
#
#     accuracy                         0.8103        58
#    macro avg     0.8103    0.8199    0.8089        58
# weighted avg     0.8252    0.8103    0.8118        58
# Rodada: 17	Seed: 7080	Score: 0.9137931034482759
#               precision    recall  f1-score   support
#
#     negative     0.9032    0.9333    0.9180        30
#     positive     0.9259    0.8929    0.9091        28
#
#     accuracy                         0.9138        58
#    macro avg     0.9146    0.9131    0.9136        58
# weighted avg     0.9142    0.9138    0.9137        58
# Rodada: 18	Seed: 5473	Score: 0.8620689655172413
#               precision    recall  f1-score   support
#
#     negative     0.9032    0.8485    0.8750        33
#     positive     0.8148    0.8800    0.8462        25
#
#     accuracy                         0.8621        58
#    macro avg     0.8590    0.8642    0.8606        58
# weighted avg     0.8651    0.8621    0.8626        58
# Rodada: 19	Seed: 7854	Score: 0.8793103448275862
#               precision    recall  f1-score   support
#
#     negative     0.8485    0.9333    0.8889        30
#     positive     0.9200    0.8214    0.8679        28
#
#     accuracy                         0.8793        58
#    macro avg     0.8842    0.8774    0.8784        58
# weighted avg     0.8830    0.8793    0.8788        58

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.896552       0.948276
# 1       0.879310       0.810345
# 2       0.827586       0.879310
# 3       0.810345       0.879310
# 4       0.931034       0.948276
# 5       0.879310       0.862069
# 6       0.827586       0.879310
# 7       0.862069       0.862069
# 8       0.879310       0.965517
# 9       0.844828       0.948276
# 10      0.879310       0.879310
# 11      0.879310       0.879310
# 12      0.844828       0.896552
# 13      0.862069       0.844828
# 14      0.844828       0.810345
# 15      0.741379       0.827586
# 16      0.741379       0.810345
# 17      0.862069       0.913793
# 18      0.862069       0.862069
# 19      0.862069       0.879310

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.850862       0.879310
# std        0.045881       0.047135
# min        0.741379       0.810345
# 25%        0.840517       0.857759
# 50%        0.862069       0.879310
# 75%        0.879310       0.900862
# max        0.931034       0.965517
