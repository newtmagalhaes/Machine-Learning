# %% [markdown]
# # KNN CHB12 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb12_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9055944055944056
#               precision    recall  f1-score   support
#
#     negative     0.8836    0.9281    0.9053       139
#     positive     0.9286    0.8844    0.9059       147
#
#     accuracy                         0.9056       286
#    macro avg     0.9061    0.9062    0.9056       286
# weighted avg     0.9067    0.9056    0.9056       286
# Rodada: 1	Seed: 8968	Score: 0.8986013986013986
#               precision    recall  f1-score   support
#
#     negative     0.8614    0.9597    0.9079       149
#     positive     0.9500    0.8321    0.8872       137
#
#     accuracy                         0.8986       286
#    macro avg     0.9057    0.8959    0.8975       286
# weighted avg     0.9039    0.8986    0.8980       286
# Rodada: 2	Seed: 8442	Score: 0.9265734265734266
#               precision    recall  f1-score   support
#
#     negative     0.8820    0.9861    0.9311       144
#     positive     0.9840    0.8662    0.9213       142
#
#     accuracy                         0.9266       286
#    macro avg     0.9330    0.9262    0.9262       286
# weighted avg     0.9326    0.9266    0.9263       286
# Rodada: 3	Seed: 1729	Score: 0.9125874125874126
#               precision    recall  f1-score   support
#
#     negative     0.8679    0.9718    0.9169       142
#     positive     0.9685    0.8542    0.9077       144
#
#     accuracy                         0.9126       286
#    macro avg     0.9182    0.9130    0.9123       286
# weighted avg     0.9186    0.9126    0.9123       286
# Rodada: 4	Seed: 290	Score: 0.9230769230769231
#               precision    recall  f1-score   support
#
#     negative     0.8864    0.9873    0.9341       158
#     positive     0.9818    0.8438    0.9076       128
#
#     accuracy                         0.9231       286
#    macro avg     0.9341    0.9155    0.9208       286
# weighted avg     0.9291    0.9231    0.9222       286
# Rodada: 5	Seed: 490	Score: 0.9265734265734266
#               precision    recall  f1-score   support
#
#     negative     0.8839    0.9786    0.9288       140
#     positive     0.9771    0.8767    0.9242       146
#
#     accuracy                         0.9266       286
#    macro avg     0.9305    0.9276    0.9265       286
# weighted avg     0.9315    0.9266    0.9265       286
# Rodada: 6	Seed: 2128	Score: 0.9265734265734266
#               precision    recall  f1-score   support
#
#     negative     0.9136    0.9548    0.9338       155
#     positive     0.9435    0.8931    0.9176       131
#
#     accuracy                         0.9266       286
#    macro avg     0.9286    0.9240    0.9257       286
# weighted avg     0.9273    0.9266    0.9264       286
# Rodada: 7	Seed: 1167	Score: 0.9195804195804196
#               precision    recall  f1-score   support
#
#     negative     0.8839    0.9648    0.9226       142
#     positive     0.9618    0.8750    0.9164       144
#
#     accuracy                         0.9196       286
#    macro avg     0.9229    0.9199    0.9195       286
# weighted avg     0.9231    0.9196    0.9194       286
# Rodada: 8	Seed: 8900	Score: 0.9265734265734266
#               precision    recall  f1-score   support
#
#     negative     0.8987    0.9660    0.9311       147
#     positive     0.9609    0.8849    0.9213       139
#
#     accuracy                         0.9266       286
#    macro avg     0.9298    0.9254    0.9262       286
# weighted avg     0.9290    0.9266    0.9264       286
# Rodada: 9	Seed: 5078	Score: 0.9370629370629371
#               precision    recall  f1-score   support
#
#     negative     0.9103    0.9726    0.9404       146
#     positive     0.9692    0.9000    0.9333       140
#
#     accuracy                         0.9371       286
#    macro avg     0.9397    0.9363    0.9369       286
# weighted avg     0.9391    0.9371    0.9369       286
# Rodada: 10	Seed: 1359	Score: 0.9055944055944056
#               precision    recall  f1-score   support
#
#     negative     0.8618    0.9562    0.9066       137
#     positive     0.9552    0.8591    0.9046       149
#
#     accuracy                         0.9056       286
#    macro avg     0.9085    0.9076    0.9056       286
# weighted avg     0.9105    0.9056    0.9055       286
# Rodada: 11	Seed: 894	Score: 0.8916083916083916
#               precision    recall  f1-score   support
#
#     negative     0.8580    0.9539    0.9034       152
#     positive     0.9402    0.8209    0.8765       134
#
#     accuracy                         0.8916       286
#    macro avg     0.8991    0.8874    0.8900       286
# weighted avg     0.8965    0.8916    0.8908       286
# Rodada: 12	Seed: 7809	Score: 0.8951048951048951
#               precision    recall  f1-score   support
#
#     negative     0.8581    0.9433    0.8986       141
#     positive     0.9389    0.8483    0.8913       145
#
#     accuracy                         0.8951       286
#    macro avg     0.8985    0.8958    0.8950       286
# weighted avg     0.8991    0.8951    0.8949       286
# Rodada: 13	Seed: 6990	Score: 0.8881118881118881
#               precision    recall  f1-score   support
#
#     negative     0.8452    0.9595    0.8987       148
#     positive     0.9492    0.8116    0.8750       138
#
#     accuracy                         0.8881       286
#    macro avg     0.8972    0.8855    0.8869       286
# weighted avg     0.8954    0.8881    0.8873       286
# Rodada: 14	Seed: 3623	Score: 0.9265734265734266
#               precision    recall  f1-score   support
#
#     negative     0.8940    0.9643    0.9278       140
#     positive     0.9630    0.8904    0.9253       146
#
#     accuracy                         0.9266       286
#    macro avg     0.9285    0.9273    0.9266       286
# weighted avg     0.9292    0.9266    0.9265       286
# Rodada: 15	Seed: 5906	Score: 0.916083916083916
#               precision    recall  f1-score   support
#
#     negative     0.8701    0.9710    0.9178       138
#     positive     0.9697    0.8649    0.9143       148
#
#     accuracy                         0.9161       286
#    macro avg     0.9199    0.9179    0.9160       286
# weighted avg     0.9217    0.9161    0.9160       286
# Rodada: 16	Seed: 1687	Score: 0.9020979020979021
#               precision    recall  f1-score   support
#
#     negative     0.8671    0.9514    0.9073       144
#     positive     0.9453    0.8521    0.8963       142
#
#     accuracy                         0.9021       286
#    macro avg     0.9062    0.9018    0.9018       286
# weighted avg     0.9059    0.9021    0.9018       286
# Rodada: 17	Seed: 7080	Score: 0.916083916083916
#               precision    recall  f1-score   support
#
#     negative     0.8774    0.9645    0.9189       141
#     positive     0.9618    0.8690    0.9130       145
#
#     accuracy                         0.9161       286
#    macro avg     0.9196    0.9168    0.9160       286
# weighted avg     0.9202    0.9161    0.9159       286
# Rodada: 18	Seed: 5473	Score: 0.9055944055944056
#               precision    recall  f1-score   support
#
#     negative     0.8922    0.9430    0.9169       158
#     positive     0.9244    0.8594    0.8907       128
#
#     accuracy                         0.9056       286
#    macro avg     0.9083    0.9012    0.9038       286
# weighted avg     0.9066    0.9056    0.9052       286
# Rodada: 19	Seed: 7854	Score: 0.9335664335664335
#               precision    recall  f1-score   support
#
#     negative     0.9150    0.9589    0.9365       146
#     positive     0.9549    0.9071    0.9304       140
#
#     accuracy                         0.9336       286
#    macro avg     0.9350    0.9330    0.9334       286
# weighted avg     0.9345    0.9336    0.9335       286

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.8811188811188811
#               precision    recall  f1-score   support
#
#     negative     0.8477    0.9209    0.8828       139
#     positive     0.9185    0.8435    0.8794       147
#
#     accuracy                         0.8811       286
#    macro avg     0.8831    0.8822    0.8811       286
# weighted avg     0.8841    0.8811    0.8810       286
# Rodada: 1	Seed: 8968	Score: 0.8846153846153846
#               precision    recall  f1-score   support
#
#     negative     0.8452    0.9530    0.8959       149
#     positive     0.9407    0.8102    0.8706       137
#
#     accuracy                         0.8846       286
#    macro avg     0.8930    0.8816    0.8832       286
# weighted avg     0.8910    0.8846    0.8838       286
# Rodada: 2	Seed: 8442	Score: 0.8916083916083916
#               precision    recall  f1-score   support
#
#     negative     0.8553    0.9444    0.8977       144
#     positive     0.9370    0.8380    0.8848       142
#
#     accuracy                         0.8916       286
#    macro avg     0.8962    0.8912    0.8912       286
# weighted avg     0.8959    0.8916    0.8913       286
# Rodada: 3	Seed: 1729	Score: 0.9265734265734266
#               precision    recall  f1-score   support
#
#     negative     0.8903    0.9718    0.9293       142
#     positive     0.9695    0.8819    0.9236       144
#
#     accuracy                         0.9266       286
#    macro avg     0.9299    0.9269    0.9265       286
# weighted avg     0.9302    0.9266    0.9264       286
# Rodada: 4	Seed: 290	Score: 0.9020979020979021
#               precision    recall  f1-score   support
#
#     negative     0.8652    0.9747    0.9167       158
#     positive     0.9630    0.8125    0.8814       128
#
#     accuracy                         0.9021       286
#    macro avg     0.9141    0.8936    0.8990       286
# weighted avg     0.9089    0.9021    0.9009       286
# Rodada: 5	Seed: 490	Score: 0.8846153846153846
#               precision    recall  f1-score   support
#
#     negative     0.8497    0.9286    0.8874       140
#     positive     0.9248    0.8425    0.8817       146
#
#     accuracy                         0.8846       286
#    macro avg     0.8872    0.8855    0.8845       286
# weighted avg     0.8880    0.8846    0.8845       286
# Rodada: 6	Seed: 2128	Score: 0.9090909090909091
#               precision    recall  f1-score   support
#
#     negative     0.8957    0.9419    0.9182       155
#     positive     0.9268    0.8702    0.8976       131
#
#     accuracy                         0.9091       286
#    macro avg     0.9113    0.9061    0.9079       286
# weighted avg     0.9100    0.9091    0.9088       286
# Rodada: 7	Seed: 1167	Score: 0.916083916083916
#               precision    recall  f1-score   support
#
#     negative     0.8882    0.9507    0.9184       142
#     positive     0.9478    0.8819    0.9137       144
#
#     accuracy                         0.9161       286
#    macro avg     0.9180    0.9163    0.9160       286
# weighted avg     0.9182    0.9161    0.9160       286
# Rodada: 8	Seed: 8900	Score: 0.8986013986013986
#               precision    recall  f1-score   support
#
#     negative     0.8642    0.9524    0.9061       147
#     positive     0.9435    0.8417    0.8897       139
#
#     accuracy                         0.8986       286
#    macro avg     0.9039    0.8971    0.8979       286
# weighted avg     0.9028    0.8986    0.8982       286
# Rodada: 9	Seed: 5078	Score: 0.9230769230769231
#               precision    recall  f1-score   support
#
#     negative     0.8827    0.9795    0.9286       146
#     positive     0.9758    0.8643    0.9167       140
#
#     accuracy                         0.9231       286
#    macro avg     0.9293    0.9219    0.9226       286
# weighted avg     0.9283    0.9231    0.9227       286
# Rodada: 10	Seed: 1359	Score: 0.8811188811188811
#               precision    recall  f1-score   support
#
#     negative     0.8239    0.9562    0.8851       137
#     positive     0.9528    0.8121    0.8768       149
#
#     accuracy                         0.8811       286
#    macro avg     0.8883    0.8841    0.8810       286
# weighted avg     0.8910    0.8811    0.8808       286
# Rodada: 11	Seed: 894	Score: 0.8776223776223776
#               precision    recall  f1-score   support
#
#     negative     0.8503    0.9342    0.8903       152
#     positive     0.9160    0.8134    0.8617       134
#
#     accuracy                         0.8776       286
#    macro avg     0.8831    0.8738    0.8760       286
# weighted avg     0.8811    0.8776    0.8769       286
# Rodada: 12	Seed: 7809	Score: 0.9090909090909091
#               precision    recall  f1-score   support
#
#     negative     0.8571    0.9787    0.9139       141
#     positive     0.9760    0.8414    0.9037       145
#
#     accuracy                         0.9091       286
#    macro avg     0.9166    0.9101    0.9088       286
# weighted avg     0.9174    0.9091    0.9087       286
# Rodada: 13	Seed: 6990	Score: 0.8916083916083916
#               precision    recall  f1-score   support
#
#     negative     0.8503    0.9595    0.9016       148
#     positive     0.9496    0.8188    0.8794       138
#
#     accuracy                         0.8916       286
#    macro avg     0.8999    0.8892    0.8905       286
# weighted avg     0.8982    0.8916    0.8909       286
# Rodada: 14	Seed: 3623	Score: 0.9055944055944056
#               precision    recall  f1-score   support
#
#     negative     0.8599    0.9643    0.9091       140
#     positive     0.9612    0.8493    0.9018       146
#
#     accuracy                         0.9056       286
#    macro avg     0.9106    0.9068    0.9055       286
# weighted avg     0.9116    0.9056    0.9054       286
# Rodada: 15	Seed: 5906	Score: 0.8846153846153846
#               precision    recall  f1-score   support
#
#     negative     0.8431    0.9348    0.8866       138
#     positive     0.9323    0.8378    0.8826       148
#
#     accuracy                         0.8846       286
#    macro avg     0.8877    0.8863    0.8846       286
# weighted avg     0.8893    0.8846    0.8845       286
# Rodada: 16	Seed: 1687	Score: 0.8741258741258742
#               precision    recall  f1-score   support
#
#     negative     0.8333    0.9375    0.8824       144
#     positive     0.9274    0.8099    0.8647       142
#
#     accuracy                         0.8741       286
#    macro avg     0.8804    0.8737    0.8735       286
# weighted avg     0.8800    0.8741    0.8736       286
# Rodada: 17	Seed: 7080	Score: 0.8881118881118881
#               precision    recall  f1-score   support
#
#     negative     0.8562    0.9291    0.8912       141
#     positive     0.9248    0.8483    0.8849       145
#
#     accuracy                         0.8881       286
#    macro avg     0.8905    0.8887    0.8880       286
# weighted avg     0.8910    0.8881    0.8880       286
# Rodada: 18	Seed: 5473	Score: 0.8916083916083916
#               precision    recall  f1-score   support
#
#     negative     0.8896    0.9177    0.9034       158
#     positive     0.8943    0.8594    0.8765       128
#
#     accuracy                         0.8916       286
#    macro avg     0.8919    0.8885    0.8900       286
# weighted avg     0.8917    0.8916    0.8914       286
# Rodada: 19	Seed: 7854	Score: 0.9370629370629371
#               precision    recall  f1-score   support
#
#     negative     0.9211    0.9589    0.9396       146
#     positive     0.9552    0.9143    0.9343       140
#
#     accuracy                         0.9371       286
#    macro avg     0.9381    0.9366    0.9370       286
# weighted avg     0.9378    0.9371    0.9370       286

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.905594       0.881119
# 1       0.898601       0.884615
# 2       0.926573       0.891608
# 3       0.912587       0.926573
# 4       0.923077       0.902098
# 5       0.926573       0.884615
# 6       0.926573       0.909091
# 7       0.919580       0.916084
# 8       0.926573       0.898601
# 9       0.937063       0.923077
# 10      0.905594       0.881119
# 11      0.891608       0.877622
# 12      0.895105       0.909091
# 13      0.888112       0.891608
# 14      0.926573       0.905594
# 15      0.916084       0.884615
# 16      0.902098       0.874126
# 17      0.916084       0.888112
# 18      0.905594       0.891608
# 19      0.933566       0.937063

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.914161       0.897902
# std        0.014415       0.017669
# min        0.888112       0.874126
# 25%        0.904720       0.884615
# 50%        0.916084       0.891608
# 75%        0.926573       0.909091
# max        0.937063       0.937063
