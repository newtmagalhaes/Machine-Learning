# %% [markdown]
# # KNN CHB15 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb15_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9852941176470589
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9750    0.9873        40
#     positive     0.9655    1.0000    0.9825        28
#
#     accuracy                         0.9853        68
#    macro avg     0.9828    0.9875    0.9849        68
# weighted avg     0.9858    0.9853    0.9853        68
# Rodada: 1	Seed: 8968	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        29
#     positive     1.0000    1.0000    1.0000        39
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 2	Seed: 8442	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        39
#     positive     1.0000    1.0000    1.0000        29
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 3	Seed: 1729	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        32
#     positive     1.0000    1.0000    1.0000        36
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 4	Seed: 290	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        39
#     positive     1.0000    1.0000    1.0000        29
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 5	Seed: 490	Score: 0.9852941176470589
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9714    0.9855        35
#     positive     0.9706    1.0000    0.9851        33
#
#     accuracy                         0.9853        68
#    macro avg     0.9853    0.9857    0.9853        68
# weighted avg     0.9857    0.9853    0.9853        68
# Rodada: 6	Seed: 2128	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        31
#     positive     1.0000    1.0000    1.0000        37
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 7	Seed: 1167	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        32
#     positive     1.0000    1.0000    1.0000        36
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 8	Seed: 8900	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        34
#     positive     1.0000    1.0000    1.0000        34
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 9	Seed: 5078	Score: 0.9852941176470589
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9737    0.9867        38
#     positive     0.9677    1.0000    0.9836        30
#
#     accuracy                         0.9853        68
#    macro avg     0.9839    0.9868    0.9851        68
# weighted avg     0.9858    0.9853    0.9853        68
# Rodada: 10	Seed: 1359	Score: 0.9852941176470589
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9706    0.9851        34
#     positive     0.9714    1.0000    0.9855        34
#
#     accuracy                         0.9853        68
#    macro avg     0.9857    0.9853    0.9853        68
# weighted avg     0.9857    0.9853    0.9853        68
# Rodada: 11	Seed: 894	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        36
#     positive     1.0000    1.0000    1.0000        32
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 12	Seed: 7809	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        33
#     positive     1.0000    1.0000    1.0000        35
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 13	Seed: 6990	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        36
#     positive     1.0000    1.0000    1.0000        32
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 14	Seed: 3623	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        35
#     positive     1.0000    1.0000    1.0000        33
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 15	Seed: 5906	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        32
#     positive     1.0000    1.0000    1.0000        36
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 16	Seed: 1687	Score: 0.9852941176470589
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9655    0.9825        29
#     positive     0.9750    1.0000    0.9873        39
#
#     accuracy                         0.9853        68
#    macro avg     0.9875    0.9828    0.9849        68
# weighted avg     0.9857    0.9853    0.9853        68
# Rodada: 17	Seed: 7080	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        34
#     positive     1.0000    1.0000    1.0000        34
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 18	Seed: 5473	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        34
#     positive     1.0000    1.0000    1.0000        34
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 19	Seed: 7854	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        37
#     positive     1.0000    1.0000    1.0000        31
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9852941176470589
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9750    0.9873        40
#     positive     0.9655    1.0000    0.9825        28
#
#     accuracy                         0.9853        68
#    macro avg     0.9828    0.9875    0.9849        68
# weighted avg     0.9858    0.9853    0.9853        68
# Rodada: 1	Seed: 8968	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        29
#     positive     1.0000    1.0000    1.0000        39
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 2	Seed: 8442	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        39
#     positive     1.0000    1.0000    1.0000        29
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 3	Seed: 1729	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        32
#     positive     1.0000    1.0000    1.0000        36
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 4	Seed: 290	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        39
#     positive     1.0000    1.0000    1.0000        29
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 5	Seed: 490	Score: 0.9852941176470589
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9714    0.9855        35
#     positive     0.9706    1.0000    0.9851        33
#
#     accuracy                         0.9853        68
#    macro avg     0.9853    0.9857    0.9853        68
# weighted avg     0.9857    0.9853    0.9853        68
# Rodada: 6	Seed: 2128	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        31
#     positive     1.0000    1.0000    1.0000        37
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 7	Seed: 1167	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        32
#     positive     1.0000    1.0000    1.0000        36
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 8	Seed: 8900	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        34
#     positive     1.0000    1.0000    1.0000        34
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 9	Seed: 5078	Score: 0.9852941176470589
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9737    0.9867        38
#     positive     0.9677    1.0000    0.9836        30
#
#     accuracy                         0.9853        68
#    macro avg     0.9839    0.9868    0.9851        68
# weighted avg     0.9858    0.9853    0.9853        68
# Rodada: 10	Seed: 1359	Score: 0.9852941176470589
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9706    0.9851        34
#     positive     0.9714    1.0000    0.9855        34
#
#     accuracy                         0.9853        68
#    macro avg     0.9857    0.9853    0.9853        68
# weighted avg     0.9857    0.9853    0.9853        68
# Rodada: 11	Seed: 894	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        36
#     positive     1.0000    1.0000    1.0000        32
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 12	Seed: 7809	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        33
#     positive     1.0000    1.0000    1.0000        35
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 13	Seed: 6990	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        36
#     positive     1.0000    1.0000    1.0000        32
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 14	Seed: 3623	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        35
#     positive     1.0000    1.0000    1.0000        33
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 15	Seed: 5906	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        32
#     positive     1.0000    1.0000    1.0000        36
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 16	Seed: 1687	Score: 0.9852941176470589
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9655    0.9825        29
#     positive     0.9750    1.0000    0.9873        39
#
#     accuracy                         0.9853        68
#    macro avg     0.9875    0.9828    0.9849        68
# weighted avg     0.9857    0.9853    0.9853        68
# Rodada: 17	Seed: 7080	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        34
#     positive     1.0000    1.0000    1.0000        34
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 18	Seed: 5473	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        34
#     positive     1.0000    1.0000    1.0000        34
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68
# Rodada: 19	Seed: 7854	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        37
#     positive     1.0000    1.0000    1.0000        31
#
#     accuracy                         1.0000        68
#    macro avg     1.0000    1.0000    1.0000        68
# weighted avg     1.0000    1.0000    1.0000        68

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.985294       0.985294
# 1       1.000000       1.000000
# 2       1.000000       1.000000
# 3       1.000000       1.000000
# 4       1.000000       1.000000
# 5       0.985294       0.985294
# 6       1.000000       1.000000
# 7       1.000000       1.000000
# 8       1.000000       1.000000
# 9       0.985294       0.985294
# 10      0.985294       0.985294
# 11      1.000000       1.000000
# 12      1.000000       1.000000
# 13      1.000000       1.000000
# 14      1.000000       1.000000
# 15      1.000000       1.000000
# 16      0.985294       0.985294
# 17      1.000000       1.000000
# 18      1.000000       1.000000
# 19      1.000000       1.000000

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.996324       0.996324
# std        0.006533       0.006533
# min        0.985294       0.985294
# 25%        0.996324       0.996324
# 50%        1.000000       1.000000
# 75%        1.000000       1.000000
# max        1.000000       1.000000
