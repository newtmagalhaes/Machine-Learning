# %% [markdown]
# # KNN CHB24 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb24_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9319727891156463
#               precision    recall  f1-score   support
#
#     negative     0.8810    1.0000    0.9367        74
#     positive     1.0000    0.8630    0.9265        73
#
#     accuracy                         0.9320       147
#    macro avg     0.9405    0.9315    0.9316       147
# weighted avg     0.9401    0.9320    0.9316       147
# Rodada: 1	Seed: 8968	Score: 0.9387755102040817
#               precision    recall  f1-score   support
#
#     negative     0.9024    0.9867    0.9427        75
#     positive     0.9846    0.8889    0.9343        72
#
#     accuracy                         0.9388       147
#    macro avg     0.9435    0.9378    0.9385       147
# weighted avg     0.9427    0.9388    0.9386       147
# Rodada: 2	Seed: 8442	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     0.8571    0.9565    0.9041        69
#     positive     0.9571    0.8590    0.9054        78
#
#     accuracy                         0.9048       147
#    macro avg     0.9071    0.9077    0.9048       147
# weighted avg     0.9102    0.9048    0.9048       147
# Rodada: 3	Seed: 1729	Score: 0.9591836734693877
#               precision    recall  f1-score   support
#
#     negative     0.9390    0.9872    0.9625        78
#     positive     0.9846    0.9275    0.9552        69
#
#     accuracy                         0.9592       147
#    macro avg     0.9618    0.9574    0.9589       147
# weighted avg     0.9604    0.9592    0.9591       147
# Rodada: 4	Seed: 290	Score: 0.9251700680272109
#               precision    recall  f1-score   support
#
#     negative     0.8630    0.9844    0.9197        64
#     positive     0.9865    0.8795    0.9299        83
#
#     accuracy                         0.9252       147
#    macro avg     0.9248    0.9319    0.9248       147
# weighted avg     0.9327    0.9252    0.9255       147
# Rodada: 5	Seed: 490	Score: 0.9727891156462585
#               precision    recall  f1-score   support
#
#     negative     0.9674    0.9889    0.9780        90
#     positive     0.9818    0.9474    0.9643        57
#
#     accuracy                         0.9728       147
#    macro avg     0.9746    0.9681    0.9712       147
# weighted avg     0.9730    0.9728    0.9727       147
# Rodada: 6	Seed: 2128	Score: 0.9659863945578231
#               precision    recall  f1-score   support
#
#     negative     0.9512    0.9873    0.9689        79
#     positive     0.9846    0.9412    0.9624        68
#
#     accuracy                         0.9660       147
#    macro avg     0.9679    0.9643    0.9657       147
# weighted avg     0.9667    0.9660    0.9659       147
# Rodada: 7	Seed: 1167	Score: 0.9387755102040817
#               precision    recall  f1-score   support
#
#     negative     0.9067    0.9714    0.9379        70
#     positive     0.9722    0.9091    0.9396        77
#
#     accuracy                         0.9388       147
#    macro avg     0.9394    0.9403    0.9388       147
# weighted avg     0.9410    0.9388    0.9388       147
# Rodada: 8	Seed: 8900	Score: 0.9591836734693877
#               precision    recall  f1-score   support
#
#     negative     0.9189    1.0000    0.9577        68
#     positive     1.0000    0.9241    0.9605        79
#
#     accuracy                         0.9592       147
#    macro avg     0.9595    0.9620    0.9591       147
# weighted avg     0.9625    0.9592    0.9592       147
# Rodada: 9	Seed: 5078	Score: 0.9387755102040817
#               precision    recall  f1-score   support
#
#     negative     0.9167    0.9747    0.9448        79
#     positive     0.9683    0.8971    0.9313        68
#
#     accuracy                         0.9388       147
#    macro avg     0.9425    0.9359    0.9380       147
# weighted avg     0.9405    0.9388    0.9385       147
# Rodada: 10	Seed: 1359	Score: 0.9183673469387755
#               precision    recall  f1-score   support
#
#     negative     0.8621    1.0000    0.9259        75
#     positive     1.0000    0.8333    0.9091        72
#
#     accuracy                         0.9184       147
#    macro avg     0.9310    0.9167    0.9175       147
# weighted avg     0.9296    0.9184    0.9177       147
# Rodada: 11	Seed: 894	Score: 0.9863945578231292
#               precision    recall  f1-score   support
#
#     negative     0.9759    1.0000    0.9878        81
#     positive     1.0000    0.9697    0.9846        66
#
#     accuracy                         0.9864       147
#    macro avg     0.9880    0.9848    0.9862       147
# weighted avg     0.9867    0.9864    0.9864       147
# Rodada: 12	Seed: 7809	Score: 0.9659863945578231
#               precision    recall  f1-score   support
#
#     negative     0.9333    1.0000    0.9655        70
#     positive     1.0000    0.9351    0.9664        77
#
#     accuracy                         0.9660       147
#    macro avg     0.9667    0.9675    0.9660       147
# weighted avg     0.9683    0.9660    0.9660       147
# Rodada: 13	Seed: 6990	Score: 0.9591836734693877
#               precision    recall  f1-score   support
#
#     negative     0.9241    1.0000    0.9605        73
#     positive     1.0000    0.9189    0.9577        74
#
#     accuracy                         0.9592       147
#    macro avg     0.9620    0.9595    0.9591       147
# weighted avg     0.9623    0.9592    0.9591       147
# Rodada: 14	Seed: 3623	Score: 0.9251700680272109
#               precision    recall  f1-score   support
#
#     negative     0.8929    0.9740    0.9317        77
#     positive     0.9683    0.8714    0.9173        70
#
#     accuracy                         0.9252       147
#    macro avg     0.9306    0.9227    0.9245       147
# weighted avg     0.9288    0.9252    0.9248       147
# Rodada: 15	Seed: 5906	Score: 0.9319727891156463
#               precision    recall  f1-score   support
#
#     negative     0.8889    0.9863    0.9351        73
#     positive     0.9848    0.8784    0.9286        74
#
#     accuracy                         0.9320       147
#    macro avg     0.9369    0.9323    0.9318       147
# weighted avg     0.9372    0.9320    0.9318       147
# Rodada: 16	Seed: 1687	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     0.8590    0.9571    0.9054        70
#     positive     0.9565    0.8571    0.9041        77
#
#     accuracy                         0.9048       147
#    macro avg     0.9077    0.9071    0.9048       147
# weighted avg     0.9101    0.9048    0.9047       147
# Rodada: 17	Seed: 7080	Score: 0.9455782312925171
#               precision    recall  f1-score   support
#
#     negative     0.9315    0.9577    0.9444        71
#     positive     0.9595    0.9342    0.9467        76
#
#     accuracy                         0.9456       147
#    macro avg     0.9455    0.9460    0.9456       147
# weighted avg     0.9460    0.9456    0.9456       147
# Rodada: 18	Seed: 5473	Score: 0.9523809523809523
#               precision    recall  f1-score   support
#
#     negative     0.9241    0.9865    0.9542        74
#     positive     0.9853    0.9178    0.9504        73
#
#     accuracy                         0.9524       147
#    macro avg     0.9547    0.9521    0.9523       147
# weighted avg     0.9545    0.9524    0.9523       147
# Rodada: 19	Seed: 7854	Score: 0.9591836734693877
#               precision    recall  f1-score   support
#
#     negative     0.9518    0.9753    0.9634        81
#     positive     0.9688    0.9394    0.9538        66
#
#     accuracy                         0.9592       147
#    macro avg     0.9603    0.9574    0.9586       147
# weighted avg     0.9594    0.9592    0.9591       147

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9659863945578231
#               precision    recall  f1-score   support
#
#     negative     0.9367    1.0000    0.9673        74
#     positive     1.0000    0.9315    0.9645        73
#
#     accuracy                         0.9660       147
#    macro avg     0.9684    0.9658    0.9659       147
# weighted avg     0.9681    0.9660    0.9659       147
# Rodada: 1	Seed: 8968	Score: 0.9659863945578231
#               precision    recall  f1-score   support
#
#     negative     0.9487    0.9867    0.9673        75
#     positive     0.9855    0.9444    0.9645        72
#
#     accuracy                         0.9660       147
#    macro avg     0.9671    0.9656    0.9659       147
# weighted avg     0.9667    0.9660    0.9660       147
# Rodada: 2	Seed: 8442	Score: 0.9319727891156463
#               precision    recall  f1-score   support
#
#     negative     0.8831    0.9855    0.9315        69
#     positive     0.9857    0.8846    0.9324        78
#
#     accuracy                         0.9320       147
#    macro avg     0.9344    0.9351    0.9320       147
# weighted avg     0.9376    0.9320    0.9320       147
# Rodada: 3	Seed: 1729	Score: 0.9659863945578231
#               precision    recall  f1-score   support
#
#     negative     0.9506    0.9872    0.9686        78
#     positive     0.9848    0.9420    0.9630        69
#
#     accuracy                         0.9660       147
#    macro avg     0.9677    0.9646    0.9658       147
# weighted avg     0.9667    0.9660    0.9659       147
# Rodada: 4	Seed: 290	Score: 0.9319727891156463
#               precision    recall  f1-score   support
#
#     negative     0.8750    0.9844    0.9265        64
#     positive     0.9867    0.8916    0.9367        83
#
#     accuracy                         0.9320       147
#    macro avg     0.9308    0.9380    0.9316       147
# weighted avg     0.9380    0.9320    0.9323       147
# Rodada: 5	Seed: 490	Score: 0.9727891156462585
#               precision    recall  f1-score   support
#
#     negative     0.9674    0.9889    0.9780        90
#     positive     0.9818    0.9474    0.9643        57
#
#     accuracy                         0.9728       147
#    macro avg     0.9746    0.9681    0.9712       147
# weighted avg     0.9730    0.9728    0.9727       147
# Rodada: 6	Seed: 2128	Score: 0.9659863945578231
#               precision    recall  f1-score   support
#
#     negative     0.9512    0.9873    0.9689        79
#     positive     0.9846    0.9412    0.9624        68
#
#     accuracy                         0.9660       147
#    macro avg     0.9679    0.9643    0.9657       147
# weighted avg     0.9667    0.9660    0.9659       147
# Rodada: 7	Seed: 1167	Score: 0.9863945578231292
#               precision    recall  f1-score   support
#
#     negative     0.9722    1.0000    0.9859        70
#     positive     1.0000    0.9740    0.9868        77
#
#     accuracy                         0.9864       147
#    macro avg     0.9861    0.9870    0.9864       147
# weighted avg     0.9868    0.9864    0.9864       147
# Rodada: 8	Seed: 8900	Score: 0.9863945578231292
#               precision    recall  f1-score   support
#
#     negative     0.9714    1.0000    0.9855        68
#     positive     1.0000    0.9747    0.9872        79
#
#     accuracy                         0.9864       147
#    macro avg     0.9857    0.9873    0.9863       147
# weighted avg     0.9868    0.9864    0.9864       147
# Rodada: 9	Seed: 5078	Score: 0.9727891156462585
#               precision    recall  f1-score   support
#
#     negative     0.9518    1.0000    0.9753        79
#     positive     1.0000    0.9412    0.9697        68
#
#     accuracy                         0.9728       147
#    macro avg     0.9759    0.9706    0.9725       147
# weighted avg     0.9741    0.9728    0.9727       147
# Rodada: 10	Seed: 1359	Score: 0.9591836734693877
#               precision    recall  f1-score   support
#
#     negative     0.9259    1.0000    0.9615        75
#     positive     1.0000    0.9167    0.9565        72
#
#     accuracy                         0.9592       147
#    macro avg     0.9630    0.9583    0.9590       147
# weighted avg     0.9622    0.9592    0.9591       147
# Rodada: 11	Seed: 894	Score: 0.9863945578231292
#               precision    recall  f1-score   support
#
#     negative     0.9759    1.0000    0.9878        81
#     positive     1.0000    0.9697    0.9846        66
#
#     accuracy                         0.9864       147
#    macro avg     0.9880    0.9848    0.9862       147
# weighted avg     0.9867    0.9864    0.9864       147
# Rodada: 12	Seed: 7809	Score: 0.9659863945578231
#               precision    recall  f1-score   support
#
#     negative     0.9333    1.0000    0.9655        70
#     positive     1.0000    0.9351    0.9664        77
#
#     accuracy                         0.9660       147
#    macro avg     0.9667    0.9675    0.9660       147
# weighted avg     0.9683    0.9660    0.9660       147
# Rodada: 13	Seed: 6990	Score: 0.9659863945578231
#               precision    recall  f1-score   support
#
#     negative     0.9359    1.0000    0.9669        73
#     positive     1.0000    0.9324    0.9650        74
#
#     accuracy                         0.9660       147
#    macro avg     0.9679    0.9662    0.9660       147
# weighted avg     0.9682    0.9660    0.9660       147
# Rodada: 14	Seed: 3623	Score: 0.9523809523809523
#               precision    recall  f1-score   support
#
#     negative     0.9268    0.9870    0.9560        77
#     positive     0.9846    0.9143    0.9481        70
#
#     accuracy                         0.9524       147
#    macro avg     0.9557    0.9506    0.9521       147
# weighted avg     0.9543    0.9524    0.9522       147
# Rodada: 15	Seed: 5906	Score: 0.9523809523809523
#               precision    recall  f1-score   support
#
#     negative     0.9125    1.0000    0.9542        73
#     positive     1.0000    0.9054    0.9504        74
#
#     accuracy                         0.9524       147
#    macro avg     0.9563    0.9527    0.9523       147
# weighted avg     0.9565    0.9524    0.9523       147
# Rodada: 16	Seed: 1687	Score: 0.9523809523809523
#               precision    recall  f1-score   support
#
#     negative     0.9200    0.9857    0.9517        70
#     positive     0.9861    0.9221    0.9530        77
#
#     accuracy                         0.9524       147
#    macro avg     0.9531    0.9539    0.9524       147
# weighted avg     0.9546    0.9524    0.9524       147
# Rodada: 17	Seed: 7080	Score: 0.9251700680272109
#               precision    recall  f1-score   support
#
#     negative     0.8846    0.9718    0.9262        71
#     positive     0.9710    0.8816    0.9241        76
#
#     accuracy                         0.9252       147
#    macro avg     0.9278    0.9267    0.9252       147
# weighted avg     0.9293    0.9252    0.9251       147
# Rodada: 18	Seed: 5473	Score: 0.9863945578231292
#               precision    recall  f1-score   support
#
#     negative     0.9737    1.0000    0.9867        74
#     positive     1.0000    0.9726    0.9861        73
#
#     accuracy                         0.9864       147
#    macro avg     0.9868    0.9863    0.9864       147
# weighted avg     0.9868    0.9864    0.9864       147
# Rodada: 19	Seed: 7854	Score: 0.9591836734693877
#               precision    recall  f1-score   support
#
#     negative     0.9412    0.9877    0.9639        81
#     positive     0.9839    0.9242    0.9531        66
#
#     accuracy                         0.9592       147
#    macro avg     0.9625    0.9559    0.9585       147
# weighted avg     0.9603    0.9592    0.9590       147

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.931973       0.965986
# 1       0.938776       0.965986
# 2       0.904762       0.931973
# 3       0.959184       0.965986
# 4       0.925170       0.931973
# 5       0.972789       0.972789
# 6       0.965986       0.965986
# 7       0.938776       0.986395
# 8       0.959184       0.986395
# 9       0.938776       0.972789
# 10      0.918367       0.959184
# 11      0.986395       0.986395
# 12      0.965986       0.965986
# 13      0.959184       0.965986
# 14      0.925170       0.952381
# 15      0.931973       0.952381
# 16      0.904762       0.952381
# 17      0.945578       0.925170
# 18      0.952381       0.986395
# 19      0.959184       0.959184

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.944218       0.962585
# std        0.022247       0.017998
# min        0.904762       0.925170
# 25%        0.930272       0.952381
# 50%        0.942177       0.965986
# 75%        0.959184       0.972789
# max        0.986395       0.986395
