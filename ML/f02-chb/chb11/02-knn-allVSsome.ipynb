# %% [markdown]
# # KNN CHB11 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb11_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9916666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9918    0.9918    0.9918       122
#     positive     0.9915    0.9915    0.9915       118
#
#     accuracy                         0.9917       240
#    macro avg     0.9917    0.9917    0.9917       240
# weighted avg     0.9917    0.9917    0.9917       240
# Rodada: 1	Seed: 8968	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9695    1.0000    0.9845       127
#     positive     1.0000    0.9646    0.9820       113
#
#     accuracy                         0.9833       240
#    macro avg     0.9847    0.9823    0.9832       240
# weighted avg     0.9838    0.9833    0.9833       240
# Rodada: 2	Seed: 8442	Score: 0.9916666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9852    1.0000    0.9925       133
#     positive     1.0000    0.9813    0.9906       107
#
#     accuracy                         0.9917       240
#    macro avg     0.9926    0.9907    0.9916       240
# weighted avg     0.9918    0.9917    0.9917       240
# Rodada: 3	Seed: 1729	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9688    1.0000    0.9841       124
#     positive     1.0000    0.9655    0.9825       116
#
#     accuracy                         0.9833       240
#    macro avg     0.9844    0.9828    0.9833       240
# weighted avg     0.9839    0.9833    0.9833       240
# Rodada: 4	Seed: 290	Score: 0.9875
#               precision    recall  f1-score   support
#
#     negative     0.9848    0.9924    0.9886       131
#     positive     0.9907    0.9817    0.9862       109
#
#     accuracy                         0.9875       240
#    macro avg     0.9878    0.9870    0.9874       240
# weighted avg     0.9875    0.9875    0.9875       240
# Rodada: 5	Seed: 490	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9677    1.0000    0.9836       120
#     positive     1.0000    0.9667    0.9831       120
#
#     accuracy                         0.9833       240
#    macro avg     0.9839    0.9833    0.9833       240
# weighted avg     0.9839    0.9833    0.9833       240
# Rodada: 6	Seed: 2128	Score: 0.975
#               precision    recall  f1-score   support
#
#     negative     0.9542    1.0000    0.9766       125
#     positive     1.0000    0.9478    0.9732       115
#
#     accuracy                         0.9750       240
#    macro avg     0.9771    0.9739    0.9749       240
# weighted avg     0.9761    0.9750    0.9750       240
# Rodada: 7	Seed: 1167	Score: 0.9916666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9844    1.0000    0.9921       126
#     positive     1.0000    0.9825    0.9912       114
#
#     accuracy                         0.9917       240
#    macro avg     0.9922    0.9912    0.9916       240
# weighted avg     0.9918    0.9917    0.9917       240
# Rodada: 8	Seed: 8900	Score: 0.9916666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9841    1.0000    0.9920       124
#     positive     1.0000    0.9828    0.9913       116
#
#     accuracy                         0.9917       240
#    macro avg     0.9921    0.9914    0.9917       240
# weighted avg     0.9918    0.9917    0.9917       240
# Rodada: 9	Seed: 5078	Score: 0.9791666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9685    0.9919    0.9801       124
#     positive     0.9912    0.9655    0.9782       116
#
#     accuracy                         0.9792       240
#    macro avg     0.9798    0.9787    0.9791       240
# weighted avg     0.9794    0.9792    0.9792       240
# Rodada: 10	Seed: 1359	Score: 0.9791666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9580    1.0000    0.9785       114
#     positive     1.0000    0.9603    0.9798       126
#
#     accuracy                         0.9792       240
#    macro avg     0.9790    0.9802    0.9791       240
# weighted avg     0.9800    0.9792    0.9792       240
# Rodada: 11	Seed: 894	Score: 0.975
#               precision    recall  f1-score   support
#
#     negative     0.9565    1.0000    0.9778       132
#     positive     1.0000    0.9444    0.9714       108
#
#     accuracy                         0.9750       240
#    macro avg     0.9783    0.9722    0.9746       240
# weighted avg     0.9761    0.9750    0.9749       240
# Rodada: 12	Seed: 7809	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9754    0.9917    0.9835       120
#     positive     0.9915    0.9750    0.9832       120
#
#     accuracy                         0.9833       240
#    macro avg     0.9835    0.9833    0.9833       240
# weighted avg     0.9835    0.9833    0.9833       240
# Rodada: 13	Seed: 6990	Score: 0.9791666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9615    1.0000    0.9804       125
#     positive     1.0000    0.9565    0.9778       115
#
#     accuracy                         0.9792       240
#    macro avg     0.9808    0.9783    0.9791       240
# weighted avg     0.9800    0.9792    0.9791       240
# Rodada: 14	Seed: 3623	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9754    0.9917    0.9835       120
#     positive     0.9915    0.9750    0.9832       120
#
#     accuracy                         0.9833       240
#    macro avg     0.9835    0.9833    0.9833       240
# weighted avg     0.9835    0.9833    0.9833       240
# Rodada: 15	Seed: 5906	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9310    1.0000    0.9643       108
#     positive     1.0000    0.9394    0.9688       132
#
#     accuracy                         0.9667       240
#    macro avg     0.9655    0.9697    0.9665       240
# weighted avg     0.9690    0.9667    0.9667       240
# Rodada: 16	Seed: 1687	Score: 0.9791666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9615    1.0000    0.9804       125
#     positive     1.0000    0.9565    0.9778       115
#
#     accuracy                         0.9792       240
#    macro avg     0.9808    0.9783    0.9791       240
# weighted avg     0.9800    0.9792    0.9791       240
# Rodada: 17	Seed: 7080	Score: 0.975
#               precision    recall  f1-score   support
#
#     negative     0.9474    1.0000    0.9730       108
#     positive     1.0000    0.9545    0.9767       132
#
#     accuracy                         0.9750       240
#    macro avg     0.9737    0.9773    0.9749       240
# weighted avg     0.9763    0.9750    0.9750       240
# Rodada: 18	Seed: 5473	Score: 0.9875
#               precision    recall  f1-score   support
#
#     negative     0.9783    1.0000    0.9890       135
#     positive     1.0000    0.9714    0.9855       105
#
#     accuracy                         0.9875       240
#    macro avg     0.9891    0.9857    0.9873       240
# weighted avg     0.9878    0.9875    0.9875       240
# Rodada: 19	Seed: 7854	Score: 0.9958333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9919    1.0000    0.9959       122
#     positive     1.0000    0.9915    0.9957       118
#
#     accuracy                         0.9958       240
#    macro avg     0.9959    0.9958    0.9958       240
# weighted avg     0.9959    0.9958    0.9958       240

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9916666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9839    1.0000    0.9919       122
#     positive     1.0000    0.9831    0.9915       118
#
#     accuracy                         0.9917       240
#    macro avg     0.9919    0.9915    0.9917       240
# weighted avg     0.9918    0.9917    0.9917       240
# Rodada: 1	Seed: 8968	Score: 0.975
#               precision    recall  f1-score   support
#
#     negative     0.9690    0.9843    0.9766       127
#     positive     0.9820    0.9646    0.9732       113
#
#     accuracy                         0.9750       240
#    macro avg     0.9755    0.9744    0.9749       240
# weighted avg     0.9751    0.9750    0.9750       240
# Rodada: 2	Seed: 8442	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9708    1.0000    0.9852       133
#     positive     1.0000    0.9626    0.9810       107
#
#     accuracy                         0.9833       240
#    macro avg     0.9854    0.9813    0.9831       240
# weighted avg     0.9838    0.9833    0.9833       240
# Rodada: 3	Seed: 1729	Score: 0.9791666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9760    0.9839    0.9799       124
#     positive     0.9826    0.9741    0.9784       116
#
#     accuracy                         0.9792       240
#    macro avg     0.9793    0.9790    0.9791       240
# weighted avg     0.9792    0.9792    0.9792       240
# Rodada: 4	Seed: 290	Score: 0.9875
#               precision    recall  f1-score   support
#
#     negative     0.9848    0.9924    0.9886       131
#     positive     0.9907    0.9817    0.9862       109
#
#     accuracy                         0.9875       240
#    macro avg     0.9878    0.9870    0.9874       240
# weighted avg     0.9875    0.9875    0.9875       240
# Rodada: 5	Seed: 490	Score: 0.9583333333333334
#               precision    recall  f1-score   support
#
#     negative     0.9297    0.9917    0.9597       120
#     positive     0.9911    0.9250    0.9569       120
#
#     accuracy                         0.9583       240
#    macro avg     0.9604    0.9583    0.9583       240
# weighted avg     0.9604    0.9583    0.9583       240
# Rodada: 6	Seed: 2128	Score: 0.9708333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9538    0.9920    0.9725       125
#     positive     0.9909    0.9478    0.9689       115
#
#     accuracy                         0.9708       240
#    macro avg     0.9724    0.9699    0.9707       240
# weighted avg     0.9716    0.9708    0.9708       240
# Rodada: 7	Seed: 1167	Score: 0.975
#               precision    recall  f1-score   support
#
#     negative     0.9615    0.9921    0.9766       126
#     positive     0.9909    0.9561    0.9732       114
#
#     accuracy                         0.9750       240
#    macro avg     0.9762    0.9741    0.9749       240
# weighted avg     0.9755    0.9750    0.9750       240
# Rodada: 8	Seed: 8900	Score: 0.975
#               precision    recall  f1-score   support
#
#     negative     0.9538    1.0000    0.9764       124
#     positive     1.0000    0.9483    0.9735       116
#
#     accuracy                         0.9750       240
#    macro avg     0.9769    0.9741    0.9749       240
# weighted avg     0.9762    0.9750    0.9750       240
# Rodada: 9	Seed: 5078	Score: 0.975
#               precision    recall  f1-score   support
#
#     negative     0.9683    0.9839    0.9760       124
#     positive     0.9825    0.9655    0.9739       116
#
#     accuracy                         0.9750       240
#    macro avg     0.9754    0.9747    0.9750       240
# weighted avg     0.9751    0.9750    0.9750       240
# Rodada: 10	Seed: 1359	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9661    1.0000    0.9828       114
#     positive     1.0000    0.9683    0.9839       126
#
#     accuracy                         0.9833       240
#    macro avg     0.9831    0.9841    0.9833       240
# weighted avg     0.9839    0.9833    0.9833       240
# Rodada: 11	Seed: 894	Score: 0.975
#               precision    recall  f1-score   support
#
#     negative     0.9565    1.0000    0.9778       132
#     positive     1.0000    0.9444    0.9714       108
#
#     accuracy                         0.9750       240
#    macro avg     0.9783    0.9722    0.9746       240
# weighted avg     0.9761    0.9750    0.9749       240
# Rodada: 12	Seed: 7809	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9516    0.9833    0.9672       120
#     positive     0.9828    0.9500    0.9661       120
#
#     accuracy                         0.9667       240
#    macro avg     0.9672    0.9667    0.9667       240
# weighted avg     0.9672    0.9667    0.9667       240
# Rodada: 13	Seed: 6990	Score: 0.9708333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9538    0.9920    0.9725       125
#     positive     0.9909    0.9478    0.9689       115
#
#     accuracy                         0.9708       240
#    macro avg     0.9724    0.9699    0.9707       240
# weighted avg     0.9716    0.9708    0.9708       240
# Rodada: 14	Seed: 3623	Score: 0.9791666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9675    0.9917    0.9794       120
#     positive     0.9915    0.9667    0.9789       120
#
#     accuracy                         0.9792       240
#    macro avg     0.9795    0.9792    0.9792       240
# weighted avg     0.9795    0.9792    0.9792       240
# Rodada: 15	Seed: 5906	Score: 0.9375
#               precision    recall  f1-score   support
#
#     negative     0.9115    0.9537    0.9321       108
#     positive     0.9606    0.9242    0.9421       132
#
#     accuracy                         0.9375       240
#    macro avg     0.9361    0.9390    0.9371       240
# weighted avg     0.9385    0.9375    0.9376       240
# Rodada: 16	Seed: 1687	Score: 0.9791666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9615    1.0000    0.9804       125
#     positive     1.0000    0.9565    0.9778       115
#
#     accuracy                         0.9792       240
#    macro avg     0.9808    0.9783    0.9791       240
# weighted avg     0.9800    0.9792    0.9791       240
# Rodada: 17	Seed: 7080	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9310    1.0000    0.9643       108
#     positive     1.0000    0.9394    0.9688       132
#
#     accuracy                         0.9667       240
#    macro avg     0.9655    0.9697    0.9665       240
# weighted avg     0.9690    0.9667    0.9667       240
# Rodada: 18	Seed: 5473	Score: 0.9791666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9643    1.0000    0.9818       135
#     positive     1.0000    0.9524    0.9756       105
#
#     accuracy                         0.9792       240
#    macro avg     0.9821    0.9762    0.9787       240
# weighted avg     0.9799    0.9792    0.9791       240
# Rodada: 19	Seed: 7854	Score: 0.9791666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9680    0.9918    0.9798       122
#     positive     0.9913    0.9661    0.9785       118
#
#     accuracy                         0.9792       240
#    macro avg     0.9797    0.9790    0.9791       240
# weighted avg     0.9795    0.9792    0.9792       240

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.991667       0.991667
# 1       0.983333       0.975000
# 2       0.991667       0.983333
# 3       0.983333       0.979167
# 4       0.987500       0.987500
# 5       0.983333       0.958333
# 6       0.975000       0.970833
# 7       0.991667       0.975000
# 8       0.991667       0.975000
# 9       0.979167       0.975000
# 10      0.979167       0.983333
# 11      0.975000       0.975000
# 12      0.983333       0.966667
# 13      0.979167       0.970833
# 14      0.983333       0.979167
# 15      0.966667       0.937500
# 16      0.979167       0.979167
# 17      0.975000       0.966667
# 18      0.987500       0.979167
# 19      0.995833       0.979167

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.983125       0.974375
# std        0.007339       0.011493
# min        0.966667       0.937500
# 25%        0.979167       0.970833
# 50%        0.983333       0.975000
# 75%        0.988542       0.979167
# max        0.995833       0.991667
