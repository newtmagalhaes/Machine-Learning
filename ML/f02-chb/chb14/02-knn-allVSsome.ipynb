# %% [markdown]
# # KNN CHB14 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb14_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.8929    0.9259    0.9091        27
#     positive     0.8947    0.8500    0.8718        20
#
#     accuracy                         0.8936        47
#    macro avg     0.8938    0.8880    0.8904        47
# weighted avg     0.8937    0.8936    0.8932        47
# Rodada: 1	Seed: 8968	Score: 0.9148936170212766
#               precision    recall  f1-score   support
#
#     negative     0.9600    0.8889    0.9231        27
#     positive     0.8636    0.9500    0.9048        20
#
#     accuracy                         0.9149        47
#    macro avg     0.9118    0.9194    0.9139        47
# weighted avg     0.9190    0.9149    0.9153        47
# Rodada: 2	Seed: 8442	Score: 0.8085106382978723
#               precision    recall  f1-score   support
#
#     negative     0.8077    0.8400    0.8235        25
#     positive     0.8095    0.7727    0.7907        22
#
#     accuracy                         0.8085        47
#    macro avg     0.8086    0.8064    0.8071        47
# weighted avg     0.8085    0.8085    0.8082        47
# Rodada: 3	Seed: 1729	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.8750    0.9130    0.8936        23
#     positive     0.9130    0.8750    0.8936        24
#
#     accuracy                         0.8936        47
#    macro avg     0.8940    0.8940    0.8936        47
# weighted avg     0.8944    0.8936    0.8936        47
# Rodada: 4	Seed: 290	Score: 0.9148936170212766
#               precision    recall  f1-score   support
#
#     negative     0.9200    0.9200    0.9200        25
#     positive     0.9091    0.9091    0.9091        22
#
#     accuracy                         0.9149        47
#    macro avg     0.9145    0.9145    0.9145        47
# weighted avg     0.9149    0.9149    0.9149        47
# Rodada: 5	Seed: 490	Score: 0.8723404255319149
#               precision    recall  f1-score   support
#
#     negative     0.7692    1.0000    0.8696        20
#     positive     1.0000    0.7778    0.8750        27
#
#     accuracy                         0.8723        47
#    macro avg     0.8846    0.8889    0.8723        47
# weighted avg     0.9018    0.8723    0.8727        47
# Rodada: 6	Seed: 2128	Score: 0.8723404255319149
#               precision    recall  f1-score   support
#
#     negative     0.8519    0.9200    0.8846        25
#     positive     0.9000    0.8182    0.8571        22
#
#     accuracy                         0.8723        47
#    macro avg     0.8759    0.8691    0.8709        47
# weighted avg     0.8744    0.8723    0.8718        47
# Rodada: 7	Seed: 1167	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.9200    0.8846    0.9020        26
#     positive     0.8636    0.9048    0.8837        21
#
#     accuracy                         0.8936        47
#    macro avg     0.8918    0.8947    0.8928        47
# weighted avg     0.8948    0.8936    0.8938        47
# Rodada: 8	Seed: 8900	Score: 0.8723404255319149
#               precision    recall  f1-score   support
#
#     negative     0.8333    0.9091    0.8696        22
#     positive     0.9130    0.8400    0.8750        25
#
#     accuracy                         0.8723        47
#    macro avg     0.8732    0.8745    0.8723        47
# weighted avg     0.8757    0.8723    0.8725        47
# Rodada: 9	Seed: 5078	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.9583    0.8519    0.9020        27
#     positive     0.8261    0.9500    0.8837        20
#
#     accuracy                         0.8936        47
#    macro avg     0.8922    0.9009    0.8928        47
# weighted avg     0.9021    0.8936    0.8942        47
# Rodada: 10	Seed: 1359	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.8077    1.0000    0.8936        21
#     positive     1.0000    0.8077    0.8936        26
#
#     accuracy                         0.8936        47
#    macro avg     0.9038    0.9038    0.8936        47
# weighted avg     0.9141    0.8936    0.8936        47
# Rodada: 11	Seed: 894	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.8621    0.9615    0.9091        26
#     positive     0.9444    0.8095    0.8718        21
#
#     accuracy                         0.8936        47
#    macro avg     0.9033    0.8855    0.8904        47
# weighted avg     0.8989    0.8936    0.8924        47
# Rodada: 12	Seed: 7809	Score: 0.851063829787234
#               precision    recall  f1-score   support
#
#     negative     0.8438    0.9310    0.8852        29
#     positive     0.8667    0.7222    0.7879        18
#
#     accuracy                         0.8511        47
#    macro avg     0.8552    0.8266    0.8366        47
# weighted avg     0.8525    0.8511    0.8480        47
# Rodada: 13	Seed: 6990	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.8846    0.9200    0.9020        25
#     positive     0.9048    0.8636    0.8837        22
#
#     accuracy                         0.8936        47
#    macro avg     0.8947    0.8918    0.8928        47
# weighted avg     0.8940    0.8936    0.8934        47
# Rodada: 14	Seed: 3623	Score: 0.9148936170212766
#               precision    recall  f1-score   support
#
#     negative     0.8621    1.0000    0.9259        25
#     positive     1.0000    0.8182    0.9000        22
#
#     accuracy                         0.9149        47
#    macro avg     0.9310    0.9091    0.9130        47
# weighted avg     0.9266    0.9149    0.9138        47
# Rodada: 15	Seed: 5906	Score: 0.8723404255319149
#               precision    recall  f1-score   support
#
#     negative     0.7931    1.0000    0.8846        23
#     positive     1.0000    0.7500    0.8571        24
#
#     accuracy                         0.8723        47
#    macro avg     0.8966    0.8750    0.8709        47
# weighted avg     0.8988    0.8723    0.8706        47
# Rodada: 16	Seed: 1687	Score: 0.8723404255319149
#               precision    recall  f1-score   support
#
#     negative     0.7778    1.0000    0.8750        21
#     positive     1.0000    0.7692    0.8696        26
#
#     accuracy                         0.8723        47
#    macro avg     0.8889    0.8846    0.8723        47
# weighted avg     0.9007    0.8723    0.8720        47
# Rodada: 17	Seed: 7080	Score: 0.8723404255319149
#               precision    recall  f1-score   support
#
#     negative     0.8333    0.9091    0.8696        22
#     positive     0.9130    0.8400    0.8750        25
#
#     accuracy                         0.8723        47
#    macro avg     0.8732    0.8745    0.8723        47
# weighted avg     0.8757    0.8723    0.8725        47
# Rodada: 18	Seed: 5473	Score: 0.8723404255319149
#               precision    recall  f1-score   support
#
#     negative     0.8387    0.9630    0.8966        27
#     positive     0.9375    0.7500    0.8333        20
#
#     accuracy                         0.8723        47
#    macro avg     0.8881    0.8565    0.8649        47
# weighted avg     0.8807    0.8723    0.8697        47
# Rodada: 19	Seed: 7854	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.9375    0.9091    0.9231        33
#     positive     0.8000    0.8571    0.8276        14
#
#     accuracy                         0.8936        47
#    macro avg     0.8688    0.8831    0.8753        47
# weighted avg     0.8965    0.8936    0.8946        47

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9148936170212766
#               precision    recall  f1-score   support
#
#     negative     0.8966    0.9630    0.9286        27
#     positive     0.9444    0.8500    0.8947        20
#
#     accuracy                         0.9149        47
#    macro avg     0.9205    0.9065    0.9117        47
# weighted avg     0.9169    0.9149    0.9142        47
# Rodada: 1	Seed: 8968	Score: 0.9574468085106383
#               precision    recall  f1-score   support
#
#     negative     0.9630    0.9630    0.9630        27
#     positive     0.9500    0.9500    0.9500        20
#
#     accuracy                         0.9574        47
#    macro avg     0.9565    0.9565    0.9565        47
# weighted avg     0.9574    0.9574    0.9574        47
# Rodada: 2	Seed: 8442	Score: 0.8085106382978723
#               precision    recall  f1-score   support
#
#     negative     0.8077    0.8400    0.8235        25
#     positive     0.8095    0.7727    0.7907        22
#
#     accuracy                         0.8085        47
#    macro avg     0.8086    0.8064    0.8071        47
# weighted avg     0.8085    0.8085    0.8082        47
# Rodada: 3	Seed: 1729	Score: 0.9361702127659575
#               precision    recall  f1-score   support
#
#     negative     0.9167    0.9565    0.9362        23
#     positive     0.9565    0.9167    0.9362        24
#
#     accuracy                         0.9362        47
#    macro avg     0.9366    0.9366    0.9362        47
# weighted avg     0.9370    0.9362    0.9362        47
# Rodada: 4	Seed: 290	Score: 0.9361702127659575
#               precision    recall  f1-score   support
#
#     negative     0.9231    0.9600    0.9412        25
#     positive     0.9524    0.9091    0.9302        22
#
#     accuracy                         0.9362        47
#    macro avg     0.9377    0.9345    0.9357        47
# weighted avg     0.9368    0.9362    0.9361        47
# Rodada: 5	Seed: 490	Score: 0.8085106382978723
#               precision    recall  f1-score   support
#
#     negative     0.6897    1.0000    0.8163        20
#     positive     1.0000    0.6667    0.8000        27
#
#     accuracy                         0.8085        47
#    macro avg     0.8448    0.8333    0.8082        47
# weighted avg     0.8679    0.8085    0.8069        47
# Rodada: 6	Seed: 2128	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.8333    1.0000    0.9091        25
#     positive     1.0000    0.7727    0.8718        22
#
#     accuracy                         0.8936        47
#    macro avg     0.9167    0.8864    0.8904        47
# weighted avg     0.9113    0.8936    0.8916        47
# Rodada: 7	Seed: 1167	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.8889    0.9231    0.9057        26
#     positive     0.9000    0.8571    0.8780        21
#
#     accuracy                         0.8936        47
#    macro avg     0.8944    0.8901    0.8919        47
# weighted avg     0.8939    0.8936    0.8933        47
# Rodada: 8	Seed: 8900	Score: 0.9361702127659575
#               precision    recall  f1-score   support
#
#     negative     0.8800    1.0000    0.9362        22
#     positive     1.0000    0.8800    0.9362        25
#
#     accuracy                         0.9362        47
#    macro avg     0.9400    0.9400    0.9362        47
# weighted avg     0.9438    0.9362    0.9362        47
# Rodada: 9	Seed: 5078	Score: 0.8723404255319149
#               precision    recall  f1-score   support
#
#     negative     0.8621    0.9259    0.8929        27
#     positive     0.8889    0.8000    0.8421        20
#
#     accuracy                         0.8723        47
#    macro avg     0.8755    0.8630    0.8675        47
# weighted avg     0.8735    0.8723    0.8713        47
# Rodada: 10	Seed: 1359	Score: 0.7446808510638298
#               precision    recall  f1-score   support
#
#     negative     0.6667    0.8571    0.7500        21
#     positive     0.8500    0.6538    0.7391        26
#
#     accuracy                         0.7447        47
#    macro avg     0.7583    0.7555    0.7446        47
# weighted avg     0.7681    0.7447    0.7440        47
# Rodada: 11	Seed: 894	Score: 0.851063829787234
#               precision    recall  f1-score   support
#
#     negative     0.7879    1.0000    0.8814        26
#     positive     1.0000    0.6667    0.8000        21
#
#     accuracy                         0.8511        47
#    macro avg     0.8939    0.8333    0.8407        47
# weighted avg     0.8827    0.8511    0.8450        47
# Rodada: 12	Seed: 7809	Score: 0.7872340425531915
#               precision    recall  f1-score   support
#
#     negative     0.7879    0.8966    0.8387        29
#     positive     0.7857    0.6111    0.6875        18
#
#     accuracy                         0.7872        47
#    macro avg     0.7868    0.7538    0.7631        47
# weighted avg     0.7870    0.7872    0.7808        47
# Rodada: 13	Seed: 6990	Score: 0.8723404255319149
#               precision    recall  f1-score   support
#
#     negative     0.8276    0.9600    0.8889        25
#     positive     0.9444    0.7727    0.8500        22
#
#     accuracy                         0.8723        47
#    macro avg     0.8860    0.8664    0.8694        47
# weighted avg     0.8823    0.8723    0.8707        47
# Rodada: 14	Seed: 3623	Score: 0.8723404255319149
#               precision    recall  f1-score   support
#
#     negative     0.8065    1.0000    0.8929        25
#     positive     1.0000    0.7273    0.8421        22
#
#     accuracy                         0.8723        47
#    macro avg     0.9032    0.8636    0.8675        47
# weighted avg     0.8970    0.8723    0.8691        47
# Rodada: 15	Seed: 5906	Score: 0.851063829787234
#               precision    recall  f1-score   support
#
#     negative     0.7857    0.9565    0.8627        23
#     positive     0.9474    0.7500    0.8372        24
#
#     accuracy                         0.8511        47
#    macro avg     0.8665    0.8533    0.8500        47
# weighted avg     0.8683    0.8511    0.8497        47
# Rodada: 16	Seed: 1687	Score: 0.851063829787234
#               precision    recall  f1-score   support
#
#     negative     0.7692    0.9524    0.8511        21
#     positive     0.9524    0.7692    0.8511        26
#
#     accuracy                         0.8511        47
#    macro avg     0.8608    0.8608    0.8511        47
# weighted avg     0.8705    0.8511    0.8511        47
# Rodada: 17	Seed: 7080	Score: 0.8936170212765957
#               precision    recall  f1-score   support
#
#     negative     0.8696    0.9091    0.8889        22
#     positive     0.9167    0.8800    0.8980        25
#
#     accuracy                         0.8936        47
#    macro avg     0.8931    0.8945    0.8934        47
# weighted avg     0.8946    0.8936    0.8937        47
# Rodada: 18	Seed: 5473	Score: 0.851063829787234
#               precision    recall  f1-score   support
#
#     negative     0.7941    1.0000    0.8852        27
#     positive     1.0000    0.6500    0.7879        20
#
#     accuracy                         0.8511        47
#    macro avg     0.8971    0.8250    0.8366        47
# weighted avg     0.8817    0.8511    0.8438        47
# Rodada: 19	Seed: 7854	Score: 0.851063829787234
#               precision    recall  f1-score   support
#
#     negative     0.9062    0.8788    0.8923        33
#     positive     0.7333    0.7857    0.7586        14
#
#     accuracy                         0.8511        47
#    macro avg     0.8198    0.8323    0.8255        47
# weighted avg     0.8547    0.8511    0.8525        47

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.893617       0.914894
# 1       0.914894       0.957447
# 2       0.808511       0.808511
# 3       0.893617       0.936170
# 4       0.914894       0.936170
# 5       0.872340       0.808511
# 6       0.872340       0.893617
# 7       0.893617       0.893617
# 8       0.872340       0.936170
# 9       0.893617       0.872340
# 10      0.893617       0.744681
# 11      0.893617       0.851064
# 12      0.851064       0.787234
# 13      0.893617       0.872340
# 14      0.914894       0.872340
# 15      0.872340       0.851064
# 16      0.872340       0.851064
# 17      0.872340       0.893617
# 18      0.872340       0.851064
# 19      0.893617       0.851064

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.882979       0.869149
# std        0.024406       0.054475
# min        0.808511       0.744681
# 25%        0.872340       0.851064
# 50%        0.893617       0.872340
# 75%        0.893617       0.898936
# max        0.914894       0.957447
