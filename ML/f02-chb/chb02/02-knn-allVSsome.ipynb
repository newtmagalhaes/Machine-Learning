# %% [markdown]
# # KNN CHB02 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb02_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9411764705882353
#               precision    recall  f1-score   support
#
#     negative     0.9355    0.9667    0.9508        30
#     positive     0.9500    0.9048    0.9268        21
#
#     accuracy                         0.9412        51
#    macro avg     0.9427    0.9357    0.9388        51
# weighted avg     0.9415    0.9412    0.9409        51
# Rodada: 1	Seed: 8968	Score: 0.9803921568627451
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9697    0.9846        33
#     positive     0.9474    1.0000    0.9730        18
#
#     accuracy                         0.9804        51
#    macro avg     0.9737    0.9848    0.9788        51
# weighted avg     0.9814    0.9804    0.9805        51
# Rodada: 2	Seed: 8442	Score: 0.9215686274509803
#               precision    recall  f1-score   support
#
#     negative     0.8621    1.0000    0.9259        25
#     positive     1.0000    0.8462    0.9167        26
#
#     accuracy                         0.9216        51
#    macro avg     0.9310    0.9231    0.9213        51
# weighted avg     0.9324    0.9216    0.9212        51
# Rodada: 3	Seed: 1729	Score: 0.9215686274509803
#               precision    recall  f1-score   support
#
#     negative     0.8667    1.0000    0.9286        26
#     positive     1.0000    0.8400    0.9130        25
#
#     accuracy                         0.9216        51
#    macro avg     0.9333    0.9200    0.9208        51
# weighted avg     0.9320    0.9216    0.9210        51
# Rodada: 4	Seed: 290	Score: 0.9607843137254902
#               precision    recall  f1-score   support
#
#     negative     0.9355    1.0000    0.9667        29
#     positive     1.0000    0.9091    0.9524        22
#
#     accuracy                         0.9608        51
#    macro avg     0.9677    0.9545    0.9595        51
# weighted avg     0.9633    0.9608    0.9605        51
# Rodada: 5	Seed: 490	Score: 0.9411764705882353
#               precision    recall  f1-score   support
#
#     negative     0.8750    1.0000    0.9333        21
#     positive     1.0000    0.9000    0.9474        30
#
#     accuracy                         0.9412        51
#    macro avg     0.9375    0.9500    0.9404        51
# weighted avg     0.9485    0.9412    0.9416        51
# Rodada: 6	Seed: 2128	Score: 0.9607843137254902
#               precision    recall  f1-score   support
#
#     negative     0.9310    1.0000    0.9643        27
#     positive     1.0000    0.9167    0.9565        24
#
#     accuracy                         0.9608        51
#    macro avg     0.9655    0.9583    0.9604        51
# weighted avg     0.9635    0.9608    0.9606        51
# Rodada: 7	Seed: 1167	Score: 0.9215686274509803
#               precision    recall  f1-score   support
#
#     negative     0.8400    1.0000    0.9130        21
#     positive     1.0000    0.8667    0.9286        30
#
#     accuracy                         0.9216        51
#    macro avg     0.9200    0.9333    0.9208        51
# weighted avg     0.9341    0.9216    0.9222        51
# Rodada: 8	Seed: 8900	Score: 0.9019607843137255
#               precision    recall  f1-score   support
#
#     negative     0.8788    0.9667    0.9206        30
#     positive     0.9444    0.8095    0.8718        21
#
#     accuracy                         0.9020        51
#    macro avg     0.9116    0.8881    0.8962        51
# weighted avg     0.9058    0.9020    0.9005        51
# Rodada: 9	Seed: 5078	Score: 0.9411764705882353
#               precision    recall  f1-score   support
#
#     negative     0.9032    1.0000    0.9492        28
#     positive     1.0000    0.8696    0.9302        23
#
#     accuracy                         0.9412        51
#    macro avg     0.9516    0.9348    0.9397        51
# weighted avg     0.9469    0.9412    0.9406        51
# Rodada: 10	Seed: 1359	Score: 0.8627450980392157
#               precision    recall  f1-score   support
#
#     negative     0.7742    1.0000    0.8727        24
#     positive     1.0000    0.7407    0.8511        27
#
#     accuracy                         0.8627        51
#    macro avg     0.8871    0.8704    0.8619        51
# weighted avg     0.8937    0.8627    0.8613        51
# Rodada: 11	Seed: 894	Score: 0.9215686274509803
#               precision    recall  f1-score   support
#
#     negative     0.8750    1.0000    0.9333        28
#     positive     1.0000    0.8261    0.9048        23
#
#     accuracy                         0.9216        51
#    macro avg     0.9375    0.9130    0.9190        51
# weighted avg     0.9314    0.9216    0.9204        51
# Rodada: 12	Seed: 7809	Score: 0.9803921568627451
#               precision    recall  f1-score   support
#
#     negative     0.9667    1.0000    0.9831        29
#     positive     1.0000    0.9545    0.9767        22
#
#     accuracy                         0.9804        51
#    macro avg     0.9833    0.9773    0.9799        51
# weighted avg     0.9810    0.9804    0.9803        51
# Rodada: 13	Seed: 6990	Score: 0.9411764705882353
#               precision    recall  f1-score   support
#
#     negative     0.8966    1.0000    0.9455        26
#     positive     1.0000    0.8800    0.9362        25
#
#     accuracy                         0.9412        51
#    macro avg     0.9483    0.9400    0.9408        51
# weighted avg     0.9473    0.9412    0.9409        51
# Rodada: 14	Seed: 3623	Score: 0.9607843137254902
#               precision    recall  f1-score   support
#
#     negative     0.9333    1.0000    0.9655        28
#     positive     1.0000    0.9130    0.9545        23
#
#     accuracy                         0.9608        51
#    macro avg     0.9667    0.9565    0.9600        51
# weighted avg     0.9634    0.9608    0.9606        51
# Rodada: 15	Seed: 5906	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        23
#     positive     1.0000    1.0000    1.0000        28
#
#     accuracy                         1.0000        51
#    macro avg     1.0000    1.0000    1.0000        51
# weighted avg     1.0000    1.0000    1.0000        51
# Rodada: 16	Seed: 1687	Score: 0.9411764705882353
#               precision    recall  f1-score   support
#
#     negative     0.8800    1.0000    0.9362        22
#     positive     1.0000    0.8966    0.9455        29
#
#     accuracy                         0.9412        51
#    macro avg     0.9400    0.9483    0.9408        51
# weighted avg     0.9482    0.9412    0.9414        51
# Rodada: 17	Seed: 7080	Score: 0.9019607843137255
#               precision    recall  f1-score   support
#
#     negative     0.8571    0.9600    0.9057        25
#     positive     0.9565    0.8462    0.8980        26
#
#     accuracy                         0.9020        51
#    macro avg     0.9068    0.9031    0.9018        51
# weighted avg     0.9078    0.9020    0.9017        51
# Rodada: 18	Seed: 5473	Score: 0.9411764705882353
#               precision    recall  f1-score   support
#
#     negative     0.9032    1.0000    0.9492        28
#     positive     1.0000    0.8696    0.9302        23
#
#     accuracy                         0.9412        51
#    macro avg     0.9516    0.9348    0.9397        51
# weighted avg     0.9469    0.9412    0.9406        51
# Rodada: 19	Seed: 7854	Score: 0.9215686274509803
#               precision    recall  f1-score   support
#
#     negative     0.9189    0.9714    0.9444        35
#     positive     0.9286    0.8125    0.8667        16
#
#     accuracy                         0.9216        51
#    macro avg     0.9237    0.8920    0.9056        51
# weighted avg     0.9219    0.9216    0.9200        51

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9607843137254902
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9333    0.9655        30
#     positive     0.9130    1.0000    0.9545        21
#
#     accuracy                         0.9608        51
#    macro avg     0.9565    0.9667    0.9600        51
# weighted avg     0.9642    0.9608    0.9610        51
# Rodada: 1	Seed: 8968	Score: 0.9607843137254902
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9394    0.9688        33
#     positive     0.9000    1.0000    0.9474        18
#
#     accuracy                         0.9608        51
#    macro avg     0.9500    0.9697    0.9581        51
# weighted avg     0.9647    0.9608    0.9612        51
# Rodada: 2	Seed: 8442	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        25
#     positive     1.0000    1.0000    1.0000        26
#
#     accuracy                         1.0000        51
#    macro avg     1.0000    1.0000    1.0000        51
# weighted avg     1.0000    1.0000    1.0000        51
# Rodada: 3	Seed: 1729	Score: 0.9019607843137255
#               precision    recall  f1-score   support
#
#     negative     0.8621    0.9615    0.9091        26
#     positive     0.9545    0.8400    0.8936        25
#
#     accuracy                         0.9020        51
#    macro avg     0.9083    0.9008    0.9014        51
# weighted avg     0.9074    0.9020    0.9015        51
# Rodada: 4	Seed: 290	Score: 0.9607843137254902
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9310    0.9643        29
#     positive     0.9167    1.0000    0.9565        22
#
#     accuracy                         0.9608        51
#    macro avg     0.9583    0.9655    0.9604        51
# weighted avg     0.9641    0.9608    0.9609        51
# Rodada: 5	Seed: 490	Score: 0.9607843137254902
#               precision    recall  f1-score   support
#
#     negative     0.9130    1.0000    0.9545        21
#     positive     1.0000    0.9333    0.9655        30
#
#     accuracy                         0.9608        51
#    macro avg     0.9565    0.9667    0.9600        51
# weighted avg     0.9642    0.9608    0.9610        51
# Rodada: 6	Seed: 2128	Score: 0.9607843137254902
#               precision    recall  f1-score   support
#
#     negative     0.9310    1.0000    0.9643        27
#     positive     1.0000    0.9167    0.9565        24
#
#     accuracy                         0.9608        51
#    macro avg     0.9655    0.9583    0.9604        51
# weighted avg     0.9635    0.9608    0.9606        51
# Rodada: 7	Seed: 1167	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        21
#     positive     1.0000    1.0000    1.0000        30
#
#     accuracy                         1.0000        51
#    macro avg     1.0000    1.0000    1.0000        51
# weighted avg     1.0000    1.0000    1.0000        51
# Rodada: 8	Seed: 8900	Score: 0.9019607843137255
#               precision    recall  f1-score   support
#
#     negative     0.9032    0.9333    0.9180        30
#     positive     0.9000    0.8571    0.8780        21
#
#     accuracy                         0.9020        51
#    macro avg     0.9016    0.8952    0.8980        51
# weighted avg     0.9019    0.9020    0.9016        51
# Rodada: 9	Seed: 5078	Score: 0.9803921568627451
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9643    0.9818        28
#     positive     0.9583    1.0000    0.9787        23
#
#     accuracy                         0.9804        51
#    macro avg     0.9792    0.9821    0.9803        51
# weighted avg     0.9812    0.9804    0.9804        51
# Rodada: 10	Seed: 1359	Score: 0.9607843137254902
#               precision    recall  f1-score   support
#
#     negative     0.9231    1.0000    0.9600        24
#     positive     1.0000    0.9259    0.9615        27
#
#     accuracy                         0.9608        51
#    macro avg     0.9615    0.9630    0.9608        51
# weighted avg     0.9638    0.9608    0.9608        51
# Rodada: 11	Seed: 894	Score: 0.9607843137254902
#               precision    recall  f1-score   support
#
#     negative     0.9333    1.0000    0.9655        28
#     positive     1.0000    0.9130    0.9545        23
#
#     accuracy                         0.9608        51
#    macro avg     0.9667    0.9565    0.9600        51
# weighted avg     0.9634    0.9608    0.9606        51
# Rodada: 12	Seed: 7809	Score: 0.9803921568627451
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9655    0.9825        29
#     positive     0.9565    1.0000    0.9778        22
#
#     accuracy                         0.9804        51
#    macro avg     0.9783    0.9828    0.9801        51
# weighted avg     0.9812    0.9804    0.9804        51
# Rodada: 13	Seed: 6990	Score: 0.9411764705882353
#               precision    recall  f1-score   support
#
#     negative     0.9259    0.9615    0.9434        26
#     positive     0.9583    0.9200    0.9388        25
#
#     accuracy                         0.9412        51
#    macro avg     0.9421    0.9408    0.9411        51
# weighted avg     0.9418    0.9412    0.9411        51
# Rodada: 14	Seed: 3623	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        28
#     positive     1.0000    1.0000    1.0000        23
#
#     accuracy                         1.0000        51
#    macro avg     1.0000    1.0000    1.0000        51
# weighted avg     1.0000    1.0000    1.0000        51
# Rodada: 15	Seed: 5906	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        23
#     positive     1.0000    1.0000    1.0000        28
#
#     accuracy                         1.0000        51
#    macro avg     1.0000    1.0000    1.0000        51
# weighted avg     1.0000    1.0000    1.0000        51
# Rodada: 16	Seed: 1687	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        22
#     positive     1.0000    1.0000    1.0000        29
#
#     accuracy                         1.0000        51
#    macro avg     1.0000    1.0000    1.0000        51
# weighted avg     1.0000    1.0000    1.0000        51
# Rodada: 17	Seed: 7080	Score: 0.9411764705882353
#               precision    recall  f1-score   support
#
#     negative     0.9231    0.9600    0.9412        25
#     positive     0.9600    0.9231    0.9412        26
#
#     accuracy                         0.9412        51
#    macro avg     0.9415    0.9415    0.9412        51
# weighted avg     0.9419    0.9412    0.9412        51
# Rodada: 18	Seed: 5473	Score: 0.9411764705882353
#               precision    recall  f1-score   support
#
#     negative     0.9310    0.9643    0.9474        28
#     positive     0.9545    0.9130    0.9333        23
#
#     accuracy                         0.9412        51
#    macro avg     0.9428    0.9387    0.9404        51
# weighted avg     0.9416    0.9412    0.9410        51
# Rodada: 19	Seed: 7854	Score: 0.9803921568627451
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9714    0.9855        35
#     positive     0.9412    1.0000    0.9697        16
#
#     accuracy                         0.9804        51
#    macro avg     0.9706    0.9857    0.9776        51
# weighted avg     0.9815    0.9804    0.9805        51

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.941176       0.960784
# 1       0.980392       0.960784
# 2       0.921569       1.000000
# 3       0.921569       0.901961
# 4       0.960784       0.960784
# 5       0.941176       0.960784
# 6       0.960784       0.960784
# 7       0.921569       1.000000
# 8       0.901961       0.901961
# 9       0.941176       0.980392
# 10      0.862745       0.960784
# 11      0.921569       0.960784
# 12      0.980392       0.980392
# 13      0.941176       0.941176
# 14      0.960784       1.000000
# 15      1.000000       1.000000
# 16      0.941176       1.000000
# 17      0.901961       0.941176
# 18      0.941176       0.941176
# 19      0.921569       0.980392

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.938235       0.964706
# std        0.031344       0.029566
# min        0.862745       0.901961
# 25%        0.921569       0.955882
# 50%        0.941176       0.960784
# 75%        0.960784       0.985294
# max        1.000000       1.000000
