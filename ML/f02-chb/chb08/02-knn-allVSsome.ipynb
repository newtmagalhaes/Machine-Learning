# %% [markdown]
# # KNN CHB08 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb08_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9304029304029304
#               precision    recall  f1-score   support
#
#     negative     0.9014    0.9624    0.9309       133
#     positive     0.9618    0.9000    0.9299       140
#
#     accuracy                         0.9304       273
#    macro avg     0.9316    0.9312    0.9304       273
# weighted avg     0.9324    0.9304    0.9304       273
# Rodada: 1	Seed: 8968	Score: 0.9560439560439561
#               precision    recall  f1-score   support
#
#     negative     0.9329    0.9858    0.9586       141
#     positive     0.9839    0.9242    0.9531       132
#
#     accuracy                         0.9560       273
#    macro avg     0.9584    0.9550    0.9559       273
# weighted avg     0.9575    0.9560    0.9560       273
# Rodada: 2	Seed: 8442	Score: 0.945054945054945
#               precision    recall  f1-score   support
#
#     negative     0.9189    0.9784    0.9477       139
#     positive     0.9760    0.9104    0.9421       134
#
#     accuracy                         0.9451       273
#    macro avg     0.9475    0.9444    0.9449       273
# weighted avg     0.9469    0.9451    0.9450       273
# Rodada: 3	Seed: 1729	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     0.8652    0.9457    0.9037       129
#     positive     0.9470    0.8681    0.9058       144
#
#     accuracy                         0.9048       273
#    macro avg     0.9061    0.9069    0.9048       273
# weighted avg     0.9084    0.9048    0.9048       273
# Rodada: 4	Seed: 290	Score: 0.9230769230769231
#               precision    recall  f1-score   support
#
#     negative     0.8968    0.9653    0.9298       144
#     positive     0.9576    0.8760    0.9150       129
#
#     accuracy                         0.9231       273
#    macro avg     0.9272    0.9206    0.9224       273
# weighted avg     0.9255    0.9231    0.9228       273
# Rodada: 5	Seed: 490	Score: 0.9267399267399268
#               precision    recall  f1-score   support
#
#     negative     0.9007    0.9645    0.9315       141
#     positive     0.9590    0.8864    0.9213       132
#
#     accuracy                         0.9267       273
#    macro avg     0.9298    0.9255    0.9264       273
# weighted avg     0.9289    0.9267    0.9266       273
# Rodada: 6	Seed: 2128	Score: 0.9267399267399268
#               precision    recall  f1-score   support
#
#     negative     0.9013    0.9648    0.9320       142
#     positive     0.9587    0.8855    0.9206       131
#
#     accuracy                         0.9267       273
#    macro avg     0.9300    0.9251    0.9263       273
# weighted avg     0.9288    0.9267    0.9265       273
# Rodada: 7	Seed: 1167	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     0.8993    0.9124    0.9058       137
#     positive     0.9104    0.8971    0.9037       136
#
#     accuracy                         0.9048       273
#    macro avg     0.9049    0.9047    0.9048       273
# weighted avg     0.9048    0.9048    0.9048       273
# Rodada: 8	Seed: 8900	Score: 0.9194139194139194
#               precision    recall  f1-score   support
#
#     negative     0.8867    0.9638    0.9236       138
#     positive     0.9593    0.8741    0.9147       135
#
#     accuracy                         0.9194       273
#    macro avg     0.9230    0.9189    0.9192       273
# weighted avg     0.9226    0.9194    0.9192       273
# Rodada: 9	Seed: 5078	Score: 0.9304029304029304
#               precision    recall  f1-score   support
#
#     negative     0.9172    0.9500    0.9333       140
#     positive     0.9453    0.9098    0.9272       133
#
#     accuracy                         0.9304       273
#    macro avg     0.9313    0.9299    0.9303       273
# weighted avg     0.9309    0.9304    0.9303       273
# Rodada: 10	Seed: 1359	Score: 0.9230769230769231
#               precision    recall  f1-score   support
#
#     negative     0.9021    0.9485    0.9247       136
#     positive     0.9462    0.8978    0.9213       137
#
#     accuracy                         0.9231       273
#    macro avg     0.9241    0.9232    0.9230       273
# weighted avg     0.9242    0.9231    0.9230       273
# Rodada: 11	Seed: 894	Score: 0.9304029304029304
#               precision    recall  f1-score   support
#
#     negative     0.9020    0.9718    0.9356       142
#     positive     0.9667    0.8855    0.9243       131
#
#     accuracy                         0.9304       273
#    macro avg     0.9343    0.9287    0.9299       273
# weighted avg     0.9330    0.9304    0.9302       273
# Rodada: 12	Seed: 7809	Score: 0.9304029304029304
#               precision    recall  f1-score   support
#
#     negative     0.9214    0.9416    0.9314       137
#     positive     0.9398    0.9191    0.9294       136
#
#     accuracy                         0.9304       273
#    macro avg     0.9306    0.9304    0.9304       273
# weighted avg     0.9306    0.9304    0.9304       273
# Rodada: 13	Seed: 6990	Score: 0.9010989010989011
#               precision    recall  f1-score   support
#
#     negative     0.8497    0.9701    0.9059       134
#     positive     0.9667    0.8345    0.8958       139
#
#     accuracy                         0.9011       273
#    macro avg     0.9082    0.9023    0.9008       273
# weighted avg     0.9092    0.9011    0.9007       273
# Rodada: 14	Seed: 3623	Score: 0.9523809523809523
#               precision    recall  f1-score   support
#
#     negative     0.9398    0.9615    0.9506       130
#     positive     0.9643    0.9441    0.9541       143
#
#     accuracy                         0.9524       273
#    macro avg     0.9521    0.9528    0.9523       273
# weighted avg     0.9526    0.9524    0.9524       273
# Rodada: 15	Seed: 5906	Score: 0.9304029304029304
#               precision    recall  f1-score   support
#
#     negative     0.8958    0.9699    0.9314       133
#     positive     0.9690    0.8929    0.9294       140
#
#     accuracy                         0.9304       273
#    macro avg     0.9324    0.9314    0.9304       273
# weighted avg     0.9334    0.9304    0.9304       273
# Rodada: 16	Seed: 1687	Score: 0.9340659340659341
#               precision    recall  f1-score   support
#
#     negative     0.9116    0.9640    0.9371       139
#     positive     0.9603    0.9030    0.9308       134
#
#     accuracy                         0.9341       273
#    macro avg     0.9359    0.9335    0.9339       273
# weighted avg     0.9355    0.9341    0.9340       273
# Rodada: 17	Seed: 7080	Score: 0.9230769230769231
#               precision    recall  f1-score   support
#
#     negative     0.9143    0.9343    0.9242       137
#     positive     0.9323    0.9118    0.9219       136
#
#     accuracy                         0.9231       273
#    macro avg     0.9233    0.9230    0.9231       273
# weighted avg     0.9233    0.9231    0.9231       273
# Rodada: 18	Seed: 5473	Score: 0.9304029304029304
#               precision    recall  f1-score   support
#
#     negative     0.9267    0.9456    0.9360       147
#     positive     0.9350    0.9127    0.9237       126
#
#     accuracy                         0.9304       273
#    macro avg     0.9308    0.9291    0.9299       273
# weighted avg     0.9305    0.9304    0.9303       273
# Rodada: 19	Seed: 7854	Score: 0.9230769230769231
#               precision    recall  f1-score   support
#
#     negative     0.9214    0.9281    0.9247       139
#     positive     0.9248    0.9179    0.9213       134
#
#     accuracy                         0.9231       273
#    macro avg     0.9231    0.9230    0.9230       273
# weighted avg     0.9231    0.9231    0.9231       273

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9120879120879121
#               precision    recall  f1-score   support
#
#     negative     0.8921    0.9323    0.9118       133
#     positive     0.9328    0.8929    0.9124       140
#
#     accuracy                         0.9121       273
#    macro avg     0.9125    0.9126    0.9121       273
# weighted avg     0.9130    0.9121    0.9121       273
# Rodada: 1	Seed: 8968	Score: 0.9487179487179487
#               precision    recall  f1-score   support
#
#     negative     0.9320    0.9716    0.9514       141
#     positive     0.9683    0.9242    0.9457       132
#
#     accuracy                         0.9487       273
#    macro avg     0.9501    0.9479    0.9486       273
# weighted avg     0.9495    0.9487    0.9487       273
# Rodada: 2	Seed: 8442	Score: 0.9340659340659341
#               precision    recall  f1-score   support
#
#     negative     0.9172    0.9568    0.9366       139
#     positive     0.9531    0.9104    0.9313       134
#
#     accuracy                         0.9341       273
#    macro avg     0.9352    0.9336    0.9340       273
# weighted avg     0.9349    0.9341    0.9340       273
# Rodada: 3	Seed: 1729	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     0.8652    0.9457    0.9037       129
#     positive     0.9470    0.8681    0.9058       144
#
#     accuracy                         0.9048       273
#    macro avg     0.9061    0.9069    0.9048       273
# weighted avg     0.9084    0.9048    0.9048       273
# Rodada: 4	Seed: 290	Score: 0.9230769230769231
#               precision    recall  f1-score   support
#
#     negative     0.9020    0.9583    0.9293       144
#     positive     0.9500    0.8837    0.9157       129
#
#     accuracy                         0.9231       273
#    macro avg     0.9260    0.9210    0.9225       273
# weighted avg     0.9247    0.9231    0.9229       273
# Rodada: 5	Seed: 490	Score: 0.9194139194139194
#               precision    recall  f1-score   support
#
#     negative     0.9048    0.9433    0.9236       141
#     positive     0.9365    0.8939    0.9147       132
#
#     accuracy                         0.9194       273
#    macro avg     0.9206    0.9186    0.9192       273
# weighted avg     0.9201    0.9194    0.9193       273
# Rodada: 6	Seed: 2128	Score: 0.9084249084249084
#               precision    recall  f1-score   support
#
#     negative     0.8980    0.9296    0.9135       142
#     positive     0.9206    0.8855    0.9027       131
#
#     accuracy                         0.9084       273
#    macro avg     0.9093    0.9075    0.9081       273
# weighted avg     0.9088    0.9084    0.9083       273
# Rodada: 7	Seed: 1167	Score: 0.8791208791208791
#               precision    recall  f1-score   support
#
#     negative     0.8562    0.9124    0.8834       137
#     positive     0.9055    0.8456    0.8745       136
#
#     accuracy                         0.8791       273
#    macro avg     0.8808    0.8790    0.8790       273
# weighted avg     0.8807    0.8791    0.8790       273
# Rodada: 8	Seed: 8900	Score: 0.9304029304029304
#               precision    recall  f1-score   support
#
#     negative     0.9103    0.9565    0.9329       138
#     positive     0.9531    0.9037    0.9278       135
#
#     accuracy                         0.9304       273
#    macro avg     0.9317    0.9301    0.9303       273
# weighted avg     0.9315    0.9304    0.9303       273
# Rodada: 9	Seed: 5078	Score: 0.9010989010989011
#               precision    recall  f1-score   support
#
#     negative     0.9065    0.9000    0.9032       140
#     positive     0.8955    0.9023    0.8989       133
#
#     accuracy                         0.9011       273
#    macro avg     0.9010    0.9011    0.9011       273
# weighted avg     0.9011    0.9011    0.9011       273
# Rodada: 10	Seed: 1359	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     0.8986    0.9118    0.9051       136
#     positive     0.9111    0.8978    0.9044       137
#
#     accuracy                         0.9048       273
#    macro avg     0.9048    0.9048    0.9048       273
# weighted avg     0.9049    0.9048    0.9048       273
# Rodada: 11	Seed: 894	Score: 0.9304029304029304
#               precision    recall  f1-score   support
#
#     negative     0.9128    0.9577    0.9347       142
#     positive     0.9516    0.9008    0.9255       131
#
#     accuracy                         0.9304       273
#    macro avg     0.9322    0.9293    0.9301       273
# weighted avg     0.9314    0.9304    0.9303       273
# Rodada: 12	Seed: 7809	Score: 0.945054945054945
#               precision    recall  f1-score   support
#
#     negative     0.9357    0.9562    0.9458       137
#     positive     0.9549    0.9338    0.9442       136
#
#     accuracy                         0.9451       273
#    macro avg     0.9453    0.9450    0.9450       273
# weighted avg     0.9453    0.9451    0.9450       273
# Rodada: 13	Seed: 6990	Score: 0.8901098901098901
#               precision    recall  f1-score   support
#
#     negative     0.8514    0.9403    0.8936       134
#     positive     0.9360    0.8417    0.8864       139
#
#     accuracy                         0.8901       273
#    macro avg     0.8937    0.8910    0.8900       273
# weighted avg     0.8945    0.8901    0.8899       273
# Rodada: 14	Seed: 3623	Score: 0.9230769230769231
#               precision    recall  f1-score   support
#
#     negative     0.8921    0.9538    0.9219       130
#     positive     0.9552    0.8951    0.9242       143
#
#     accuracy                         0.9231       273
#    macro avg     0.9237    0.9245    0.9231       273
# weighted avg     0.9252    0.9231    0.9231       273
# Rodada: 15	Seed: 5906	Score: 0.9230769230769231
#               precision    recall  f1-score   support
#
#     negative     0.8836    0.9699    0.9247       133
#     positive     0.9685    0.8786    0.9213       140
#
#     accuracy                         0.9231       273
#    macro avg     0.9260    0.9242    0.9230       273
# weighted avg     0.9271    0.9231    0.9230       273
# Rodada: 16	Seed: 1687	Score: 0.9120879120879121
#               precision    recall  f1-score   support
#
#     negative     0.8966    0.9353    0.9155       139
#     positive     0.9297    0.8881    0.9084       134
#
#     accuracy                         0.9121       273
#    macro avg     0.9131    0.9117    0.9119       273
# weighted avg     0.9128    0.9121    0.9120       273
# Rodada: 17	Seed: 7080	Score: 0.9047619047619048
#               precision    recall  f1-score   support
#
#     negative     0.9051    0.9051    0.9051       137
#     positive     0.9044    0.9044    0.9044       136
#
#     accuracy                         0.9048       273
#    macro avg     0.9048    0.9048    0.9048       273
# weighted avg     0.9048    0.9048    0.9048       273
# Rodada: 18	Seed: 5473	Score: 0.9340659340659341
#               precision    recall  f1-score   support
#
#     negative     0.9510    0.9252    0.9379       147
#     positive     0.9154    0.9444    0.9297       126
#
#     accuracy                         0.9341       273
#    macro avg     0.9332    0.9348    0.9338       273
# weighted avg     0.9346    0.9341    0.9341       273
# Rodada: 19	Seed: 7854	Score: 0.9230769230769231
#               precision    recall  f1-score   support
#
#     negative     0.9338    0.9137    0.9236       139
#     positive     0.9124    0.9328    0.9225       134
#
#     accuracy                         0.9231       273
#    macro avg     0.9231    0.9233    0.9231       273
# weighted avg     0.9233    0.9231    0.9231       273

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.930403       0.912088
# 1       0.956044       0.948718
# 2       0.945055       0.934066
# 3       0.904762       0.904762
# 4       0.923077       0.923077
# 5       0.926740       0.919414
# 6       0.926740       0.908425
# 7       0.904762       0.879121
# 8       0.919414       0.930403
# 9       0.930403       0.901099
# 10      0.923077       0.904762
# 11      0.930403       0.930403
# 12      0.930403       0.945055
# 13      0.901099       0.890110
# 14      0.952381       0.923077
# 15      0.930403       0.923077
# 16      0.934066       0.912088
# 17      0.923077       0.904762
# 18      0.930403       0.934066
# 19      0.923077       0.923077

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.944218       0.962585
# std        0.022247       0.017998
# min        0.904762       0.925170
# 25%        0.930272       0.952381
# 50%        0.942177       0.965986
# 75%        0.959184       0.972789
# max        0.986395       0.986395
