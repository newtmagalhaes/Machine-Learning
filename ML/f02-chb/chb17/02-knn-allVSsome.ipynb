# %% [markdown]
# # KNN CHB17 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb17_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9540229885057471
#               precision    recall  f1-score   support
#
#     negative     0.9318    0.9762    0.9535        42
#     positive     0.9767    0.9333    0.9545        45
#
#     accuracy                         0.9540        87
#    macro avg     0.9543    0.9548    0.9540        87
# weighted avg     0.9551    0.9540    0.9540        87
# Rodada: 1	Seed: 8968	Score: 0.8850574712643678
#               precision    recall  f1-score   support
#
#     negative     0.8444    0.9268    0.8837        41
#     positive     0.9286    0.8478    0.8864        46
#
#     accuracy                         0.8851        87
#    macro avg     0.8865    0.8873    0.8850        87
# weighted avg     0.8889    0.8851    0.8851        87
# Rodada: 2	Seed: 8442	Score: 0.9425287356321839
#               precision    recall  f1-score   support
#
#     negative     0.9500    0.9268    0.9383        41
#     positive     0.9362    0.9565    0.9462        46
#
#     accuracy                         0.9425        87
#    macro avg     0.9431    0.9417    0.9423        87
# weighted avg     0.9427    0.9425    0.9425        87
# Rodada: 3	Seed: 1729	Score: 0.9195402298850575
#               precision    recall  f1-score   support
#
#     negative     0.9268    0.9048    0.9157        42
#     positive     0.9130    0.9333    0.9231        45
#
#     accuracy                         0.9195        87
#    macro avg     0.9199    0.9190    0.9194        87
# weighted avg     0.9197    0.9195    0.9195        87
# Rodada: 4	Seed: 290	Score: 0.9655172413793104
#               precision    recall  f1-score   support
#
#     negative     0.9778    0.9565    0.9670        46
#     positive     0.9524    0.9756    0.9639        41
#
#     accuracy                         0.9655        87
#    macro avg     0.9651    0.9661    0.9654        87
# weighted avg     0.9658    0.9655    0.9655        87
# Rodada: 5	Seed: 490	Score: 0.9310344827586207
#               precision    recall  f1-score   support
#
#     negative     0.9070    0.9512    0.9286        41
#     positive     0.9545    0.9130    0.9333        46
#
#     accuracy                         0.9310        87
#    macro avg     0.9308    0.9321    0.9310        87
# weighted avg     0.9321    0.9310    0.9311        87
# Rodada: 6	Seed: 2128	Score: 0.9195402298850575
#               precision    recall  f1-score   support
#
#     negative     0.9302    0.9091    0.9195        44
#     positive     0.9091    0.9302    0.9195        43
#
#     accuracy                         0.9195        87
#    macro avg     0.9197    0.9197    0.9195        87
# weighted avg     0.9198    0.9195    0.9195        87
# Rodada: 7	Seed: 1167	Score: 0.9425287356321839
#               precision    recall  f1-score   support
#
#     negative     0.9800    0.9245    0.9515        53
#     positive     0.8919    0.9706    0.9296        34
#
#     accuracy                         0.9425        87
#    macro avg     0.9359    0.9476    0.9405        87
# weighted avg     0.9456    0.9425    0.9429        87
# Rodada: 8	Seed: 8900	Score: 0.9080459770114943
#               precision    recall  f1-score   support
#
#     negative     0.9048    0.9048    0.9048        42
#     positive     0.9111    0.9111    0.9111        45
#
#     accuracy                         0.9080        87
#    macro avg     0.9079    0.9079    0.9079        87
# weighted avg     0.9080    0.9080    0.9080        87
# Rodada: 9	Seed: 5078	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.8909    0.9423    0.9159        52
#     positive     0.9062    0.8286    0.8657        35
#
#     accuracy                         0.8966        87
#    macro avg     0.8986    0.8854    0.8908        87
# weighted avg     0.8971    0.8966    0.8957        87
# Rodada: 10	Seed: 1359	Score: 0.9540229885057471
#               precision    recall  f1-score   support
#
#     negative     0.9375    0.9783    0.9574        46
#     positive     0.9744    0.9268    0.9500        41
#
#     accuracy                         0.9540        87
#    macro avg     0.9559    0.9525    0.9537        87
# weighted avg     0.9549    0.9540    0.9539        87
# Rodada: 11	Seed: 894	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.8696    0.9302    0.8989        43
#     positive     0.9268    0.8636    0.8941        44
#
#     accuracy                         0.8966        87
#    macro avg     0.8982    0.8969    0.8965        87
# weighted avg     0.8985    0.8966    0.8965        87
# Rodada: 12	Seed: 7809	Score: 0.9195402298850575
#               precision    recall  f1-score   support
#
#     negative     0.9362    0.9167    0.9263        48
#     positive     0.9000    0.9231    0.9114        39
#
#     accuracy                         0.9195        87
#    macro avg     0.9181    0.9199    0.9189        87
# weighted avg     0.9200    0.9195    0.9196        87
# Rodada: 13	Seed: 6990	Score: 0.9195402298850575
#               precision    recall  f1-score   support
#
#     negative     0.9167    0.9362    0.9263        47
#     positive     0.9231    0.9000    0.9114        40
#
#     accuracy                         0.9195        87
#    macro avg     0.9199    0.9181    0.9189        87
# weighted avg     0.9196    0.9195    0.9195        87
# Rodada: 14	Seed: 3623	Score: 0.8850574712643678
#               precision    recall  f1-score   support
#
#     negative     0.8684    0.8684    0.8684        38
#     positive     0.8980    0.8980    0.8980        49
#
#     accuracy                         0.8851        87
#    macro avg     0.8832    0.8832    0.8832        87
# weighted avg     0.8851    0.8851    0.8851        87
# Rodada: 15	Seed: 5906	Score: 0.8850574712643678
#               precision    recall  f1-score   support
#
#     negative     0.8542    0.9318    0.8913        44
#     positive     0.9231    0.8372    0.8780        43
#
#     accuracy                         0.8851        87
#    macro avg     0.8886    0.8845    0.8847        87
# weighted avg     0.8882    0.8851    0.8848        87
# Rodada: 16	Seed: 1687	Score: 0.9195402298850575
#               precision    recall  f1-score   support
#
#     negative     0.8947    0.9189    0.9067        37
#     positive     0.9388    0.9200    0.9293        50
#
#     accuracy                         0.9195        87
#    macro avg     0.9168    0.9195    0.9180        87
# weighted avg     0.9200    0.9195    0.9197        87
# Rodada: 17	Seed: 7080	Score: 0.9080459770114943
#               precision    recall  f1-score   support
#
#     negative     0.9070    0.9070    0.9070        43
#     positive     0.9091    0.9091    0.9091        44
#
#     accuracy                         0.9080        87
#    macro avg     0.9080    0.9080    0.9080        87
# weighted avg     0.9080    0.9080    0.9080        87
# Rodada: 18	Seed: 5473	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.9348    0.8776    0.9053        49
#     positive     0.8537    0.9211    0.8861        38
#
#     accuracy                         0.8966        87
#    macro avg     0.8942    0.8993    0.8957        87
# weighted avg     0.8993    0.8966    0.8969        87
# Rodada: 19	Seed: 7854	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.8810    0.9024    0.8916        41
#     positive     0.9111    0.8913    0.9011        46
#
#     accuracy                         0.8966        87
#    macro avg     0.8960    0.8969    0.8963        87
# weighted avg     0.8969    0.8966    0.8966        87

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9310344827586207
#               precision    recall  f1-score   support
#
#     negative     0.9091    0.9524    0.9302        42
#     positive     0.9535    0.9111    0.9318        45
#
#     accuracy                         0.9310        87
#    macro avg     0.9313    0.9317    0.9310        87
# weighted avg     0.9321    0.9310    0.9311        87
# Rodada: 1	Seed: 8968	Score: 0.8505747126436781
#               precision    recall  f1-score   support
#
#     negative     0.8043    0.9024    0.8506        41
#     positive     0.9024    0.8043    0.8506        46
#
#     accuracy                         0.8506        87
#    macro avg     0.8534    0.8534    0.8506        87
# weighted avg     0.8562    0.8506    0.8506        87
# Rodada: 2	Seed: 8442	Score: 0.9310344827586207
#               precision    recall  f1-score   support
#
#     negative     0.9070    0.9512    0.9286        41
#     positive     0.9545    0.9130    0.9333        46
#
#     accuracy                         0.9310        87
#    macro avg     0.9308    0.9321    0.9310        87
# weighted avg     0.9321    0.9310    0.9311        87
# Rodada: 3	Seed: 1729	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.8837    0.9048    0.8941        42
#     positive     0.9091    0.8889    0.8989        45
#
#     accuracy                         0.8966        87
#    macro avg     0.8964    0.8968    0.8965        87
# weighted avg     0.8968    0.8966    0.8966        87
# Rodada: 4	Seed: 290	Score: 0.9425287356321839
#               precision    recall  f1-score   support
#
#     negative     0.9556    0.9348    0.9451        46
#     positive     0.9286    0.9512    0.9398        41
#
#     accuracy                         0.9425        87
#    macro avg     0.9421    0.9430    0.9424        87
# weighted avg     0.9428    0.9425    0.9426        87
# Rodada: 5	Seed: 490	Score: 0.9310344827586207
#               precision    recall  f1-score   support
#
#     negative     0.9070    0.9512    0.9286        41
#     positive     0.9545    0.9130    0.9333        46
#
#     accuracy                         0.9310        87
#    macro avg     0.9308    0.9321    0.9310        87
# weighted avg     0.9321    0.9310    0.9311        87
# Rodada: 6	Seed: 2128	Score: 0.9310344827586207
#               precision    recall  f1-score   support
#
#     negative     0.9750    0.8864    0.9286        44
#     positive     0.8936    0.9767    0.9333        43
#
#     accuracy                         0.9310        87
#    macro avg     0.9343    0.9316    0.9310        87
# weighted avg     0.9348    0.9310    0.9309        87
# Rodada: 7	Seed: 1167	Score: 0.9080459770114943
#               precision    recall  f1-score   support
#
#     negative     0.9592    0.8868    0.9216        53
#     positive     0.8421    0.9412    0.8889        34
#
#     accuracy                         0.9080        87
#    macro avg     0.9006    0.9140    0.9052        87
# weighted avg     0.9134    0.9080    0.9088        87
# Rodada: 8	Seed: 8900	Score: 0.9540229885057471
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9048    0.9500        42
#     positive     0.9184    1.0000    0.9574        45
#
#     accuracy                         0.9540        87
#    macro avg     0.9592    0.9524    0.9537        87
# weighted avg     0.9578    0.9540    0.9539        87
# Rodada: 9	Seed: 5078	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.9388    0.8846    0.9109        52
#     positive     0.8421    0.9143    0.8767        35
#
#     accuracy                         0.8966        87
#    macro avg     0.8904    0.8995    0.8938        87
# weighted avg     0.8999    0.8966    0.8971        87
# Rodada: 10	Seed: 1359	Score: 0.9080459770114943
#               precision    recall  f1-score   support
#
#     negative     0.9130    0.9130    0.9130        46
#     positive     0.9024    0.9024    0.9024        41
#
#     accuracy                         0.9080        87
#    macro avg     0.9077    0.9077    0.9077        87
# weighted avg     0.9080    0.9080    0.9080        87
# Rodada: 11	Seed: 894	Score: 0.9310344827586207
#               precision    recall  f1-score   support
#
#     negative     0.9111    0.9535    0.9318        43
#     positive     0.9524    0.9091    0.9302        44
#
#     accuracy                         0.9310        87
#    macro avg     0.9317    0.9313    0.9310        87
# weighted avg     0.9320    0.9310    0.9310        87
# Rodada: 12	Seed: 7809	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.9756    0.8333    0.8989        48
#     positive     0.8261    0.9744    0.8941        39
#
#     accuracy                         0.8966        87
#    macro avg     0.9008    0.9038    0.8965        87
# weighted avg     0.9086    0.8966    0.8967        87
# Rodada: 13	Seed: 6990	Score: 0.9195402298850575
#               precision    recall  f1-score   support
#
#     negative     0.9762    0.8723    0.9213        47
#     positive     0.8667    0.9750    0.9176        40
#
#     accuracy                         0.9195        87
#    macro avg     0.9214    0.9237    0.9195        87
# weighted avg     0.9258    0.9195    0.9196        87
# Rodada: 14	Seed: 3623	Score: 0.8850574712643678
#               precision    recall  f1-score   support
#
#     negative     0.8684    0.8684    0.8684        38
#     positive     0.8980    0.8980    0.8980        49
#
#     accuracy                         0.8851        87
#    macro avg     0.8832    0.8832    0.8832        87
# weighted avg     0.8851    0.8851    0.8851        87
# Rodada: 15	Seed: 5906	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.9268    0.8636    0.8941        44
#     positive     0.8696    0.9302    0.8989        43
#
#     accuracy                         0.8966        87
#    macro avg     0.8982    0.8969    0.8965        87
# weighted avg     0.8985    0.8966    0.8965        87
# Rodada: 16	Seed: 1687	Score: 0.9310344827586207
#               precision    recall  f1-score   support
#
#     negative     0.8974    0.9459    0.9211        37
#     positive     0.9583    0.9200    0.9388        50
#
#     accuracy                         0.9310        87
#    macro avg     0.9279    0.9330    0.9299        87
# weighted avg     0.9324    0.9310    0.9312        87
# Rodada: 17	Seed: 7080	Score: 0.896551724137931
#               precision    recall  f1-score   support
#
#     negative     0.8864    0.9070    0.8966        43
#     positive     0.9070    0.8864    0.8966        44
#
#     accuracy                         0.8966        87
#    macro avg     0.8967    0.8967    0.8966        87
# weighted avg     0.8968    0.8966    0.8966        87
# Rodada: 18	Seed: 5473	Score: 0.9080459770114943
#               precision    recall  f1-score   support
#
#     negative     0.9556    0.8776    0.9149        49
#     positive     0.8571    0.9474    0.9000        38
#
#     accuracy                         0.9080        87
#    macro avg     0.9063    0.9125    0.9074        87
# weighted avg     0.9126    0.9080    0.9084        87
# Rodada: 19	Seed: 7854	Score: 0.9425287356321839
#               precision    recall  f1-score   support
#
#     negative     0.9500    0.9268    0.9383        41
#     positive     0.9362    0.9565    0.9462        46
#
#     accuracy                         0.9425        87
#    macro avg     0.9431    0.9417    0.9423        87
# weighted avg     0.9427    0.9425    0.9425        87

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.954023       0.931034
# 1       0.885057       0.850575
# 2       0.942529       0.931034
# 3       0.919540       0.896552
# 4       0.965517       0.942529
# 5       0.931034       0.931034
# 6       0.919540       0.931034
# 7       0.942529       0.908046
# 8       0.908046       0.954023
# 9       0.896552       0.896552
# 10      0.954023       0.908046
# 11      0.896552       0.931034
# 12      0.919540       0.896552
# 13      0.919540       0.919540
# 14      0.885057       0.885057
# 15      0.885057       0.896552
# 16      0.919540       0.931034
# 17      0.908046       0.896552
# 18      0.896552       0.908046
# 19      0.896552       0.942529

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.944218       0.962585
# std        0.022247       0.017998
# min        0.904762       0.925170
# 25%        0.930272       0.952381
# 50%        0.942177       0.965986
# 75%        0.959184       0.972789
# max        0.986395       0.986395
