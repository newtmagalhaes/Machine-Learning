# %% [markdown]
# # KNN CHB19 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb19_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 0.8142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.7636    1.0000    0.8660        42
#     positive     1.0000    0.5357    0.6977        28
#
#     accuracy                         0.8143        70
#    macro avg     0.8818    0.7679    0.7818        70
# weighted avg     0.8582    0.8143    0.7987        70
# Rodada: 1	Seed: 8968	Score: 0.8714285714285714
#               precision    recall  f1-score   support
#
#     negative     0.7632    1.0000    0.8657        29
#     positive     1.0000    0.7805    0.8767        41
#
#     accuracy                         0.8714        70
#    macro avg     0.8816    0.8902    0.8712        70
# weighted avg     0.9019    0.8714    0.8721        70
# Rodada: 2	Seed: 8442	Score: 0.9
#               precision    recall  f1-score   support
#
#     negative     0.8511    1.0000    0.9195        40
#     positive     1.0000    0.7667    0.8679        30
#
#     accuracy                         0.9000        70
#    macro avg     0.9255    0.8833    0.8937        70
# weighted avg     0.9149    0.9000    0.8974        70
# Rodada: 3	Seed: 1729	Score: 0.8857142857142857
#               precision    recall  f1-score   support
#
#     negative     0.8095    1.0000    0.8947        34
#     positive     1.0000    0.7778    0.8750        36
#
#     accuracy                         0.8857        70
#    macro avg     0.9048    0.8889    0.8849        70
# weighted avg     0.9075    0.8857    0.8846        70
# Rodada: 4	Seed: 290	Score: 0.9571428571428572
#               precision    recall  f1-score   support
#
#     negative     0.9333    1.0000    0.9655        42
#     positive     1.0000    0.8929    0.9434        28
#
#     accuracy                         0.9571        70
#    macro avg     0.9667    0.9464    0.9545        70
# weighted avg     0.9600    0.9571    0.9567        70
# Rodada: 5	Seed: 490	Score: 0.9142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.8500    1.0000    0.9189        34
#     positive     1.0000    0.8333    0.9091        36
#
#     accuracy                         0.9143        70
#    macro avg     0.9250    0.9167    0.9140        70
# weighted avg     0.9271    0.9143    0.9139        70
# Rodada: 6	Seed: 2128	Score: 0.8714285714285714
#               precision    recall  f1-score   support
#
#     negative     0.7805    1.0000    0.8767        32
#     positive     1.0000    0.7632    0.8657        38
#
#     accuracy                         0.8714        70
#    macro avg     0.8902    0.8816    0.8712        70
# weighted avg     0.8997    0.8714    0.8707        70
# Rodada: 7	Seed: 1167	Score: 0.8428571428571429
#               precision    recall  f1-score   support
#
#     negative     0.7609    1.0000    0.8642        35
#     positive     1.0000    0.6857    0.8136        35
#
#     accuracy                         0.8429        70
#    macro avg     0.8804    0.8429    0.8389        70
# weighted avg     0.8804    0.8429    0.8389        70
# Rodada: 8	Seed: 8900	Score: 0.9285714285714286
#               precision    recall  f1-score   support
#
#     negative     0.8810    1.0000    0.9367        37
#     positive     1.0000    0.8485    0.9180        33
#
#     accuracy                         0.9286        70
#    macro avg     0.9405    0.9242    0.9274        70
# weighted avg     0.9371    0.9286    0.9279        70
# Rodada: 9	Seed: 5078	Score: 0.8857142857142857
#               precision    recall  f1-score   support
#
#     negative     0.8298    1.0000    0.9070        39
#     positive     1.0000    0.7419    0.8519        31
#
#     accuracy                         0.8857        70
#    macro avg     0.9149    0.8710    0.8794        70
# weighted avg     0.9052    0.8857    0.8826        70
# Rodada: 10	Seed: 1359	Score: 0.9285714285714286
#               precision    recall  f1-score   support
#
#     negative     0.8718    1.0000    0.9315        34
#     positive     1.0000    0.8611    0.9254        36
#
#     accuracy                         0.9286        70
#    macro avg     0.9359    0.9306    0.9284        70
# weighted avg     0.9377    0.9286    0.9284        70
# Rodada: 11	Seed: 894	Score: 0.9
#               precision    recall  f1-score   support
#
#     negative     0.8372    1.0000    0.9114        36
#     positive     1.0000    0.7941    0.8852        34
#
#     accuracy                         0.9000        70
#    macro avg     0.9186    0.8971    0.8983        70
# weighted avg     0.9163    0.9000    0.8987        70
# Rodada: 12	Seed: 7809	Score: 0.9
#               precision    recall  f1-score   support
#
#     negative     0.8205    1.0000    0.9014        32
#     positive     1.0000    0.8158    0.8986        38
#
#     accuracy                         0.9000        70
#    macro avg     0.9103    0.9079    0.9000        70
# weighted avg     0.9179    0.9000    0.8999        70
# Rodada: 13	Seed: 6990	Score: 0.9285714285714286
#               precision    recall  f1-score   support
#
#     negative     0.8810    1.0000    0.9367        37
#     positive     1.0000    0.8485    0.9180        33
#
#     accuracy                         0.9286        70
#    macro avg     0.9405    0.9242    0.9274        70
# weighted avg     0.9371    0.9286    0.9279        70
# Rodada: 14	Seed: 3623	Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#     negative     0.7872    1.0000    0.8810        37
#     positive     1.0000    0.6970    0.8214        33
#
#     accuracy                         0.8571        70
#    macro avg     0.8936    0.8485    0.8512        70
# weighted avg     0.8875    0.8571    0.8529        70
# Rodada: 15	Seed: 5906	Score: 0.9
#               precision    recall  f1-score   support
#
#     negative     0.8444    1.0000    0.9157        38
#     positive     1.0000    0.7812    0.8772        32
#
#     accuracy                         0.9000        70
#    macro avg     0.9222    0.8906    0.8964        70
# weighted avg     0.9156    0.9000    0.8981        70
# Rodada: 16	Seed: 1687	Score: 0.8428571428571429
#               precision    recall  f1-score   support
#
#     negative     0.7381    1.0000    0.8493        31
#     positive     1.0000    0.7179    0.8358        39
#
#     accuracy                         0.8429        70
#    macro avg     0.8690    0.8590    0.8426        70
# weighted avg     0.8840    0.8429    0.8418        70
# Rodada: 17	Seed: 7080	Score: 0.8142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.7174    1.0000    0.8354        33
#     positive     1.0000    0.6486    0.7869        37
#
#     accuracy                         0.8143        70
#    macro avg     0.8587    0.8243    0.8112        70
# weighted avg     0.8668    0.8143    0.8098        70
# Rodada: 18	Seed: 5473	Score: 0.8857142857142857
#               precision    recall  f1-score   support
#
#     negative     0.8222    1.0000    0.9024        37
#     positive     1.0000    0.7576    0.8621        33
#
#     accuracy                         0.8857        70
#    macro avg     0.9111    0.8788    0.8823        70
# weighted avg     0.9060    0.8857    0.8834        70
# Rodada: 19	Seed: 7854	Score: 0.9285714285714286
#               precision    recall  f1-score   support
#
#     negative     0.8837    1.0000    0.9383        38
#     positive     1.0000    0.8438    0.9153        32
#
#     accuracy                         0.9286        70
#    macro avg     0.9419    0.9219    0.9268        70
# weighted avg     0.9369    0.9286    0.9277        70

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.8142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.7636    1.0000    0.8660        42
#     positive     1.0000    0.5357    0.6977        28
#
#     accuracy                         0.8143        70
#    macro avg     0.8818    0.7679    0.7818        70
# weighted avg     0.8582    0.8143    0.7987        70
# Rodada: 1	Seed: 8968	Score: 0.8857142857142857
#               precision    recall  f1-score   support
#
#     negative     0.7838    1.0000    0.8788        29
#     positive     1.0000    0.8049    0.8919        41
#
#     accuracy                         0.8857        70
#    macro avg     0.8919    0.9024    0.8853        70
# weighted avg     0.9104    0.8857    0.8865        70
# Rodada: 2	Seed: 8442	Score: 0.9571428571428572
#               precision    recall  f1-score   support
#
#     negative     0.9302    1.0000    0.9639        40
#     positive     1.0000    0.9000    0.9474        30
#
#     accuracy                         0.9571        70
#    macro avg     0.9651    0.9500    0.9556        70
# weighted avg     0.9601    0.9571    0.9568        70
# Rodada: 3	Seed: 1729	Score: 0.9142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.8500    1.0000    0.9189        34
#     positive     1.0000    0.8333    0.9091        36
#
#     accuracy                         0.9143        70
#    macro avg     0.9250    0.9167    0.9140        70
# weighted avg     0.9271    0.9143    0.9139        70
# Rodada: 4	Seed: 290	Score: 0.9428571428571428
#               precision    recall  f1-score   support
#
#     negative     0.9318    0.9762    0.9535        42
#     positive     0.9615    0.8929    0.9259        28
#
#     accuracy                         0.9429        70
#    macro avg     0.9467    0.9345    0.9397        70
# weighted avg     0.9437    0.9429    0.9425        70
# Rodada: 5	Seed: 490	Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#     negative     0.7727    1.0000    0.8718        34
#     positive     1.0000    0.7222    0.8387        36
#
#     accuracy                         0.8571        70
#    macro avg     0.8864    0.8611    0.8553        70
# weighted avg     0.8896    0.8571    0.8548        70
# Rodada: 6	Seed: 2128	Score: 0.8714285714285714
#               precision    recall  f1-score   support
#
#     negative     0.7805    1.0000    0.8767        32
#     positive     1.0000    0.7632    0.8657        38
#
#     accuracy                         0.8714        70
#    macro avg     0.8902    0.8816    0.8712        70
# weighted avg     0.8997    0.8714    0.8707        70
# Rodada: 7	Seed: 1167	Score: 0.8428571428571429
#               precision    recall  f1-score   support
#
#     negative     0.7609    1.0000    0.8642        35
#     positive     1.0000    0.6857    0.8136        35
#
#     accuracy                         0.8429        70
#    macro avg     0.8804    0.8429    0.8389        70
# weighted avg     0.8804    0.8429    0.8389        70
# Rodada: 8	Seed: 8900	Score: 0.9
#               precision    recall  f1-score   support
#
#     negative     0.8409    1.0000    0.9136        37
#     positive     1.0000    0.7879    0.8814        33
#
#     accuracy                         0.9000        70
#    macro avg     0.9205    0.8939    0.8975        70
# weighted avg     0.9159    0.9000    0.8984        70
# Rodada: 9	Seed: 5078	Score: 0.9428571428571428
#               precision    recall  f1-score   support
#
#     negative     0.9070    1.0000    0.9512        39
#     positive     1.0000    0.8710    0.9310        31
#
#     accuracy                         0.9429        70
#    macro avg     0.9535    0.9355    0.9411        70
# weighted avg     0.9482    0.9429    0.9423        70
# Rodada: 10	Seed: 1359	Score: 0.9
#               precision    recall  f1-score   support
#
#     negative     0.8293    1.0000    0.9067        34
#     positive     1.0000    0.8056    0.8923        36
#
#     accuracy                         0.9000        70
#    macro avg     0.9146    0.9028    0.8995        70
# weighted avg     0.9171    0.9000    0.8993        70
# Rodada: 11	Seed: 894	Score: 0.9
#               precision    recall  f1-score   support
#
#     negative     0.8372    1.0000    0.9114        36
#     positive     1.0000    0.7941    0.8852        34
#
#     accuracy                         0.9000        70
#    macro avg     0.9186    0.8971    0.8983        70
# weighted avg     0.9163    0.9000    0.8987        70
# Rodada: 12	Seed: 7809	Score: 0.9142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.8421    1.0000    0.9143        32
#     positive     1.0000    0.8421    0.9143        38
#
#     accuracy                         0.9143        70
#    macro avg     0.9211    0.9211    0.9143        70
# weighted avg     0.9278    0.9143    0.9143        70
# Rodada: 13	Seed: 6990	Score: 0.9142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.8605    1.0000    0.9250        37
#     positive     1.0000    0.8182    0.9000        33
#
#     accuracy                         0.9143        70
#    macro avg     0.9302    0.9091    0.9125        70
# weighted avg     0.9262    0.9143    0.9132        70
# Rodada: 14	Seed: 3623	Score: 0.8428571428571429
#               precision    recall  f1-score   support
#
#     negative     0.7708    1.0000    0.8706        37
#     positive     1.0000    0.6667    0.8000        33
#
#     accuracy                         0.8429        70
#    macro avg     0.8854    0.8333    0.8353        70
# weighted avg     0.8789    0.8429    0.8373        70
# Rodada: 15	Seed: 5906	Score: 0.8714285714285714
#               precision    recall  f1-score   support
#
#     negative     0.8085    1.0000    0.8941        38
#     positive     1.0000    0.7188    0.8364        32
#
#     accuracy                         0.8714        70
#    macro avg     0.9043    0.8594    0.8652        70
# weighted avg     0.8960    0.8714    0.8677        70
# Rodada: 16	Seed: 1687	Score: 0.8142857142857143
#               precision    recall  f1-score   support
#
#     negative     0.7045    1.0000    0.8267        31
#     positive     1.0000    0.6667    0.8000        39
#
#     accuracy                         0.8143        70
#    macro avg     0.8523    0.8333    0.8133        70
# weighted avg     0.8692    0.8143    0.8118        70
# Rodada: 17	Seed: 7080	Score: 0.8428571428571429
#               precision    recall  f1-score   support
#
#     negative     0.7500    1.0000    0.8571        33
#     positive     1.0000    0.7027    0.8254        37
#
#     accuracy                         0.8429        70
#    macro avg     0.8750    0.8514    0.8413        70
# weighted avg     0.8821    0.8429    0.8404        70
# Rodada: 18	Seed: 5473	Score: 0.8857142857142857
#               precision    recall  f1-score   support
#
#     negative     0.8222    1.0000    0.9024        37
#     positive     1.0000    0.7576    0.8621        33
#
#     accuracy                         0.8857        70
#    macro avg     0.9111    0.8788    0.8823        70
# weighted avg     0.9060    0.8857    0.8834        70
# Rodada: 19	Seed: 7854	Score: 0.9285714285714286
#               precision    recall  f1-score   support
#
#     negative     0.8837    1.0000    0.9383        38
#     positive     1.0000    0.8438    0.9153        32
#
#     accuracy                         0.9286        70
#    macro avg     0.9419    0.9219    0.9268        70
# weighted avg     0.9369    0.9286    0.9277        70

# %%
acc_df
# Out:
#     all channels  some channels
# 0       0.814286       0.814286
# 1       0.871429       0.885714
# 2       0.900000       0.957143
# 3       0.885714       0.914286
# 4       0.957143       0.942857
# 5       0.914286       0.857143
# 6       0.871429       0.871429
# 7       0.842857       0.842857
# 8       0.928571       0.900000
# 9       0.885714       0.942857
# 10      0.928571       0.900000
# 11      0.900000       0.900000
# 12      0.900000       0.914286
# 13      0.928571       0.914286
# 14      0.857143       0.842857
# 15      0.900000       0.871429
# 16      0.842857       0.814286
# 17      0.814286       0.842857
# 18      0.885714       0.885714
# 19      0.928571       0.928571

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.887857       0.887143
# std        0.039130       0.041945
# min        0.814286       0.814286
# 25%        0.867857       0.853571
# 50%        0.892857       0.892857
# 75%        0.917857       0.914286
# max        0.957143       0.957143
