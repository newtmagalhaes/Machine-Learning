# %% [markdown]
# # KNN CHB22 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb22_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        37
#     positive     1.0000    1.0000    1.0000        23
#
#     accuracy                         1.0000        60
#    macro avg     1.0000    1.0000    1.0000        60
# weighted avg     1.0000    1.0000    1.0000        60
# Rodada: 1	Seed: 8968	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9643    1.0000    0.9818        27
#     positive     1.0000    0.9697    0.9846        33
#
#     accuracy                         0.9833        60
#    macro avg     0.9821    0.9848    0.9832        60
# weighted avg     0.9839    0.9833    0.9834        60
# Rodada: 2	Seed: 8442	Score: 0.95
#               precision    recall  f1-score   support
#
#     negative     0.9722    0.9459    0.9589        37
#     positive     0.9167    0.9565    0.9362        23
#
#     accuracy                         0.9500        60
#    macro avg     0.9444    0.9512    0.9475        60
# weighted avg     0.9509    0.9500    0.9502        60
# Rodada: 3	Seed: 1729	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9697    0.9846        33
#     positive     0.9643    1.0000    0.9818        27
#
#     accuracy                         0.9833        60
#    macro avg     0.9821    0.9848    0.9832        60
# weighted avg     0.9839    0.9833    0.9834        60
# Rodada: 4	Seed: 290	Score: 0.9
#               precision    recall  f1-score   support
#
#     negative     0.8810    0.9737    0.9250        38
#     positive     0.9444    0.7727    0.8500        22
#
#     accuracy                         0.9000        60
#    macro avg     0.9127    0.8732    0.8875        60
# weighted avg     0.9042    0.9000    0.8975        60
# Rodada: 5	Seed: 490	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        27
#     positive     1.0000    1.0000    1.0000        33
#
#     accuracy                         1.0000        60
#    macro avg     1.0000    1.0000    1.0000        60
# weighted avg     1.0000    1.0000    1.0000        60
# Rodada: 6	Seed: 2128	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9259    1.0000    0.9615        25
#     positive     1.0000    0.9429    0.9706        35
#
#     accuracy                         0.9667        60
#    macro avg     0.9630    0.9714    0.9661        60
# weighted avg     0.9691    0.9667    0.9668        60
# Rodada: 7	Seed: 1167	Score: 0.9
#               precision    recall  f1-score   support
#
#     negative     0.8333    1.0000    0.9091        30
#     positive     1.0000    0.8000    0.8889        30
#
#     accuracy                         0.9000        60
#    macro avg     0.9167    0.9000    0.8990        60
# weighted avg     0.9167    0.9000    0.8990        60
# Rodada: 8	Seed: 8900	Score: 0.9333333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9714    0.9189    0.9444        37
#     positive     0.8800    0.9565    0.9167        23
#
#     accuracy                         0.9333        60
#    macro avg     0.9257    0.9377    0.9306        60
# weighted avg     0.9364    0.9333    0.9338        60
# Rodada: 9	Seed: 5078	Score: 0.95
#               precision    recall  f1-score   support
#
#     negative     0.9375    0.9677    0.9524        31
#     positive     0.9643    0.9310    0.9474        29
#
#     accuracy                         0.9500        60
#    macro avg     0.9509    0.9494    0.9499        60
# weighted avg     0.9504    0.9500    0.9500        60
# Rodada: 10	Seed: 1359	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9667    1.0000    0.9831        29
#     positive     1.0000    0.9677    0.9836        31
#
#     accuracy                         0.9833        60
#    macro avg     0.9833    0.9839    0.9833        60
# weighted avg     0.9839    0.9833    0.9833        60
# Rodada: 11	Seed: 894	Score: 0.9333333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9091    0.9677    0.9375        31
#     positive     0.9630    0.8966    0.9286        29
#
#     accuracy                         0.9333        60
#    macro avg     0.9360    0.9321    0.9330        60
# weighted avg     0.9351    0.9333    0.9332        60
# Rodada: 12	Seed: 7809	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9286    0.9630        28
#     positive     0.9412    1.0000    0.9697        32
#
#     accuracy                         0.9667        60
#    macro avg     0.9706    0.9643    0.9663        60
# weighted avg     0.9686    0.9667    0.9666        60
# Rodada: 13	Seed: 6990	Score: 0.9166666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9032    0.9333    0.9180        30
#     positive     0.9310    0.9000    0.9153        30
#
#     accuracy                         0.9167        60
#    macro avg     0.9171    0.9167    0.9166        60
# weighted avg     0.9171    0.9167    0.9166        60
# Rodada: 14	Seed: 3623	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9412    1.0000    0.9697        32
#     positive     1.0000    0.9286    0.9630        28
#
#     accuracy                         0.9667        60
#    macro avg     0.9706    0.9643    0.9663        60
# weighted avg     0.9686    0.9667    0.9666        60
# Rodada: 15	Seed: 5906	Score: 0.95
#               precision    recall  f1-score   support
#
#     negative     0.8929    1.0000    0.9434        25
#     positive     1.0000    0.9143    0.9552        35
#
#     accuracy                         0.9500        60
#    macro avg     0.9464    0.9571    0.9493        60
# weighted avg     0.9554    0.9500    0.9503        60
# Rodada: 16	Seed: 1687	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9630    0.9811        27
#     positive     0.9706    1.0000    0.9851        33
#
#     accuracy                         0.9833        60
#    macro avg     0.9853    0.9815    0.9831        60
# weighted avg     0.9838    0.9833    0.9833        60
# Rodada: 17	Seed: 7080	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9630    0.9811        27
#     positive     0.9706    1.0000    0.9851        33
#
#     accuracy                         0.9833        60
#    macro avg     0.9853    0.9815    0.9831        60
# weighted avg     0.9838    0.9833    0.9833        60
# Rodada: 18	Seed: 5473	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9677    0.9836        31
#     positive     0.9667    1.0000    0.9831        29
#
#     accuracy                         0.9833        60
#    macro avg     0.9833    0.9839    0.9833        60
# weighted avg     0.9839    0.9833    0.9833        60
# Rodada: 19	Seed: 7854	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9714    0.9714    0.9714        35
#     positive     0.9600    0.9600    0.9600        25
#
#     accuracy                         0.9667        60
#    macro avg     0.9657    0.9657    0.9657        60
# weighted avg     0.9667    0.9667    0.9667        60

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9459    0.9722        37
#     positive     0.9200    1.0000    0.9583        23
#
#     accuracy                         0.9667        60
#    macro avg     0.9600    0.9730    0.9653        60
# weighted avg     0.9693    0.9667    0.9669        60
# Rodada: 1	Seed: 8968	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9643    1.0000    0.9818        27
#     positive     1.0000    0.9697    0.9846        33
#
#     accuracy                         0.9833        60
#    macro avg     0.9821    0.9848    0.9832        60
# weighted avg     0.9839    0.9833    0.9834        60
# Rodada: 2	Seed: 8442	Score: 0.9333333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9459    0.9459    0.9459        37
#     positive     0.9130    0.9130    0.9130        23
#
#     accuracy                         0.9333        60
#    macro avg     0.9295    0.9295    0.9295        60
# weighted avg     0.9333    0.9333    0.9333        60
# Rodada: 3	Seed: 1729	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9697    0.9697    0.9697        33
#     positive     0.9630    0.9630    0.9630        27
#
#     accuracy                         0.9667        60
#    macro avg     0.9663    0.9663    0.9663        60
# weighted avg     0.9667    0.9667    0.9667        60
# Rodada: 4	Seed: 290	Score: 0.9166666666666666
#               precision    recall  f1-score   support
#
#     negative     0.9231    0.9474    0.9351        38
#     positive     0.9048    0.8636    0.8837        22
#
#     accuracy                         0.9167        60
#    macro avg     0.9139    0.9055    0.9094        60
# weighted avg     0.9164    0.9167    0.9162        60
# Rodada: 5	Seed: 490	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        27
#     positive     1.0000    1.0000    1.0000        33
#
#     accuracy                         1.0000        60
#    macro avg     1.0000    1.0000    1.0000        60
# weighted avg     1.0000    1.0000    1.0000        60
# Rodada: 6	Seed: 2128	Score: 0.95
#               precision    recall  f1-score   support
#
#     negative     0.9231    0.9600    0.9412        25
#     positive     0.9706    0.9429    0.9565        35
#
#     accuracy                         0.9500        60
#    macro avg     0.9468    0.9514    0.9488        60
# weighted avg     0.9508    0.9500    0.9501        60
# Rodada: 7	Seed: 1167	Score: 0.95
#               precision    recall  f1-score   support
#
#     negative     0.9091    1.0000    0.9524        30
#     positive     1.0000    0.9000    0.9474        30
#
#     accuracy                         0.9500        60
#    macro avg     0.9545    0.9500    0.9499        60
# weighted avg     0.9545    0.9500    0.9499        60
# Rodada: 8	Seed: 8900	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9459    0.9722        37
#     positive     0.9200    1.0000    0.9583        23
#
#     accuracy                         0.9667        60
#    macro avg     0.9600    0.9730    0.9653        60
# weighted avg     0.9693    0.9667    0.9669        60
# Rodada: 9	Seed: 5078	Score: 0.95
#               precision    recall  f1-score   support
#
#     negative     0.9667    0.9355    0.9508        31
#     positive     0.9333    0.9655    0.9492        29
#
#     accuracy                         0.9500        60
#    macro avg     0.9500    0.9505    0.9500        60
# weighted avg     0.9506    0.9500    0.9500        60
# Rodada: 10	Seed: 1359	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9355    1.0000    0.9667        29
#     positive     1.0000    0.9355    0.9667        31
#
#     accuracy                         0.9667        60
#    macro avg     0.9677    0.9677    0.9667        60
# weighted avg     0.9688    0.9667    0.9667        60
# Rodada: 11	Seed: 894	Score: 0.9333333333333333
#               precision    recall  f1-score   support
#
#     negative     0.9091    0.9677    0.9375        31
#     positive     0.9630    0.8966    0.9286        29
#
#     accuracy                         0.9333        60
#    macro avg     0.9360    0.9321    0.9330        60
# weighted avg     0.9351    0.9333    0.9332        60
# Rodada: 12	Seed: 7809	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9643    0.9818        28
#     positive     0.9697    1.0000    0.9846        32
#
#     accuracy                         0.9833        60
#    macro avg     0.9848    0.9821    0.9832        60
# weighted avg     0.9838    0.9833    0.9833        60
# Rodada: 13	Seed: 6990	Score: 0.95
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9000    0.9474        30
#     positive     0.9091    1.0000    0.9524        30
#
#     accuracy                         0.9500        60
#    macro avg     0.9545    0.9500    0.9499        60
# weighted avg     0.9545    0.9500    0.9499        60
# Rodada: 14	Seed: 3623	Score: 0.95
#               precision    recall  f1-score   support
#
#     negative     0.9394    0.9688    0.9538        32
#     positive     0.9630    0.9286    0.9455        28
#
#     accuracy                         0.9500        60
#    macro avg     0.9512    0.9487    0.9497        60
# weighted avg     0.9504    0.9500    0.9499        60
# Rodada: 15	Seed: 5906	Score: 0.95
#               precision    recall  f1-score   support
#
#     negative     0.8929    1.0000    0.9434        25
#     positive     1.0000    0.9143    0.9552        35
#
#     accuracy                         0.9500        60
#    macro avg     0.9464    0.9571    0.9493        60
# weighted avg     0.9554    0.9500    0.9503        60
# Rodada: 16	Seed: 1687	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9259    0.9615        27
#     positive     0.9429    1.0000    0.9706        33
#
#     accuracy                         0.9667        60
#    macro avg     0.9714    0.9630    0.9661        60
# weighted avg     0.9686    0.9667    0.9665        60
# Rodada: 17	Seed: 7080	Score: 0.9833333333333333
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9630    0.9811        27
#     positive     0.9706    1.0000    0.9851        33
#
#     accuracy                         0.9833        60
#    macro avg     0.9853    0.9815    0.9831        60
# weighted avg     0.9838    0.9833    0.9833        60
# Rodada: 18	Seed: 5473	Score: 0.9666666666666667
#               precision    recall  f1-score   support
#
#     negative     0.9677    0.9677    0.9677        31
#     positive     0.9655    0.9655    0.9655        29
#
#     accuracy                         0.9667        60
#    macro avg     0.9666    0.9666    0.9666        60
# weighted avg     0.9667    0.9667    0.9667        60
# Rodada: 19	Seed: 7854	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        35
#     positive     1.0000    1.0000    1.0000        25
#
#     accuracy                         1.0000        60
#    macro avg     1.0000    1.0000    1.0000        60
# weighted avg     1.0000    1.0000    1.0000        60

# %%
acc_df
# Out:
#     all channels  some channels
# 0       1.000000       0.966667
# 1       0.983333       0.983333
# 2       0.950000       0.933333
# 3       0.983333       0.966667
# 4       0.900000       0.916667
# 5       1.000000       1.000000
# 6       0.966667       0.950000
# 7       0.900000       0.950000
# 8       0.933333       0.966667
# 9       0.950000       0.950000
# 10      0.983333       0.966667
# 11      0.933333       0.933333
# 12      0.966667       0.983333
# 13      0.916667       0.950000
# 14      0.966667       0.950000
# 15      0.950000       0.950000
# 16      0.983333       0.966667
# 17      0.983333       0.983333
# 18      0.983333       0.966667
# 19      0.966667       1.000000

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count     20.000000      20.000000
# mean       0.960000       0.961667
# std        0.030301       0.021697
# min        0.900000       0.916667
# 25%        0.945833       0.950000
# 50%        0.966667       0.966667
# 75%        0.983333       0.970833
# max        1.000000       1.000000
