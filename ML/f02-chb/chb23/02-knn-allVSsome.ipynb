# %% [markdown]
# # KNN CHB23 _All VS Some_
#
# Comparando o resultado de 20 rodadas de classificação com KNN entre o modelo treinado com todos os 18 canais e o modelo treinado com apenas os 6 no qual obteve melhor desempenho
#
# ## importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
# Carregando chb
chb_df = pd.read_csv('./chb23_com_dwt.csv')
target_s = chb_df.pop('target')

some_channels = ['2', '3', '6', '7', '10', '14']

# Filtrando colunas do chb que são referentes aos canais em some_channels
some_columns = [column for column in chb_df.columns if column.split('-')[-1] in some_channels]

# Para 20 rodadas com todos os canais
X_all = chb_df.values

# Para 20 rodadas com os 6 canais
X_some = chb_df[some_columns].values

# A classificação não muda para ambos os casos
y = target_s.values

# Carregando sementes
seed_array = np.load('./../20_seeds.npy')
print(f'seeds: {seed_array}')
# Out:
# seeds: [4382 8968 8442 1729  290  490 2128 1167 8900 5078 1359  894 7809 6990
#  3623 5906 1687 7080 5473 7854]

# %% [markdown]
# ## 20 rodadas com todos os canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

# Formando dataframe de acurácias
acc_df = pd.DataFrame(data=acc_list, columns=['all channels'])
# Out:
# Rodada: 0	Seed: 4382	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        55
#     positive     1.0000    1.0000    1.0000        70
#
#     accuracy                         1.0000       125
#    macro avg     1.0000    1.0000    1.0000       125
# weighted avg     1.0000    1.0000    1.0000       125
# Rodada: 1	Seed: 8968	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9420    0.9701        69
#     positive     0.9333    1.0000    0.9655        56
#
#     accuracy                         0.9680       125
#    macro avg     0.9667    0.9710    0.9678       125
# weighted avg     0.9701    0.9680    0.9681       125
# Rodada: 2	Seed: 8442	Score: 0.984
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9692    0.9844        65
#     positive     0.9677    1.0000    0.9836        60
#
#     accuracy                         0.9840       125
#    macro avg     0.9839    0.9846    0.9840       125
# weighted avg     0.9845    0.9840    0.9840       125
# Rodada: 3	Seed: 1729	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9355    0.9667        62
#     positive     0.9403    1.0000    0.9692        63
#
#     accuracy                         0.9680       125
#    macro avg     0.9701    0.9677    0.9679       125
# weighted avg     0.9699    0.9680    0.9680       125
# Rodada: 4	Seed: 290	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     0.9836    0.9524    0.9677        63
#     positive     0.9531    0.9839    0.9683        62
#
#     accuracy                         0.9680       125
#    macro avg     0.9684    0.9681    0.9680       125
# weighted avg     0.9685    0.9680    0.9680       125
# Rodada: 5	Seed: 490	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9494    0.9740        79
#     positive     0.9200    1.0000    0.9583        46
#
#     accuracy                         0.9680       125
#    macro avg     0.9600    0.9747    0.9662       125
# weighted avg     0.9706    0.9680    0.9683       125
# Rodada: 6	Seed: 2128	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     0.9583    0.9857    0.9718        70
#     positive     0.9811    0.9455    0.9630        55
#
#     accuracy                         0.9680       125
#    macro avg     0.9697    0.9656    0.9674       125
# weighted avg     0.9684    0.9680    0.9679       125
# Rodada: 7	Seed: 1167	Score: 0.984
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9683    0.9839        63
#     positive     0.9688    1.0000    0.9841        62
#
#     accuracy                         0.9840       125
#    macro avg     0.9844    0.9841    0.9840       125
# weighted avg     0.9845    0.9840    0.9840       125
# Rodada: 8	Seed: 8900	Score: 0.992
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9831    0.9915        59
#     positive     0.9851    1.0000    0.9925        66
#
#     accuracy                         0.9920       125
#    macro avg     0.9925    0.9915    0.9920       125
# weighted avg     0.9921    0.9920    0.9920       125
# Rodada: 9	Seed: 5078	Score: 0.96
#               precision    recall  f1-score   support
#
#     negative     0.9841    0.9394    0.9612        66
#     positive     0.9355    0.9831    0.9587        59
#
#     accuracy                         0.9600       125
#    macro avg     0.9598    0.9612    0.9600       125
# weighted avg     0.9612    0.9600    0.9600       125
# Rodada: 10	Seed: 1359	Score: 0.976
#               precision    recall  f1-score   support
#
#     negative     0.9825    0.9655    0.9739        58
#     positive     0.9706    0.9851    0.9778        67
#
#     accuracy                         0.9760       125
#    macro avg     0.9765    0.9753    0.9758       125
# weighted avg     0.9761    0.9760    0.9760       125
# Rodada: 11	Seed: 894	Score: 0.952
#               precision    recall  f1-score   support
#
#     negative     0.9683    0.9385    0.9531        65
#     positive     0.9355    0.9667    0.9508        60
#
#     accuracy                         0.9520       125
#    macro avg     0.9519    0.9526    0.9520       125
# weighted avg     0.9525    0.9520    0.9520       125
# Rodada: 12	Seed: 7809	Score: 0.984
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9692    0.9844        65
#     positive     0.9677    1.0000    0.9836        60
#
#     accuracy                         0.9840       125
#    macro avg     0.9839    0.9846    0.9840       125
# weighted avg     0.9845    0.9840    0.9840       125
# Rodada: 13	Seed: 6990	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     0.9828    0.9500    0.9661        60
#     positive     0.9552    0.9846    0.9697        65
#
#     accuracy                         0.9680       125
#    macro avg     0.9690    0.9673    0.9679       125
# weighted avg     0.9684    0.9680    0.9680       125
# Rodada: 14	Seed: 3623	Score: 0.992
#               precision    recall  f1-score   support
#
#     negative     0.9828    1.0000    0.9913        57
#     positive     1.0000    0.9853    0.9926        68
#
#     accuracy                         0.9920       125
#    macro avg     0.9914    0.9926    0.9919       125
# weighted avg     0.9921    0.9920    0.9920       125
# Rodada: 15	Seed: 5906	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9394    0.9688        66
#     positive     0.9365    1.0000    0.9672        59
#
#     accuracy                         0.9680       125
#    macro avg     0.9683    0.9697    0.9680       125
# weighted avg     0.9700    0.9680    0.9680       125
# Rodada: 16	Seed: 1687	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     0.9833    0.9516    0.9672        62
#     positive     0.9538    0.9841    0.9688        63
#
#     accuracy                         0.9680       125
#    macro avg     0.9686    0.9679    0.9680       125
# weighted avg     0.9685    0.9680    0.9680       125
# Rodada: 17	Seed: 7080	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     0.9683    0.9683    0.9683        63
#     positive     0.9677    0.9677    0.9677        62
#
#     accuracy                         0.9680       125
#    macro avg     0.9680    0.9680    0.9680       125
# weighted avg     0.9680    0.9680    0.9680       125
# Rodada: 18	Seed: 5473	Score: 0.96
#               precision    recall  f1-score   support
#
#     negative     0.9403    0.9844    0.9618        64
#     positive     0.9828    0.9344    0.9580        61
#
#     accuracy                         0.9600       125
#    macro avg     0.9615    0.9594    0.9599       125
# weighted avg     0.9610    0.9600    0.9600       125
# Rodada: 19	Seed: 7854	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     0.9459    1.0000    0.9722        70
#     positive     1.0000    0.9273    0.9623        55
#
#     accuracy                         0.9680       125
#    macro avg     0.9730    0.9636    0.9672       125
# weighted avg     0.9697    0.9680    0.9678       125

# %% [markdown]
# ## 20 rodadas com apenas 6 canais

# %%
acc_list = []
for turn, seed in enumerate(seed_array):
    # Separando dados
    X_train, X_test, y_train, y_test = train_test_split(X_some, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    model = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = model.predict(X_test)

    # Salvando acurácia da predição
    acc = model.score(X_test, y_test)
    acc_list.append(acc)

    print(f'Rodada: {turn}\tSeed: {seed}\tScore: {acc}')

    print(classification_report(
        y_pred=y_pred,
        y_true=y_test,
        target_names=['negative', 'positive'],
        digits=4
    ))

    plot_confusion_matrix(
        estimator=model,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=['negative', 'positive']
    )
    plt.show()

acc_df['some channels'] = acc_list
# Out:
# Rodada: 0	Seed: 4382	Score: 0.992
#               precision    recall  f1-score   support
#
#     negative     0.9821    1.0000    0.9910        55
#     positive     1.0000    0.9857    0.9928        70
#
#     accuracy                         0.9920       125
#    macro avg     0.9911    0.9929    0.9919       125
# weighted avg     0.9921    0.9920    0.9920       125
# Rodada: 1	Seed: 8968	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9420    0.9701        69
#     positive     0.9333    1.0000    0.9655        56
#
#     accuracy                         0.9680       125
#    macro avg     0.9667    0.9710    0.9678       125
# weighted avg     0.9701    0.9680    0.9681       125
# Rodada: 2	Seed: 8442	Score: 0.976
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9538    0.9764        65
#     positive     0.9524    1.0000    0.9756        60
#
#     accuracy                         0.9760       125
#    macro avg     0.9762    0.9769    0.9760       125
# weighted avg     0.9771    0.9760    0.9760       125
# Rodada: 3	Seed: 1729	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     0.9833    0.9516    0.9672        62
#     positive     0.9538    0.9841    0.9688        63
#
#     accuracy                         0.9680       125
#    macro avg     0.9686    0.9679    0.9680       125
# weighted avg     0.9685    0.9680    0.9680       125
# Rodada: 4	Seed: 290	Score: 0.992
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9841    0.9920        63
#     positive     0.9841    1.0000    0.9920        62
#
#     accuracy                         0.9920       125
#    macro avg     0.9921    0.9921    0.9920       125
# weighted avg     0.9921    0.9920    0.9920       125
# Rodada: 5	Seed: 490	Score: 0.976
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9620    0.9806        79
#     positive     0.9388    1.0000    0.9684        46
#
#     accuracy                         0.9760       125
#    macro avg     0.9694    0.9810    0.9745       125
# weighted avg     0.9775    0.9760    0.9761       125
# Rodada: 6	Seed: 2128	Score: 0.976
#               precision    recall  f1-score   support
#
#     negative     0.9718    0.9857    0.9787        70
#     positive     0.9815    0.9636    0.9725        55
#
#     accuracy                         0.9760       125
#    macro avg     0.9767    0.9747    0.9756       125
# weighted avg     0.9761    0.9760    0.9760       125
# Rodada: 7	Seed: 1167	Score: 0.992
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9841    0.9920        63
#     positive     0.9841    1.0000    0.9920        62
#
#     accuracy                         0.9920       125
#    macro avg     0.9921    0.9921    0.9920       125
# weighted avg     0.9921    0.9920    0.9920       125
# Rodada: 8	Seed: 8900	Score: 0.992
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9831    0.9915        59
#     positive     0.9851    1.0000    0.9925        66
#
#     accuracy                         0.9920       125
#    macro avg     0.9925    0.9915    0.9920       125
# weighted avg     0.9921    0.9920    0.9920       125
# Rodada: 9	Seed: 5078	Score: 0.968
#               precision    recall  f1-score   support
#
#     negative     0.9844    0.9545    0.9692        66
#     positive     0.9508    0.9831    0.9667        59
#
#     accuracy                         0.9680       125
#    macro avg     0.9676    0.9688    0.9679       125
# weighted avg     0.9685    0.9680    0.9680       125
# Rodada: 10	Seed: 1359	Score: 0.984
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9655    0.9825        58
#     positive     0.9710    1.0000    0.9853        67
#
#     accuracy                         0.9840       125
#    macro avg     0.9855    0.9828    0.9839       125
# weighted avg     0.9845    0.9840    0.9840       125
# Rodada: 11	Seed: 894	Score: 0.984
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9692    0.9844        65
#     positive     0.9677    1.0000    0.9836        60
#
#     accuracy                         0.9840       125
#    macro avg     0.9839    0.9846    0.9840       125
# weighted avg     0.9845    0.9840    0.9840       125
# Rodada: 12	Seed: 7809	Score: 0.976
#               precision    recall  f1-score   support
#
#     negative     0.9844    0.9692    0.9767        65
#     positive     0.9672    0.9833    0.9752        60
#
#     accuracy                         0.9760       125
#    macro avg     0.9758    0.9763    0.9760       125
# weighted avg     0.9761    0.9760    0.9760       125
# Rodada: 13	Seed: 6990	Score: 0.976
#               precision    recall  f1-score   support
#
#     negative     0.9831    0.9667    0.9748        60
#     positive     0.9697    0.9846    0.9771        65
#
#     accuracy                         0.9760       125
#    macro avg     0.9764    0.9756    0.9759       125
# weighted avg     0.9761    0.9760    0.9760       125
# Rodada: 14	Seed: 3623	Score: 1.0
#               precision    recall  f1-score   support
#
#     negative     1.0000    1.0000    1.0000        57
#     positive     1.0000    1.0000    1.0000        68
#
#     accuracy                         1.0000       125
#    macro avg     1.0000    1.0000    1.0000       125
# weighted avg     1.0000    1.0000    1.0000       125
# Rodada: 15	Seed: 5906	Score: 0.984
#               precision    recall  f1-score   support
#
#     negative     1.0000    0.9697    0.9846        66
#     positive     0.9672    1.0000    0.9833        59
#
#     accuracy                         0.9840       125
#    macro avg     0.9836    0.9848    0.9840       125
# weighted avg     0.9845    0.9840    0.9840       125
# Rodada: 16	Seed: 1687	Score: 0.976
#               precision    recall  f1-score   support
#
#     negative     0.9836    0.9677    0.9756        62
#     positive     0.9688    0.9841    0.9764        63
#
#     accuracy                         0.9760       125
#    macro avg     0.9762    0.9759    0.9760       125
# weighted avg     0.9761    0.9760    0.9760       125
# Rodada: 17	Seed: 7080	Score: 0.976
#               precision    recall  f1-score   support
#
#     negative     0.9839    0.9683    0.9760        63
#     positive     0.9683    0.9839    0.9760        62
#
#     accuracy                         0.9760       125
#    macro avg     0.9761    0.9761    0.9760       125
# weighted avg     0.9761    0.9760    0.9760       125
# Rodada: 18	Seed: 5473	Score: 0.984
#               precision    recall  f1-score   support
#
#     negative     0.9844    0.9844    0.9844        64
#     positive     0.9836    0.9836    0.9836        61
#
#     accuracy                         0.9840       125
#    macro avg     0.9840    0.9840    0.9840       125
# weighted avg     0.9840    0.9840    0.9840       125
# Rodada: 19	Seed: 7854	Score: 0.992
#               precision    recall  f1-score   support
#
#     negative     0.9859    1.0000    0.9929        70
#     positive     1.0000    0.9818    0.9908        55
#
#     accuracy                         0.9920       125
#    macro avg     0.9930    0.9909    0.9919       125
# weighted avg     0.9921    0.9920    0.9920       125

# %%
acc_df
# Out:
#     all channels  some channels
# 0          1.000          0.992
# 1          0.968          0.968
# 2          0.984          0.976
# 3          0.968          0.968
# 4          0.968          0.992
# 5          0.968          0.976
# 6          0.968          0.976
# 7          0.984          0.992
# 8          0.992          0.992
# 9          0.960          0.968
# 10         0.976          0.984
# 11         0.952          0.984
# 12         0.984          0.976
# 13         0.968          0.976
# 14         0.992          1.000
# 15         0.968          0.984
# 16         0.968          0.976
# 17         0.968          0.976
# 18         0.960          0.984
# 19         0.968          0.992

# %%
acc_df.boxplot(figsize=(12, 6))
acc_df.describe()
# Out:
#        all channels  some channels
# count      20.00000      20.000000
# mean        0.97320       0.981600
# std         0.01225       0.009394
# min         0.95200       0.968000
# 25%         0.96800       0.976000
# 50%         0.96800       0.980000
# 75%         0.98400       0.992000
# max         1.00000       1.000000
