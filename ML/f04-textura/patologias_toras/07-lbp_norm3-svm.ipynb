# %% [markdown]
# # 07 - Classificando patologias em toras usando combinação de `LBP + SVM` e normalizando amostras pela soma de cada elemento do histograma
#
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from zipfile import ZipFile
from skimage import io
from skimage.feature import local_binary_pattern

# Parâmetros do LBP
METHOD = 'nri_uniform'
RADIUS = 1
N_POINTS = 8

TARGET_NAMES = {'normal': 0,
                'broca':1,
                'fissura': 2,
                'musgo': 3}

# %% [markdown]
# ## Processando imagens

# %%
path_dict = {name: [] for name in TARGET_NAMES}

with ZipFile('./patologias_toras.zip') as zip_file:
  for path in zip_file.namelist():
    # a pasta de cada amostra é o segundo elemento do split
    folder = path.split('/')[1]
    # Separando amostras por classe
    if folder in TARGET_NAMES:
      path_dict[folder].append(f'./patologias_toras.zip/{path}')


# Mostrando quantidade de amostras por classe
qtd_amostras_p_classe = []
for target in path_dict:
  n_amostras = len(path_dict[target])
  print(f'{target}: {n_amostras} amostras')

  qtd_amostras_p_classe.append(n_amostras)

N_MIN_DE_AMOSTRAS = min(qtd_amostras_p_classe)
amostra = []

for target_name in TARGET_NAMES:
  path_list = path_dict[target_name]
  path_list_slice = path_list[:N_MIN_DE_AMOSTRAS]
  
  for path in path_list_slice:
    img = io.imread(path, as_gray=True)
    
    lbp = local_binary_pattern(image=img, P=N_POINTS, R=RADIUS, method=METHOD).flatten()
    
    hist = pd.Series(lbp).value_counts().sort_index()
    arr = np.zeros(59)
    for i in hist.index:
      arr[int(i)] = hist[i]

    # Realizando normalização pela soma de cada elemento do histograma
    arr /= arr.sum()

    df = pd.DataFrame(data=[arr])
    df['target'] = TARGET_NAMES[target_name]
    amostra.append(df)

data = pd.concat(amostra, ignore_index=True)
data.to_csv('./csvs/lbp_norm3_toras.csv')
data
# Out:
# normal: 107 amostras
# broca: 90 amostras
# fissura: 109 amostras
# musgo: 111 amostras
#             0         1         2         3         4         5         6  \
# 0    0.062339  0.020684  0.002552  0.015116  0.003219  0.021569  0.002868
# 1    0.067556  0.022592  0.003121  0.016275  0.003088  0.023164  0.003025
# 2    0.062777  0.025827  0.002639  0.012041  0.003192  0.026918  0.002728
# 3    0.066076  0.024677  0.003045  0.014568  0.003464  0.025366  0.002964
# 4    0.065848  0.025710  0.002824  0.015218  0.003266  0.026152  0.002895
# ..        ...       ...       ...       ...       ...       ...       ...
# 355  0.055930  0.024259  0.002415  0.011399  0.002808  0.023978  0.002246
# 356  0.062714  0.019921  0.002953  0.014799  0.003117  0.019884  0.002825
# 357  0.061074  0.022898  0.002437  0.013924  0.002824  0.024058  0.002127
# 358  0.062252  0.021824  0.002702  0.013319  0.003248  0.021764  0.002850
# 359  0.064162  0.022068  0.002698  0.013075  0.002767  0.021895  0.003148
#
#             7         8         9  ...        50        51        52  \
# 0    0.016283  0.003188  0.009106  ...  0.014097  0.004920  0.017840
# 1    0.016869  0.002724  0.007599  ...  0.014031  0.004255  0.019073
# 2    0.012305  0.003084  0.008778  ...  0.010976  0.005282  0.022085
# 3    0.015250  0.002973  0.008439  ...  0.013148  0.004666  0.022506
# 4    0.014964  0.003022  0.008147  ...  0.013099  0.004046  0.022672
# ..        ...       ...       ...  ...       ...       ...       ...
# 355  0.010332  0.003032  0.011175  ...  0.008929  0.003257  0.018812
# 356  0.014508  0.002789  0.009222  ...  0.014179  0.003882  0.016768
# 357  0.012919  0.002553  0.009824  ...  0.012841  0.004757  0.018256
# 358  0.012610  0.002599  0.010159  ...  0.013821  0.004075  0.018457
# 359  0.013213  0.003321  0.011207  ...  0.012971  0.004946  0.017122
#
#            53        54        55        56        57        58  target
# 0    0.004161  0.013598  0.005019  0.018280  0.074520  0.126319       0
# 1    0.004641  0.013473  0.004054  0.019374  0.071963  0.127372       0
# 2    0.004384  0.010007  0.004933  0.022278  0.072940  0.126353       0
# 3    0.004403  0.013219  0.004442  0.021941  0.076049  0.130858       0
# 4    0.003753  0.013573  0.004189  0.022565  0.071876  0.126972       0
# ..        ...       ...       ...       ...       ...       ...     ...
# 355  0.003145  0.009434  0.004268  0.018924  0.065813  0.113938       3
# 356  0.003718  0.013833  0.003754  0.016221  0.069585  0.124317       3
# 357  0.002940  0.011604  0.004680  0.018721  0.065251  0.120755       3
# 358  0.003514  0.012787  0.004504  0.019432  0.070358  0.124533       3
# 359  0.003044  0.011311  0.003736  0.017398  0.066307  0.121476       3
#
# [360 rows x 60 columns]

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score,
                             classification_report,
                             confusion_matrix,
                             f1_score,
                             plot_confusion_matrix)

# %% [markdown]
# ## Realizando 30 rodadas de classificação

# %%
df = pd.read_csv('./csvs/lbp_norm3_toras.csv')
y = df.pop('target').values
X = df.values

# Gerando 30 sementes "aleatórias" dentro do intervalo [0, 8000)
seed_arr = np.random.randint(8000, size=30)

acc_e_f1_por_rodada = []
confu_matrices = []

for rodada, seed in enumerate(seed_arr):
  # separando dados
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

  clf = make_pipeline(StandardScaler(), SVC()).fit(X_train, y_train)
  y_pred = clf.predict(X_test)
  
  # Adicionando resultados à respectiva lista
  acc_e_f1_por_rodada.append(
    [accuracy_score(y_test, y_pred)]
    + list(f1_score(y_test, y_pred, average=None)))

  confu_matrices.append(
    confusion_matrix(y_test, y_pred, normalize='true'))

  print(f'Rodada {rodada}\t-\tSeed {seed}')
  print(
    classification_report(
      y_true=y_test,
      y_pred=y_pred,
      target_names=TARGET_NAMES))

  plot_confusion_matrix(
    estimator=clf,
    X=X_test,
    y_true=y_test,
    display_labels=TARGET_NAMES,
    xticks_rotation=30,
    normalize='true')
  
  plt.show()
# Out:
# Rodada 0	-	Seed 7163
#               precision    recall  f1-score   support
#
#       normal       0.68      0.81      0.74        21
#        broca       0.62      0.70      0.65        23
#      fissura       0.88      0.65      0.75        34
#        musgo       0.91      0.97      0.94        30
#
#     accuracy                           0.78       108
#    macro avg       0.77      0.78      0.77       108
# weighted avg       0.79      0.78      0.78       108
# Rodada 1	-	Seed 450
#               precision    recall  f1-score   support
#
#       normal       0.68      0.88      0.77        17
#        broca       0.76      0.56      0.64        34
#      fissura       0.71      0.81      0.76        31
#        musgo       0.88      0.88      0.88        26
#
#     accuracy                           0.76       108
#    macro avg       0.76      0.78      0.76       108
# weighted avg       0.76      0.76      0.75       108
# Rodada 2	-	Seed 7286
#               precision    recall  f1-score   support
#
#       normal       0.88      0.79      0.84        29
#        broca       0.69      0.71      0.70        28
#      fissura       0.73      0.79      0.76        24
#        musgo       0.85      0.85      0.85        27
#
#     accuracy                           0.79       108
#    macro avg       0.79      0.79      0.79       108
# weighted avg       0.79      0.79      0.79       108
# Rodada 3	-	Seed 505
#               precision    recall  f1-score   support
#
#       normal       0.85      0.91      0.88        32
#        broca       0.62      0.60      0.61        25
#      fissura       0.64      0.64      0.64        25
#        musgo       0.84      0.81      0.82        26
#
#     accuracy                           0.75       108
#    macro avg       0.74      0.74      0.74       108
# weighted avg       0.75      0.75      0.75       108
# Rodada 4	-	Seed 1270
#               precision    recall  f1-score   support
#
#       normal       0.93      0.84      0.89        32
#        broca       0.84      0.47      0.60        34
#      fissura       0.47      0.95      0.63        19
#        musgo       0.86      0.83      0.84        23
#
#     accuracy                           0.74       108
#    macro avg       0.78      0.77      0.74       108
# weighted avg       0.81      0.74      0.74       108
# Rodada 5	-	Seed 401
#               precision    recall  f1-score   support
#
#       normal       0.93      0.93      0.93        27
#        broca       0.87      0.52      0.65        25
#      fissura       0.60      0.78      0.68        27
#        musgo       0.84      0.90      0.87        29
#
#     accuracy                           0.79       108
#    macro avg       0.81      0.78      0.78       108
# weighted avg       0.81      0.79      0.78       108
# Rodada 6	-	Seed 4712
#               precision    recall  f1-score   support
#
#       normal       0.83      0.86      0.85        29
#        broca       0.75      0.58      0.65        31
#      fissura       0.57      0.70      0.63        23
#        musgo       0.85      0.88      0.86        25
#
#     accuracy                           0.75       108
#    macro avg       0.75      0.75      0.75       108
# weighted avg       0.76      0.75      0.75       108
# Rodada 7	-	Seed 5621
#               precision    recall  f1-score   support
#
#       normal       0.88      0.66      0.75        32
#        broca       0.59      0.50      0.54        26
#      fissura       0.53      0.76      0.62        25
#        musgo       0.85      0.88      0.86        25
#
#     accuracy                           0.69       108
#    macro avg       0.71      0.70      0.69       108
# weighted avg       0.72      0.69      0.70       108
# Rodada 8	-	Seed 241
#               precision    recall  f1-score   support
#
#       normal       0.94      0.85      0.89        34
#        broca       0.58      0.64      0.61        22
#      fissura       0.69      0.72      0.71        25
#        musgo       0.85      0.85      0.85        27
#
#     accuracy                           0.78       108
#    macro avg       0.77      0.77      0.76       108
# weighted avg       0.79      0.78      0.78       108
# Rodada 9	-	Seed 6553
#               precision    recall  f1-score   support
#
#       normal       0.84      0.91      0.87        23
#        broca       0.76      0.46      0.57        35
#      fissura       0.53      0.83      0.65        24
#        musgo       0.92      0.85      0.88        26
#
#     accuracy                           0.73       108
#    macro avg       0.76      0.76      0.74       108
# weighted avg       0.76      0.73      0.73       108
# Rodada 10	-	Seed 728
#               precision    recall  f1-score   support
#
#       normal       0.91      0.91      0.91        23
#        broca       0.48      0.75      0.59        16
#      fissura       0.73      0.47      0.57        34
#        musgo       0.84      0.91      0.88        35
#
#     accuracy                           0.75       108
#    macro avg       0.74      0.76      0.74       108
# weighted avg       0.77      0.75      0.75       108
# Rodada 11	-	Seed 4688
#               precision    recall  f1-score   support
#
#       normal       0.63      0.74      0.68        23
#        broca       0.69      0.55      0.61        33
#      fissura       0.63      0.61      0.62        28
#        musgo       0.82      0.96      0.88        24
#
#     accuracy                           0.69       108
#    macro avg       0.69      0.71      0.70       108
# weighted avg       0.69      0.69      0.69       108
# Rodada 12	-	Seed 7521
#               precision    recall  f1-score   support
#
#       normal       0.96      0.79      0.87        29
#        broca       0.52      0.67      0.58        21
#      fissura       0.72      0.72      0.72        29
#        musgo       1.00      0.97      0.98        29
#
#     accuracy                           0.80       108
#    macro avg       0.80      0.79      0.79       108
# weighted avg       0.82      0.80      0.80       108
# Rodada 13	-	Seed 6037
#               precision    recall  f1-score   support
#
#       normal       0.88      0.76      0.81        29
#        broca       0.76      0.70      0.73        23
#      fissura       0.62      0.72      0.67        25
#        musgo       0.85      0.90      0.88        31
#
#     accuracy                           0.78       108
#    macro avg       0.78      0.77      0.77       108
# weighted avg       0.79      0.78      0.78       108
# Rodada 14	-	Seed 1555
#               precision    recall  f1-score   support
#
#       normal       0.66      0.81      0.72        26
#        broca       0.62      0.67      0.64        27
#      fissura       0.91      0.59      0.71        34
#        musgo       0.76      0.90      0.83        21
#
#     accuracy                           0.72       108
#    macro avg       0.74      0.74      0.73       108
# weighted avg       0.75      0.72      0.72       108
# Rodada 15	-	Seed 7132
#               precision    recall  f1-score   support
#
#       normal       0.76      0.67      0.71        24
#        broca       0.59      0.52      0.55        31
#      fissura       0.49      0.69      0.57        26
#        musgo       0.91      0.78      0.84        27
#
#     accuracy                           0.66       108
#    macro avg       0.69      0.66      0.67       108
# weighted avg       0.68      0.66      0.66       108
# Rodada 16	-	Seed 3320
#               precision    recall  f1-score   support
#
#       normal       0.94      0.97      0.95        30
#        broca       0.89      0.70      0.78        23
#      fissura       0.66      0.85      0.74        27
#        musgo       0.92      0.79      0.85        28
#
#     accuracy                           0.83       108
#    macro avg       0.85      0.82      0.83       108
# weighted avg       0.85      0.83      0.84       108
# Rodada 17	-	Seed 3529
#               precision    recall  f1-score   support
#
#       normal       0.65      0.89      0.76        19
#        broca       0.59      0.52      0.55        25
#      fissura       0.68      0.48      0.57        31
#        musgo       0.79      0.91      0.85        33
#
#     accuracy                           0.69       108
#    macro avg       0.68      0.70      0.68       108
# weighted avg       0.69      0.69      0.68       108
# Rodada 18	-	Seed 154
#               precision    recall  f1-score   support
#
#       normal       1.00      0.73      0.85        30
#        broca       0.64      0.69      0.67        26
#      fissura       0.70      0.81      0.75        26
#        musgo       0.82      0.88      0.85        26
#
#     accuracy                           0.78       108
#    macro avg       0.79      0.78      0.78       108
# weighted avg       0.80      0.78      0.78       108
# Rodada 19	-	Seed 6565
#               precision    recall  f1-score   support
#
#       normal       0.88      0.86      0.87        35
#        broca       0.67      0.75      0.71        24
#      fissura       0.70      0.68      0.69        28
#        musgo       0.80      0.76      0.78        21
#
#     accuracy                           0.77       108
#    macro avg       0.76      0.76      0.76       108
# weighted avg       0.77      0.77      0.77       108
# Rodada 20	-	Seed 123
#               precision    recall  f1-score   support
#
#       normal       0.89      0.89      0.89        27
#        broca       0.75      0.54      0.63        28
#      fissura       0.63      0.81      0.71        27
#        musgo       0.85      0.85      0.85        26
#
#     accuracy                           0.77       108
#    macro avg       0.78      0.77      0.77       108
# weighted avg       0.78      0.77      0.77       108
# Rodada 21	-	Seed 3280
#               precision    recall  f1-score   support
#
#       normal       0.85      0.81      0.83        21
#        broca       0.66      0.73      0.69        26
#      fissura       0.72      0.64      0.68        28
#        musgo       0.85      0.88      0.87        33
#
#     accuracy                           0.77       108
#    macro avg       0.77      0.77      0.77       108
# weighted avg       0.77      0.77      0.77       108
# Rodada 22	-	Seed 2449
#               precision    recall  f1-score   support
#
#       normal       0.84      0.79      0.82        34
#        broca       0.71      0.40      0.51        30
#      fissura       0.52      0.68      0.59        22
#        musgo       0.73      1.00      0.85        22
#
#     accuracy                           0.70       108
#    macro avg       0.70      0.72      0.69       108
# weighted avg       0.72      0.70      0.69       108
# Rodada 23	-	Seed 4547
#               precision    recall  f1-score   support
#
#       normal       0.84      0.81      0.82        26
#        broca       0.53      0.76      0.63        21
#      fissura       0.67      0.56      0.61        32
#        musgo       0.92      0.83      0.87        29
#
#     accuracy                           0.73       108
#    macro avg       0.74      0.74      0.73       108
# weighted avg       0.75      0.73      0.74       108
# Rodada 24	-	Seed 2733
#               precision    recall  f1-score   support
#
#       normal       0.89      0.75      0.81        32
#        broca       0.56      0.83      0.67        23
#      fissura       0.82      0.69      0.75        26
#        musgo       0.92      0.85      0.88        27
#
#     accuracy                           0.78       108
#    macro avg       0.80      0.78      0.78       108
# weighted avg       0.81      0.78      0.78       108
# Rodada 25	-	Seed 3034
#               precision    recall  f1-score   support
#
#       normal       0.92      0.89      0.91        27
#        broca       0.70      0.68      0.69        28
#      fissura       0.79      0.77      0.78        30
#        musgo       0.85      0.96      0.90        23
#
#     accuracy                           0.81       108
#    macro avg       0.82      0.82      0.82       108
# weighted avg       0.81      0.81      0.81       108
# Rodada 26	-	Seed 1757
#               precision    recall  f1-score   support
#
#       normal       0.88      0.85      0.87        27
#        broca       0.65      0.68      0.67        25
#      fissura       0.82      0.69      0.75        26
#        musgo       0.82      0.93      0.87        30
#
#     accuracy                           0.80       108
#    macro avg       0.80      0.79      0.79       108
# weighted avg       0.80      0.80      0.79       108
# Rodada 27	-	Seed 7764
#               precision    recall  f1-score   support
#
#       normal       0.85      1.00      0.92        23
#        broca       0.94      0.55      0.70        29
#      fissura       0.63      0.88      0.73        25
#        musgo       0.97      0.90      0.93        31
#
#     accuracy                           0.82       108
#    macro avg       0.85      0.83      0.82       108
# weighted avg       0.86      0.82      0.82       108
# Rodada 28	-	Seed 1467
#               precision    recall  f1-score   support
#
#       normal       0.89      0.71      0.79        34
#        broca       0.67      0.73      0.70        22
#      fissura       0.72      0.82      0.77        28
#        musgo       0.84      0.88      0.86        24
#
#     accuracy                           0.78       108
#    macro avg       0.78      0.78      0.78       108
# weighted avg       0.79      0.78      0.78       108
# Rodada 29	-	Seed 3000
#               precision    recall  f1-score   support
#
#       normal       0.81      0.81      0.81        27
#        broca       0.61      0.54      0.57        26
#      fissura       0.71      0.74      0.73        27
#        musgo       0.87      0.93      0.90        28
#
#     accuracy                           0.76       108
#    macro avg       0.75      0.76      0.75       108
# weighted avg       0.75      0.76      0.76       108

# %% [markdown]
# ## Métricas do experimento

# %%
confusion_matrix_mean = np.mean(confu_matrices, axis=0)
confusion_matrix_std = np.std(confu_matrices, axis=0)

sns.heatmap(
    data=confusion_matrix_mean,
    cmap='Blues',
    vmin=0,
    vmax=1,
    annot=True,
    fmt='.4f',
    mask=confusion_matrix_mean == 0,
    xticklabels=TARGET_NAMES,
    yticklabels=TARGET_NAMES
    ).set(
        title='Matriz de confusão média',
        xlabel='Predicted label',
        ylabel='True label')

plt.show()

sns.heatmap(
    data=confusion_matrix_std,
    cmap='Blues',
    annot=True,
    fmt='.4f',
    mask=confusion_matrix_std == 0,
    xticklabels=TARGET_NAMES,
    yticklabels=TARGET_NAMES
    ).set(
        title='Desvio padrão da matriz de confusão',
        xlabel='Predicted label',
        ylabel='True label')

None

# %%
acc_df = pd.DataFrame(
  data=acc_e_f1_por_rodada,
  columns=['Acurácia'] + [f'f1-{name}' for name in TARGET_NAMES])

print(acc_df.describe())

acc_df.boxplot(rot=30)

acc_df.style.hide_index().background_gradient(cmap='Blues')
# Out:
#         Acurácia  f1-normal   f1-broca  f1-fissura   f1-musgo
# count  30.000000  30.000000  30.000000   30.000000  30.000000
# mean    0.758333   0.833376   0.636305    0.684102   0.868256
# std     0.041075   0.069117   0.061807    0.066210   0.037349
# min     0.657407   0.680000   0.510638    0.566038   0.780488
# 25%     0.733796   0.793554   0.589968    0.628483   0.846154
# 50%     0.768519   0.841259   0.643462    0.698396   0.864208
# 75%     0.777778   0.883631   0.684848    0.744806   0.883462
# max     0.833333   0.950820   0.780488    0.779661   0.982456
# <style  type="text/css" >
# #T_94e0400e_0f44_11ec_8db2_8de1283b1118row0_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row8_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row13_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row18_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row24_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row27_col2,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row28_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row28_col2{
#             background-color:  #3282be;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row0_col1{
#             background-color:  #cddff1;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row0_col2,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row21_col3,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row23_col1{
#             background-color:  #61a7d2;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row0_col3{
#             background-color:  #0e59a2;
#             color:  #f1f1f1;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row0_col4{
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row1_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row18_col2,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row24_col2,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row25_col4,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row26_col2,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row29_col0{
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row1_col1{
#             background-color:  #add0e6;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row1_col2,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row9_col4,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row24_col1{
#             background-color:  #6dafd7;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row1_col3,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row25_col0{
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row1_col4,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row11_col4,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row24_col4{
#             background-color:  #66abd4;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row2_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row5_col0{
#             background-color:  #2474b7;
#             color:  #f1f1f1;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row2_col1,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row29_col4{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row2_col2{
#             background-color:  #2c7cba;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row2_col3,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row5_col1{
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row2_col4,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row8_col4,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row18_col4{
#             background-color:  #a5cde3;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row3_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row6_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row10_col0{
#             background-color:  #63a8d3;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row3_col1{
#             background-color:  #2575b7;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row3_col2{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row3_col3,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row4_col2{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row3_col4{
#             background-color:  #cde0f1;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row4_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row10_col4{
#             background-color:  #75b4d8;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row4_col1{
#             background-color:  #1f6eb3;
#             color:  #f1f1f1;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row4_col3{
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row4_col4,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row17_col4{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row5_col2{
#             background-color:  #65aad4;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row5_col3{
#             background-color:  #64a9d3;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row5_col4{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row6_col1{
#             background-color:  #4493c7;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row6_col2{
#             background-color:  #60a7d2;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row6_col3{
#             background-color:  #bad6eb;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row6_col4,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row7_col4{
#             background-color:  #91c3de;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row7_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row11_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row17_col0{
#             background-color:  #cee0f2;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row7_col1{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row7_col2,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row15_col1{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row7_col3,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row12_col2{
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row8_col1,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row27_col3{
#             background-color:  #1a68ae;
#             color:  #f1f1f1;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row8_col2{
#             background-color:  #a1cbe2;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row8_col3{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row9_col0,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row21_col4,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row23_col0{
#             background-color:  #8cc0dd;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row9_col1{
#             background-color:  #2979b9;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row9_col2,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row14_col4,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row29_col2{
#             background-color:  #cbdef1;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row9_col3,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row11_col2,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row14_col0{
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row10_col1,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row18_col3,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row24_col3,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row26_col3{
#             background-color:  #0a549e;
#             color:  #f1f1f1;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row10_col2{
#             background-color:  #bed8ec;
#             color:  #000000;
#         }#T_94e0400e_0f44_11ec_8db2_8de1283b1118row10_col3,#T_94e0400e_0f44_11ec_8db2_8de1283b1118row15_col3{
#             background-color:  #f2f8fd;
