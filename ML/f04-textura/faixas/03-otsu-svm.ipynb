# %% [markdown]
# # Experimentando Classificação com SVM com 4 classes
#
# ## Importando Bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, plot_confusion_matrix

TARGET_NAMES = ['nao_faixa',
                'faixa_frente',
                'faixa_diagonal_direita',
                'faixa_diagonal_esquerda']

# %% [markdown]
# ## Carregando dados

# %%
# df tem as ultimas 1000 linhas do csv
# Contendo assim 250 amostras de cada classe
df = pd.read_csv('./csvs/otsu-lbp_faixas.csv').tail(1000)

y = df.pop('target').values
X = df.values

# Gerando 30 sementes "aleatórias" dentro do intervalo [0, 8000)
seed_arr = np.random.randint(8000, size=30)

# %% [markdown]
# ## Realizando 30 rodadas de classificação

# %%
acc_por_rodada = []
confu_matrices = []

for rodada, seed in enumerate(seed_arr):
  # separando dados
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

  clf = make_pipeline(StandardScaler(), SVC()).fit(X_train, y_train)
  y_pred = clf.predict(X_test)
  
  # Adicionando resultados à respectiva lista
  acc_por_rodada.append(
      accuracy_score(
          y_true=y_test,
          y_pred=y_pred))

  confu_matrices.append(
      confusion_matrix(
          y_pred=y_pred,
          y_true=y_test,
          normalize='true'))

  print(f'Rodada {rodada}\t-\tSeed {seed}')
  print(
    classification_report(
      y_true=y_test,
      y_pred=y_pred,
      target_names=TARGET_NAMES))

  plot_confusion_matrix(
    estimator=clf,
    X=X_test,
    y_true=y_test,
    display_labels=TARGET_NAMES,
    xticks_rotation=30,
    normalize='true')
  
  plt.show()
# Out:
# Rodada 0	-	Seed 7903
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.94      0.89      0.91        81
#            faixa_frente       0.82      0.91      0.86        70
#  faixa_diagonal_direita       0.94      0.92      0.93        71
# faixa_diagonal_esquerda       0.99      0.96      0.97        78
#
#                accuracy                           0.92       300
#               macro avg       0.92      0.92      0.92       300
#            weighted avg       0.92      0.92      0.92       300
# Rodada 1	-	Seed 4706
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.87      0.92      0.90        75
#            faixa_frente       0.91      0.87      0.89        84
#  faixa_diagonal_direita       0.97      0.94      0.96        72
# faixa_diagonal_esquerda       0.96      0.99      0.97        69
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 2	-	Seed 1272
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.89      0.96      0.93        78
#            faixa_frente       0.91      0.89      0.90        70
#  faixa_diagonal_direita       0.99      0.91      0.95        81
# faixa_diagonal_esquerda       0.97      1.00      0.99        71
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 3	-	Seed 42
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.92      0.97      0.95        72
#            faixa_frente       0.93      0.91      0.92        78
#  faixa_diagonal_direita       0.97      0.93      0.95        75
# faixa_diagonal_esquerda       0.99      1.00      0.99        75
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 4	-	Seed 6752
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.94      0.97      0.96        68
#            faixa_frente       0.94      0.95      0.94        77
#  faixa_diagonal_direita       0.97      0.92      0.95        76
# faixa_diagonal_esquerda       0.96      0.97      0.97        79
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 5	-	Seed 6790
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.97      0.95        79
#            faixa_frente       0.91      0.93      0.92        74
#  faixa_diagonal_direita       1.00      0.87      0.93        76
# faixa_diagonal_esquerda       0.95      1.00      0.97        71
#
#                accuracy                           0.94       300
#               macro avg       0.95      0.94      0.94       300
#            weighted avg       0.95      0.94      0.94       300
# Rodada 6	-	Seed 1978
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.87      0.97      0.92        70
#            faixa_frente       0.94      0.86      0.90        78
#  faixa_diagonal_direita       0.93      0.94      0.94        72
# faixa_diagonal_esquerda       0.99      0.96      0.97        80
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.94      0.93      0.93       300
# Rodada 7	-	Seed 4326
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      1.00      0.95        67
#            faixa_frente       0.95      0.94      0.94        78
#  faixa_diagonal_direita       1.00      0.91      0.95        76
# faixa_diagonal_esquerda       0.97      0.99      0.98        79
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 8	-	Seed 1538
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.99      0.96        78
#            faixa_frente       0.88      0.91      0.89        69
#  faixa_diagonal_direita       0.98      0.81      0.89        72
# faixa_diagonal_esquerda       0.94      1.00      0.97        81
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 9	-	Seed 2463
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.92      0.95      0.94        61
#            faixa_frente       0.92      0.93      0.92        85
#  faixa_diagonal_direita       0.99      0.92      0.95        78
# faixa_diagonal_esquerda       0.97      1.00      0.99        76
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 10	-	Seed 2901
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      1.00      0.96        64
#            faixa_frente       0.90      0.92      0.91        87
#  faixa_diagonal_direita       0.96      0.82      0.89        80
# faixa_diagonal_esquerda       0.95      1.00      0.97        69
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.94      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 11	-	Seed 973
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.94      0.96      0.95        75
#            faixa_frente       0.90      0.93      0.91        81
#  faixa_diagonal_direita       0.97      0.89      0.93        70
# faixa_diagonal_esquerda       0.96      0.99      0.97        74
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 12	-	Seed 2324
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.99      0.97      0.98        73
#            faixa_frente       0.93      0.97      0.95        72
#  faixa_diagonal_direita       0.99      0.90      0.94        82
# faixa_diagonal_esquerda       0.94      1.00      0.97        73
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 13	-	Seed 4715
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.95      0.95        75
#            faixa_frente       0.88      0.94      0.91        70
#  faixa_diagonal_direita       0.97      0.87      0.92        77
# faixa_diagonal_esquerda       0.96      1.00      0.98        78
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 14	-	Seed 2071
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.99      0.97        83
#            faixa_frente       0.94      0.93      0.93        68
#  faixa_diagonal_direita       0.97      0.93      0.95        73
# faixa_diagonal_esquerda       0.97      0.99      0.98        76
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 15	-	Seed 903
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.96      0.95        73
#            faixa_frente       0.94      0.96      0.95        75
#  faixa_diagonal_direita       0.99      0.95      0.97        84
# faixa_diagonal_esquerda       1.00      1.00      1.00        68
#
#                accuracy                           0.97       300
#               macro avg       0.97      0.97      0.97       300
#            weighted avg       0.97      0.97      0.97       300
# Rodada 16	-	Seed 4546
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.88      1.00      0.94        74
#            faixa_frente       0.92      0.87      0.89        77
#  faixa_diagonal_direita       0.99      0.89      0.94        82
# faixa_diagonal_esquerda       0.97      1.00      0.99        67
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 17	-	Seed 1561
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      0.92      0.92        79
#            faixa_frente       0.86      0.92      0.89        74
#  faixa_diagonal_direita       1.00      0.83      0.91        72
# faixa_diagonal_esquerda       0.91      0.99      0.95        75
#
#                accuracy                           0.92       300
#               macro avg       0.92      0.92      0.92       300
#            weighted avg       0.92      0.92      0.92       300
# Rodada 18	-	Seed 5749
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.96      0.93      0.94        82
#            faixa_frente       0.88      0.95      0.91        76
#  faixa_diagonal_direita       0.96      0.88      0.92        74
# faixa_diagonal_esquerda       0.94      0.99      0.96        68
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.94      0.93      0.93       300
# Rodada 19	-	Seed 1265
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.92      0.93        76
#            faixa_frente       0.80      0.95      0.87        62
#  faixa_diagonal_direita       0.96      0.86      0.91        88
# faixa_diagonal_esquerda       0.99      0.96      0.97        74
#
#                accuracy                           0.92       300
#               macro avg       0.92      0.92      0.92       300
#            weighted avg       0.93      0.92      0.92       300
# Rodada 20	-	Seed 5504
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.92      0.99      0.95        70
#            faixa_frente       0.95      0.90      0.93        83
#  faixa_diagonal_direita       0.96      0.94      0.95        68
# faixa_diagonal_esquerda       0.99      0.99      0.99        79
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 21	-	Seed 3747
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.82      1.00      0.90        68
#            faixa_frente       0.95      0.80      0.87        90
#  faixa_diagonal_direita       0.93      0.86      0.90        74
# faixa_diagonal_esquerda       0.94      1.00      0.97        68
#
#                accuracy                           0.91       300
#               macro avg       0.91      0.92      0.91       300
#            weighted avg       0.91      0.91      0.91       300
# Rodada 22	-	Seed 5808
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.87      1.00      0.93        82
#            faixa_frente       0.93      0.85      0.89        79
#  faixa_diagonal_direita       0.95      0.88      0.91        72
# faixa_diagonal_esquerda       0.97      0.99      0.98        67
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 23	-	Seed 1610
#                          precision    recall  f1-score   support
#
#               nao_faixa       1.00      0.97      0.99        72
#            faixa_frente       0.95      0.99      0.97        79
#  faixa_diagonal_direita       0.96      0.96      0.96        74
# faixa_diagonal_esquerda       0.99      0.97      0.98        75
#
#                accuracy                           0.97       300
#               macro avg       0.97      0.97      0.97       300
#            weighted avg       0.97      0.97      0.97       300
# Rodada 24	-	Seed 2882
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.94      0.93        80
#            faixa_frente       0.84      0.89      0.86        61
#  faixa_diagonal_direita       0.96      0.90      0.93        77
# faixa_diagonal_esquerda       0.98      0.99      0.98        82
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 25	-	Seed 7526
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.96      0.97      0.97        75
#            faixa_frente       0.91      0.97      0.94        71
#  faixa_diagonal_direita       0.96      0.89      0.92        75
# faixa_diagonal_esquerda       0.96      0.95      0.96        79
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 26	-	Seed 7793
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.98      0.96        89
#            faixa_frente       0.94      0.90      0.92        73
#  faixa_diagonal_direita       0.95      0.97      0.96        64
# faixa_diagonal_esquerda       1.00      0.99      0.99        74
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 27	-	Seed 4448
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      1.00      0.96        80
#            faixa_frente       0.95      0.92      0.94        66
#  faixa_diagonal_direita       0.93      0.90      0.91        71
# faixa_diagonal_esquerda       0.98      0.95      0.96        83
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.94      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 28	-	Seed 6236
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.92      0.98      0.95        84
#            faixa_frente       0.97      0.90      0.93        78
#  faixa_diagonal_direita       0.95      0.98      0.97        63
# faixa_diagonal_esquerda       0.99      0.97      0.98        75
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 29	-	Seed 4868
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.90      0.94      0.92        78
#            faixa_frente       0.88      0.94      0.91        77
#  faixa_diagonal_direita       0.98      0.85      0.91        66
# faixa_diagonal_esquerda       0.96      0.97      0.97        79
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.92      0.93       300
#            weighted avg       0.93      0.93      0.93       300

# %% [markdown]
# ## Exibindo média e desvio padrão das matrizes de confusão

# %%
confusion_matrix_mean = np.mean(confu_matrices, axis=0)
confusion_matrix_std = np.std(confu_matrices, axis=0)

sns.heatmap(
    data=confusion_matrix_mean,
    cmap='Blues',
    vmin=0,
    vmax=1,
    annot=True,
    fmt='.4f',
    mask=confusion_matrix_mean == 0,
    xticklabels=TARGET_NAMES,
    yticklabels=TARGET_NAMES
    ).set(
        title='Matriz de confusão média',
        xlabel='Predicted label',
        ylabel='True label')

plt.show()

sns.heatmap(
    data=confusion_matrix_std,
    cmap='Blues',
    annot=True,
    fmt='.4f',
    mask=confusion_matrix_std == 0,
    xticklabels=TARGET_NAMES,
    yticklabels=TARGET_NAMES
    ).set(
        title='Desvio padrão da matriz de confusão',
        xlabel='Predicted label',
        ylabel='True label')

None

# %% [markdown]
# ## Exibindo Acurácia geral e sua distribuição

# %%
acc_s = pd.Series(data=acc_por_rodada, name='Acurácia')

print(acc_s.describe())

acc_s.to_frame().boxplot()

acc_s.to_frame().style.hide_index().background_gradient(cmap='Blues')
# Out:
# count    30.000000
# mean      0.941222
# std       0.016247
# min       0.906667
# 25%       0.930000
# 50%       0.940000
# 75%       0.953333
# max       0.973333
# Name: Acurácia, dtype: float64
# <style  type="text/css" >
# #T_a55c7352_de99_11eb_b85c_6964397c3b91row0_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row19_col0{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row1_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row22_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row29_col0{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row2_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row11_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row13_col0{
#             background-color:  #6caed6;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row3_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row4_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row20_col0{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row5_col0{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row6_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row18_col0{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row7_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row28_col0{
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row8_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row10_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row24_col0{
#             background-color:  #a6cee4;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row9_col0{
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row12_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row14_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row26_col0{
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row15_col0{
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row16_col0{
#             background-color:  #7fb9da;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row17_col0{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row21_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row23_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_a55c7352_de99_11eb_b85c_6964397c3b91row25_col0,#T_a55c7352_de99_11eb_b85c_6964397c3b91row27_col0{
#             background-color:  #4a98c9;
#             color:  #000000;
#         }</style><table id="T_a55c7352_de99_11eb_b85c_6964397c3b91" ><thead>    <tr>        <th class="col_heading level0 col0" >Acurácia</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row0_col0" class="data row0 col0" >0.920000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row1_col0" class="data row1 col0" >0.926667</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row2_col0" class="data row2 col0" >0.940000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row3_col0" class="data row3 col0" >0.953333</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row4_col0" class="data row4 col0" >0.953333</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row5_col0" class="data row5 col0" >0.943333</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row6_col0" class="data row6 col0" >0.933333</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row7_col0" class="data row7 col0" >0.956667</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row8_col0" class="data row8 col0" >0.930000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row9_col0" class="data row9 col0" >0.950000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row10_col0" class="data row10 col0" >0.930000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row11_col0" class="data row11 col0" >0.940000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row12_col0" class="data row12 col0" >0.960000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row13_col0" class="data row13 col0" >0.940000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row14_col0" class="data row14 col0" >0.960000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row15_col0" class="data row15 col0" >0.966667</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row16_col0" class="data row16 col0" >0.936667</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row17_col0" class="data row17 col0" >0.916667</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row18_col0" class="data row18 col0" >0.933333</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row19_col0" class="data row19 col0" >0.920000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row20_col0" class="data row20 col0" >0.953333</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row21_col0" class="data row21 col0" >0.906667</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row22_col0" class="data row22 col0" >0.926667</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row23_col0" class="data row23 col0" >0.973333</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row24_col0" class="data row24 col0" >0.930000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row25_col0" class="data row25 col0" >0.946667</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row26_col0" class="data row26 col0" >0.960000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row27_col0" class="data row27 col0" >0.946667</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row28_col0" class="data row28 col0" >0.956667</td>
#             </tr>
#             <tr>
#                                 <td id="T_a55c7352_de99_11eb_b85c_6964397c3b91row29_col0" class="data row29 col0" >0.926667</td>
#             </tr>
#     </tbody></table>
