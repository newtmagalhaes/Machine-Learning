# %% [markdown]
# # Experimentando Classificação com SVM com 4 classes
#
# ## Importando Bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score,
                             classification_report,
                             confusion_matrix,
                             f1_score,
                             plot_confusion_matrix)

TARGET_NAMES = ['nao_faixa',
                'faixa_frente',
                'faixa_diagonal_direita',
                'faixa_diagonal_esquerda']

# %% [markdown]
# ## Carregando dados

# %%
# df tem as ultimas 1000 linhas do csv
# Contendo assim 250 amostras de cada classe
df = pd.read_csv('./csvs/otsu-lbp_faixas.csv').tail(1000)

y = df.pop('target').values
X = df.values

# Gerando 30 sementes "aleatórias" dentro do intervalo [0, 8000)
seed_arr = np.random.randint(8000, size=30)

# %% [markdown]
# ## Realizando 30 rodadas de classificação

# %%
acc_e_f1_por_rodada = []
confu_matrices = []

for rodada, seed in enumerate(seed_arr):
  # separando dados
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

  clf = make_pipeline(StandardScaler(), SVC()).fit(X_train, y_train)
  y_pred = clf.predict(X_test)
  
  # Adicionando resultados à respectiva lista
  acc_e_f1_por_rodada.append(
    [accuracy_score(y_test, y_pred)]
    + list(f1_score(y_test, y_pred, average=None)))

  confu_matrices.append(
    confusion_matrix(y_test, y_pred, normalize='true'))

  print(f'Rodada {rodada}\t-\tSeed {seed}')
  print(
    classification_report(
      y_true=y_test,
      y_pred=y_pred,
      target_names=TARGET_NAMES))

  plot_confusion_matrix(
    estimator=clf,
    X=X_test,
    y_true=y_test,
    display_labels=TARGET_NAMES,
    xticks_rotation=30,
    normalize='true')
  
  plt.show()
# Out:
# Rodada 0	-	Seed 3166
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.86      0.95      0.91        65
#            faixa_frente       0.90      0.86      0.88        73
#  faixa_diagonal_direita       0.99      0.92      0.96        93
# faixa_diagonal_esquerda       0.97      1.00      0.99        69
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.94      0.93       300
#            weighted avg       0.94      0.93      0.93       300
# Rodada 1	-	Seed 7020
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      1.00      0.95        72
#            faixa_frente       0.95      0.92      0.93        83
#  faixa_diagonal_direita       0.97      0.88      0.92        74
# faixa_diagonal_esquerda       0.95      0.99      0.97        71
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 2	-	Seed 7017
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.92      0.97      0.94        78
#            faixa_frente       0.91      0.91      0.91        79
#  faixa_diagonal_direita       0.97      0.91      0.94        67
# faixa_diagonal_esquerda       1.00      0.99      0.99        76
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 3	-	Seed 4417
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.95      0.95        85
#            faixa_frente       0.94      0.94      0.94        67
#  faixa_diagonal_direita       0.99      0.99      0.99        71
# faixa_diagonal_esquerda       0.99      0.99      0.99        77
#
#                accuracy                           0.97       300
#               macro avg       0.97      0.97      0.97       300
#            weighted avg       0.97      0.97      0.97       300
# Rodada 4	-	Seed 3332
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.97      0.96      0.97        79
#            faixa_frente       0.95      0.96      0.95        76
#  faixa_diagonal_direita       0.97      0.94      0.96        70
# faixa_diagonal_esquerda       0.96      0.99      0.97        75
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 5	-	Seed 4584
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.97      0.95        79
#            faixa_frente       0.89      0.94      0.92        70
#  faixa_diagonal_direita       1.00      0.88      0.93        81
# faixa_diagonal_esquerda       0.96      0.99      0.97        70
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.95      0.94      0.94       300
# Rodada 6	-	Seed 191
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.90      0.96      0.93        78
#            faixa_frente       0.89      0.91      0.90        70
#  faixa_diagonal_direita       0.96      0.91      0.93        78
# faixa_diagonal_esquerda       0.99      0.95      0.97        74
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 7	-	Seed 3859
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      0.99      0.95        86
#            faixa_frente       0.94      0.87      0.90        75
#  faixa_diagonal_direita       0.94      0.88      0.91        72
# faixa_diagonal_esquerda       0.93      0.99      0.96        67
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 8	-	Seed 7447
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.96      1.00      0.98        78
#            faixa_frente       0.91      0.95      0.93        74
#  faixa_diagonal_direita       0.92      0.88      0.90        69
# faixa_diagonal_esquerda       0.99      0.95      0.97        79
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.94      0.94       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 9	-	Seed 1975
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.95      0.94        57
#            faixa_frente       0.91      0.94      0.92        78
#  faixa_diagonal_direita       0.97      0.90      0.94        84
# faixa_diagonal_esquerda       0.96      1.00      0.98        81
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 10	-	Seed 6910
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.86      0.98      0.91        60
#            faixa_frente       0.96      0.90      0.93        80
#  faixa_diagonal_direita       0.99      0.92      0.95        78
# faixa_diagonal_esquerda       0.98      0.99      0.98        82
#
#                accuracy                           0.95       300
#               macro avg       0.94      0.95      0.94       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 11	-	Seed 7223
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.92      0.97      0.94        79
#            faixa_frente       0.91      0.93      0.92        75
#  faixa_diagonal_direita       1.00      0.86      0.92        76
# faixa_diagonal_esquerda       0.95      1.00      0.97        70
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 12	-	Seed 3872
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.92      0.94      0.93        86
#            faixa_frente       0.85      0.91      0.88        70
#  faixa_diagonal_direita       0.98      0.82      0.89        67
# faixa_diagonal_esquerda       0.95      1.00      0.97        77
#
#                accuracy                           0.92       300
#               macro avg       0.93      0.92      0.92       300
#            weighted avg       0.93      0.92      0.92       300
# Rodada 13	-	Seed 733
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.92      1.00      0.96        76
#            faixa_frente       0.88      0.90      0.89        67
#  faixa_diagonal_direita       0.99      0.91      0.95        93
# faixa_diagonal_esquerda       1.00      0.98      0.99        64
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 14	-	Seed 4597
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.85      0.97      0.90        63
#            faixa_frente       0.80      0.85      0.82        66
#  faixa_diagonal_direita       0.96      0.81      0.88        86
# faixa_diagonal_esquerda       0.98      0.98      0.98        85
#
#                accuracy                           0.90       300
#               macro avg       0.90      0.90      0.90       300
#            weighted avg       0.91      0.90      0.90       300
# Rodada 15	-	Seed 5464
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.99      0.96        70
#            faixa_frente       0.91      0.93      0.92        72
#  faixa_diagonal_direita       0.97      0.87      0.92        78
# faixa_diagonal_esquerda       0.95      0.97      0.96        80
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 16	-	Seed 7879
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.96      0.99      0.97        74
#            faixa_frente       0.94      0.95      0.94        80
#  faixa_diagonal_direita       0.96      0.89      0.92        73
# faixa_diagonal_esquerda       0.97      1.00      0.99        73
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 17	-	Seed 6372
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.96      0.94        78
#            faixa_frente       0.90      0.94      0.92        82
#  faixa_diagonal_direita       0.95      0.89      0.92        71
# faixa_diagonal_esquerda       0.96      0.93      0.94        69
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 18	-	Seed 894
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.94      0.95        89
#            faixa_frente       0.90      0.96      0.93        77
#  faixa_diagonal_direita       0.98      0.92      0.95        61
# faixa_diagonal_esquerda       0.97      0.97      0.97        73
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 19	-	Seed 7551
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.96      0.94      0.95        80
#            faixa_frente       0.89      0.97      0.93        73
#  faixa_diagonal_direita       1.00      0.89      0.94        71
# faixa_diagonal_esquerda       0.96      1.00      0.98        76
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 20	-	Seed 7399
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.94      0.99      0.96        79
#            faixa_frente       0.90      0.92      0.91        65
#  faixa_diagonal_direita       1.00      0.91      0.95        74
# faixa_diagonal_esquerda       0.99      1.00      0.99        82
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.95      0.95       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 21	-	Seed 5552
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.99      0.96        71
#            faixa_frente       0.91      0.89      0.90        71
#  faixa_diagonal_direita       0.96      0.90      0.93        86
# faixa_diagonal_esquerda       0.95      1.00      0.97        72
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 22	-	Seed 1969
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.90      0.99      0.94        77
#            faixa_frente       0.96      0.88      0.92        80
#  faixa_diagonal_direita       0.96      0.93      0.95        74
# faixa_diagonal_esquerda       0.97      1.00      0.99        69
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 23	-	Seed 4622
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      0.90      0.90        79
#            faixa_frente       0.83      0.93      0.88        72
#  faixa_diagonal_direita       0.99      0.84      0.91        80
# faixa_diagonal_esquerda       0.92      0.97      0.94        69
#
#                accuracy                           0.91       300
#               macro avg       0.91      0.91      0.91       300
#            weighted avg       0.91      0.91      0.91       300
# Rodada 24	-	Seed 3967
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.96      0.99      0.97        78
#            faixa_frente       0.93      0.97      0.95        68
#  faixa_diagonal_direita       0.97      0.90      0.93        77
# faixa_diagonal_esquerda       0.96      0.97      0.97        77
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 25	-	Seed 6701
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.96      0.94        78
#            faixa_frente       0.89      0.91      0.90        74
#  faixa_diagonal_direita       0.97      0.90      0.93        69
# faixa_diagonal_esquerda       0.99      1.00      0.99        79
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 26	-	Seed 1744
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.88      0.96      0.92        71
#            faixa_frente       0.89      0.86      0.88        74
#  faixa_diagonal_direita       0.95      0.89      0.92        80
# faixa_diagonal_esquerda       0.96      0.97      0.97        75
#
#                accuracy                           0.92       300
#               macro avg       0.92      0.92      0.92       300
#            weighted avg       0.92      0.92      0.92       300
# Rodada 27	-	Seed 1485
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      0.97      0.94        77
#            faixa_frente       0.93      0.90      0.91        69
#  faixa_diagonal_direita       0.97      0.93      0.95        72
# faixa_diagonal_esquerda       0.98      0.98      0.98        82
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.94      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 28	-	Seed 5563
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      1.00      0.95        69
#            faixa_frente       0.95      0.94      0.94        80
#  faixa_diagonal_direita       0.96      0.91      0.93        75
# faixa_diagonal_esquerda       0.99      0.96      0.97        76
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 29	-	Seed 4809
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.92      0.99      0.95        81
#            faixa_frente       0.94      0.91      0.93        75
#  faixa_diagonal_direita       0.98      0.91      0.95        68
# faixa_diagonal_esquerda       0.96      0.99      0.97        76
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300

# %% [markdown]
# ## Exibindo média e desvio padrão das matrizes de confusão

# %%
confusion_matrix_mean = np.mean(confu_matrices, axis=0)
confusion_matrix_std = np.std(confu_matrices, axis=0)

sns.heatmap(
    data=confusion_matrix_mean,
    cmap='Blues',
    vmin=0,
    vmax=1,
    annot=True,
    fmt='.4f',
    mask=confusion_matrix_mean == 0,
    xticklabels=TARGET_NAMES,
    yticklabels=TARGET_NAMES
    ).set(
        title='Matriz de confusão média',
        xlabel='Predicted label',
        ylabel='True label')

plt.show()

sns.heatmap(
    data=confusion_matrix_std,
    cmap='Blues',
    annot=True,
    fmt='.4f',
    mask=confusion_matrix_std == 0,
    xticklabels=TARGET_NAMES,
    yticklabels=TARGET_NAMES
    ).set(
        title='Desvio padrão da matriz de confusão',
        xlabel='Predicted label',
        ylabel='True label')

None

# %% [markdown]
# ## Exibindo Acurácia geral e sua distribuição

# %%
acc_df = pd.DataFrame(
  data=acc_e_f1_por_rodada,
  columns=['Acurácia'] + [f'f1-{name}' for name in TARGET_NAMES])

print(acc_df.describe())

acc_df.boxplot(rot=30)

acc_df.style.hide_index().background_gradient(cmap='Blues')
# Out:
#         Acurácia  f1-nao_faixa  f1-faixa_frente  f1-faixa_diagonal_direita  \
# count  30.000000     30.000000        30.000000                  30.000000
# mean    0.941778      0.945165         0.912678                   0.932118
# std     0.014875      0.020017         0.027089                   0.021564
# min     0.900000      0.903704         0.823529                   0.880503
# 25%     0.935000      0.940197         0.900352                   0.920277
# 50%     0.946667      0.949260         0.916667                   0.933321
# 75%     0.950000      0.955392         0.928800                   0.948506
# max     0.966667      0.981132         0.954248                   0.985915
#
#        f1-faixa_diagonal_esquerda
# count                   30.000000
# mean                     0.974584
# std                      0.013084
# min                      0.941176
# 25%                      0.967742
# 50%                      0.973855
# 75%                      0.984740
# max                      0.993939
# <style  type="text/css" >
# #T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow0_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow6_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow8_col4,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow13_col2,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow24_col4{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow0_col1{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow0_col2{
#             background-color:  #84bcdb;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow0_col3,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow5_col2,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow17_col2,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow21_col1{
#             background-color:  #2b7bba;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow0_col4,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow22_col4{
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow1_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow5_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow18_col3,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow25_col0{
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow1_col1{
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow1_col2,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow4_col1{
#             background-color:  #105ba4;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow1_col3,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow11_col3,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow16_col3{
#             background-color:  #97c6df;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow1_col4,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow6_col4{
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow2_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow8_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow9_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow10_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow13_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow22_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow22_col2,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow27_col0{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow2_col1,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow22_col1{
#             background-color:  #64a9d3;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow2_col2,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow13_col1,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow27_col2{
#             background-color:  #3585bf;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow2_col3,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow9_col3{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow2_col4{
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow3_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow3_col3,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow4_col2,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow8_col1,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow20_col4{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow3_col1,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow12_col4{
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow3_col2{
#             background-color:  #084c95;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow3_col4{
#             background-color:  #09529d;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow4_col0{
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow4_col3,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow15_col2{
#             background-color:  #2979b9;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow4_col4,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow22_col3{
#             background-color:  #4594c7;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow5_col1,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow7_col2{
#             background-color:  #4896c8;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow5_col3,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow6_col3{
#             background-color:  #68acd5;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow5_col4,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow25_col2{
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow6_col1{
#             background-color:  #a3cce3;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow6_col2,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow7_col1,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow18_col4{
#             background-color:  #4b98ca;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow7_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow12_col2,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow17_col0{
#             background-color:  #7fb9da;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow7_col3{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow7_col4{
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow8_col2{
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow8_col3{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow9_col1{
#             background-color:  #7cb7da;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow9_col2{
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow9_col4,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow10_col4{
#             background-color:  #1c6bb0;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow10_col1{
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow10_col2{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow10_col3{
#             background-color:  #3080bd;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow11_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow15_col0,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow21_col0{
#             background-color:  #4a98c9;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow11_col1{
#             background-color:  #61a7d2;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow11_col2{
#             background-color:  #2272b6;
#             color:  #f1f1f1;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow11_col4,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow18_col1,#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow19_col1{
#             background-color:  #4e9acb;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow12_col0{
#             background-color:  #a6cee4;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow12_col1{
#             background-color:  #a5cde3;
#             color:  #000000;
#         }#T_31da8f32_e3ca_11eb_99d0_c9d4ad98a10drow12_col3{
#             background-color:  #ddeaf7;
