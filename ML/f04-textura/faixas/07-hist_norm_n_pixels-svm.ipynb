# %% [markdown]
# # Explorando classificação com histogramas normalizados pela quantidade de píxels de cada amostra
#
# ## Importando biblioteca

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score,
                             classification_report,
                             confusion_matrix,
                             f1_score,
                             plot_confusion_matrix)

TARGET_NAMES = {'nao_faixa': 0,
                'faixa_frente': 1,
                'faixa_diagonal_direita': 2,
                'faixa_diagonal_esquerda': 3}
                
# Gerando 30 sementes aleatórias dentro do intervalo [0, 8000)
seed_arr = np.random.randint(8000, size=30)

# %% [markdown]
# ## Realizando 30 rodadas de classificação

# %%
df = pd.read_csv('./csvs/otsu-norm_n_pixels-lbp_faixas.csv').tail(1000)
y = df.pop('target').values
X = df.values

acc_e_f1_por_rodada = []
confu_matrices = []

for rodada, seed in enumerate(seed_arr):
  # separando dados
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

  clf = make_pipeline(StandardScaler(), SVC()).fit(X_train, y_train)
  y_pred = clf.predict(X_test)
  
  # Adicionando resultados à respectiva lista
  acc_e_f1_por_rodada.append(
    [accuracy_score(y_test, y_pred)]
    + list(f1_score(y_test, y_pred, average=None)))

  confu_matrices.append(
    confusion_matrix(y_test, y_pred, normalize='true'))

  print(f'Rodada {rodada}\t-\tSeed {seed}')
  print(
    classification_report(
      y_true=y_test,
      y_pred=y_pred,
      target_names=TARGET_NAMES))

  plot_confusion_matrix(
    estimator=clf,
    X=X_test,
    y_true=y_test,
    display_labels=TARGET_NAMES,
    xticks_rotation=30,
    normalize='true')
  
  plt.show()
# Out:
# Rodada 0	-	Seed 316
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.88      0.98      0.92        81
#            faixa_frente       0.95      0.87      0.91        83
#  faixa_diagonal_direita       0.98      0.94      0.96        69
# faixa_diagonal_esquerda       0.97      0.99      0.98        67
#
#                accuracy                           0.94       300
#               macro avg       0.95      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 1	-	Seed 4944
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.92      0.93        77
#            faixa_frente       0.89      0.93      0.91        71
#  faixa_diagonal_direita       0.97      0.92      0.94        74
# faixa_diagonal_esquerda       0.95      0.97      0.96        78
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 2	-	Seed 3112
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.99      0.96        67
#            faixa_frente       0.93      0.90      0.91        87
#  faixa_diagonal_direita       0.92      0.88      0.90        68
# faixa_diagonal_esquerda       0.96      0.99      0.97        78
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 3	-	Seed 1533
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.86      1.00      0.92        66
#            faixa_frente       0.96      0.88      0.92        80
#  faixa_diagonal_direita       0.99      0.93      0.96        83
# faixa_diagonal_esquerda       0.99      1.00      0.99        71
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 4	-	Seed 5184
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.94      0.94      0.94        79
#            faixa_frente       0.86      0.93      0.89        73
#  faixa_diagonal_direita       0.95      0.88      0.92        69
# faixa_diagonal_esquerda       0.97      0.96      0.97        79
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 5	-	Seed 2692
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.97      0.94      0.95        67
#            faixa_frente       0.91      0.96      0.93        74
#  faixa_diagonal_direita       0.94      0.93      0.93        81
# faixa_diagonal_esquerda       0.97      0.96      0.97        78
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 6	-	Seed 3544
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.97      0.97      0.97        66
#            faixa_frente       0.87      0.93      0.90        71
#  faixa_diagonal_direita       0.94      0.87      0.91        77
# faixa_diagonal_esquerda       0.98      0.99      0.98        86
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 7	-	Seed 2148
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.94      0.94        77
#            faixa_frente       0.85      0.93      0.89        73
#  faixa_diagonal_direita       0.97      0.85      0.91        79
# faixa_diagonal_esquerda       0.95      1.00      0.97        71
#
#                accuracy                           0.93       300
#               macro avg       0.93      0.93      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 8	-	Seed 5503
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      0.97      0.94        73
#            faixa_frente       0.93      0.91      0.92        69
#  faixa_diagonal_direita       0.97      0.96      0.97        80
# faixa_diagonal_esquerda       1.00      0.96      0.98        78
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 9	-	Seed 5230
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.90      0.94      0.92        69
#            faixa_frente       0.88      0.92      0.90        77
#  faixa_diagonal_direita       0.93      0.88      0.90        72
# faixa_diagonal_esquerda       0.99      0.95      0.97        82
#
#                accuracy                           0.92       300
#               macro avg       0.92      0.92      0.92       300
#            weighted avg       0.92      0.92      0.92       300
# Rodada 10	-	Seed 672
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.96      0.93      0.94        69
#            faixa_frente       0.86      0.96      0.91        72
#  faixa_diagonal_direita       1.00      0.89      0.94        79
# faixa_diagonal_esquerda       0.96      1.00      0.98        80
#
#                accuracy                           0.94       300
#               macro avg       0.95      0.94      0.94       300
#            weighted avg       0.95      0.94      0.94       300
# Rodada 11	-	Seed 6235
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.93      0.94        74
#            faixa_frente       0.90      0.95      0.92        82
#  faixa_diagonal_direita       0.97      0.93      0.95        69
# faixa_diagonal_esquerda       0.99      0.97      0.98        75
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 12	-	Seed 487
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.97      0.96        76
#            faixa_frente       0.95      0.93      0.94        80
#  faixa_diagonal_direita       0.96      0.94      0.95        72
# faixa_diagonal_esquerda       0.97      0.99      0.98        72
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 13	-	Seed 2047
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.92      0.93        75
#            faixa_frente       0.87      0.92      0.89        72
#  faixa_diagonal_direita       0.99      0.92      0.95        73
# faixa_diagonal_esquerda       0.98      1.00      0.99        80
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 14	-	Seed 2453
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.93      0.93        74
#            faixa_frente       0.92      0.90      0.91        73
#  faixa_diagonal_direita       0.95      0.97      0.96        72
# faixa_diagonal_esquerda       0.99      0.98      0.98        81
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 15	-	Seed 392
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.93      0.97      0.95        67
#            faixa_frente       0.95      0.90      0.92        82
#  faixa_diagonal_direita       0.92      0.94      0.93        65
# faixa_diagonal_esquerda       0.98      0.98      0.98        86
#
#                accuracy                           0.95       300
#               macro avg       0.94      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 16	-	Seed 5542
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.99      0.97        73
#            faixa_frente       0.92      0.90      0.91        72
#  faixa_diagonal_direita       0.93      0.92      0.92        73
# faixa_diagonal_esquerda       0.99      0.98      0.98        82
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 17	-	Seed 3584
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.90      0.98      0.94        63
#            faixa_frente       0.93      0.93      0.93        84
#  faixa_diagonal_direita       0.97      0.90      0.93        78
# faixa_diagonal_esquerda       0.99      0.99      0.99        75
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 18	-	Seed 4580
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.96      0.97      0.96        88
#            faixa_frente       0.91      0.92      0.91        73
#  faixa_diagonal_direita       0.92      0.94      0.93        64
# faixa_diagonal_esquerda       1.00      0.96      0.98        75
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 19	-	Seed 3606
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.94      0.94      0.94        82
#            faixa_frente       0.91      0.94      0.92        79
#  faixa_diagonal_direita       0.96      0.92      0.94        74
# faixa_diagonal_esquerda       0.95      0.97      0.96        65
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 20	-	Seed 5485
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.87      0.97      0.92        77
#            faixa_frente       0.91      0.90      0.91        81
#  faixa_diagonal_direita       0.98      0.88      0.93        74
# faixa_diagonal_esquerda       0.97      0.97      0.97        68
#
#                accuracy                           0.93       300
#               macro avg       0.94      0.93      0.93       300
#            weighted avg       0.93      0.93      0.93       300
# Rodada 21	-	Seed 6914
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.97      0.99      0.98        70
#            faixa_frente       0.94      0.95      0.94        77
#  faixa_diagonal_direita       0.94      0.93      0.94        72
# faixa_diagonal_esquerda       0.99      0.98      0.98        81
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 22	-	Seed 5901
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      0.97      0.94        75
#            faixa_frente       0.89      0.92      0.91        63
#  faixa_diagonal_direita       0.96      0.90      0.93        79
# faixa_diagonal_esquerda       0.99      0.96      0.98        83
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 23	-	Seed 5857
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.99      0.97        73
#            faixa_frente       0.97      0.96      0.97        75
#  faixa_diagonal_direita       0.96      0.95      0.95        75
# faixa_diagonal_esquerda       0.97      0.96      0.97        77
#
#                accuracy                           0.96       300
#               macro avg       0.96      0.96      0.96       300
#            weighted avg       0.96      0.96      0.96       300
# Rodada 24	-	Seed 4285
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.95      0.95        81
#            faixa_frente       0.89      0.94      0.92        70
#  faixa_diagonal_direita       0.99      0.92      0.95        85
# faixa_diagonal_esquerda       0.97      1.00      0.98        64
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 25	-	Seed 719
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      0.97      0.94        65
#            faixa_frente       0.93      0.90      0.92        72
#  faixa_diagonal_direita       0.97      0.91      0.94        69
# faixa_diagonal_esquerda       0.97      0.99      0.98        94
#
#                accuracy                           0.95       300
#               macro avg       0.94      0.94      0.94       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 26	-	Seed 2908
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.95      0.97      0.96        74
#            faixa_frente       0.93      0.96      0.95        72
#  faixa_diagonal_direita       1.00      0.89      0.94        88
# faixa_diagonal_esquerda       0.92      1.00      0.96        66
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 27	-	Seed 6585
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.94      0.96      0.95        71
#            faixa_frente       0.89      0.94      0.91        66
#  faixa_diagonal_direita       0.97      0.92      0.94        83
# faixa_diagonal_esquerda       0.99      0.99      0.99        80
#
#                accuracy                           0.95       300
#               macro avg       0.95      0.95      0.95       300
#            weighted avg       0.95      0.95      0.95       300
# Rodada 28	-	Seed 4774
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.91      0.94      0.93        72
#            faixa_frente       0.93      0.95      0.94        79
#  faixa_diagonal_direita       0.99      0.91      0.95        89
# faixa_diagonal_esquerda       0.92      0.95      0.93        60
#
#                accuracy                           0.94       300
#               macro avg       0.93      0.94      0.94       300
#            weighted avg       0.94      0.94      0.94       300
# Rodada 29	-	Seed 540
#                          precision    recall  f1-score   support
#
#               nao_faixa       0.89      0.97      0.93        78
#            faixa_frente       0.89      0.89      0.89        74
#  faixa_diagonal_direita       0.98      0.90      0.94        69
# faixa_diagonal_esquerda       0.99      0.97      0.98        79
#
#                accuracy                           0.94       300
#               macro avg       0.94      0.93      0.94       300
#            weighted avg       0.94      0.94      0.94       300

# %% [markdown]
# ## Métricas do experimento

# %%
confusion_matrix_mean = np.mean(confu_matrices, axis=0)
confusion_matrix_std = np.std(confu_matrices, axis=0)

sns.heatmap(
    data=confusion_matrix_mean,
    cmap='Blues',
    vmin=0,
    vmax=1,
    annot=True,
    fmt='.4f',
    mask=confusion_matrix_mean == 0,
    xticklabels=TARGET_NAMES,
    yticklabels=TARGET_NAMES
    ).set(
        title='Matriz de confusão média',
        xlabel='Predicted label',
        ylabel='True label')

plt.show()

sns.heatmap(
    data=confusion_matrix_std,
    cmap='Blues',
    annot=True,
    fmt='.4f',
    mask=confusion_matrix_std == 0,
    xticklabels=TARGET_NAMES,
    yticklabels=TARGET_NAMES
    ).set(
        title='Desvio padrão da matriz de confusão',
        xlabel='Predicted label',
        ylabel='True label')

None

# %%
acc_df = pd.DataFrame(
  data=acc_e_f1_por_rodada,
  columns=['Acurácia'] + [f'f1-{name}' for name in TARGET_NAMES])

print(acc_df.describe())

acc_df.boxplot(rot=30)

acc_df.style.hide_index().background_gradient(cmap='Blues')
# Out:
#         Acurácia  f1-nao_faixa  f1-faixa_frente  f1-faixa_diagonal_direita  \
# count  30.000000     30.000000        30.000000                  30.000000
# mean    0.943444      0.943900         0.916223                   0.936947
# std     0.009201      0.015895         0.017777                   0.017745
# min     0.923333      0.920245         0.888889                   0.900000
# 25%     0.937500      0.932453         0.906396                   0.928987
# 50%     0.946667      0.940787         0.912023                   0.939496
# 75%     0.946667      0.956028         0.925000                   0.949803
# max     0.963333      0.978723         0.966443                   0.968553
#
#        f1-faixa_diagonal_esquerda
# count                   30.000000
# mean                     0.975400
# std                      0.011439
# min                      0.934426
# 25%                      0.969355
# 50%                      0.979129
# 75%                      0.981538
# max                      0.993007
# <style  type="text/css" >
# #T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow0_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow6_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow13_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow19_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow20_col3,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow22_col0{
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow0_col1{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow0_col2{
#             background-color:  #cddff1;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow0_col3{
#             background-color:  #08458a;
#             color:  #f1f1f1;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow0_col4{
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow1_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow2_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow28_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow29_col0{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow1_col1{
#             background-color:  #dceaf6;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow1_col2,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow14_col2{
#             background-color:  #bed8ec;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow1_col3{
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow1_col4{
#             background-color:  #77b5d9;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow2_col1,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow20_col4{
#             background-color:  #4493c7;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow2_col2{
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow2_col3{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow2_col4,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow21_col2{
#             background-color:  #3282be;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow3_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow5_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow5_col2,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow11_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow14_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow15_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow16_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow17_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow18_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow25_col0{
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow3_col1{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow3_col2{
#             background-color:  #aacfe5;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow3_col3{
#             background-color:  #125da6;
#             color:  #f1f1f1;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow3_col4,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow8_col3,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow21_col1,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow23_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow23_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow4_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow20_col0{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow4_col1{
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow4_col2{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow4_col3{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow4_col4,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow10_col3,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow29_col3{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow5_col1,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow9_col4,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow25_col3{
#             background-color:  #4e9acb;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow5_col3{
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow5_col4{
#             background-color:  #549fcd;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow6_col1{
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow6_col2{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow6_col3,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow7_col3{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow6_col4{
#             background-color:  #125ea6;
#             color:  #f1f1f1;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow7_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow28_col1{
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow7_col1,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow10_col1,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow24_col2{
#             background-color:  #a4cce3;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow7_col2,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow9_col0,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow9_col3,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow20_col1,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow28_col4{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow7_col4{
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow8_col0{
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow8_col1{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow8_col2{
#             background-color:  #95c5df;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow8_col4{
#             background-color:  #1a68ae;
#             color:  #f1f1f1;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow9_col1{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow9_col2{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow10_col0{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow10_col2{
#             background-color:  #c7dcef;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow10_col4,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow16_col4{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow11_col1{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow11_col2,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow18_col3{
#             background-color:  #84bcdb;
#             color:  #000000;
#         }#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow11_col3,#T_02b6c9f4_e993_11eb_b8bb_8b6767ffe1edrow22_col4{
#             background-color:  #2e7ebc;
