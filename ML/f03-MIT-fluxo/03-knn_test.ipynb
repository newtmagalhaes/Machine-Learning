# %% [markdown]
# # Experimento 0: classificação com KNN
#
# Experimentando 20 rodadas de classificação com KNN
#
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
fluxo_df = pd.read_csv('./csvs/fs20.csv')

sns.set(style='ticks', rc={'figure.figsize':(12, 6)})
sns.countplot(data=fluxo_df, x='target')

TARGET_LABELS = ['Normal', 'HI-1', 'HI-2', 'HI-3', 'LI-1', 'LI-2', 'LI-3']

fluxo_df[['target']].value_counts(sort=False)
# Out:
# target
# 0         352
# 1         382
# 2         378
# 3         382
# 4         376
# 5         360
# 6         361
# dtype: int64

# %%
random_seeds = np.random.randint(0, 8000, 20)
print(f'seeds: {random_seeds}')

y = fluxo_df.pop('target').values
X = fluxo_df.values

acc_scores = []

for rodada, seed in enumerate(random_seeds):
    # Distribuindo os dados
    X_pre_train, X_pre_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Padronizando os dados
    sc = StandardScaler().fit(X_pre_train)
    X_train = sc.transform(X_pre_train)
    X_test = sc.transform(X_pre_test)

    # Instanciando e treinando classificador
    classifier = KNeighborsClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Adicionando resultados à respectiva lista
    acc_scores.append(classifier.score(X_test, y_test))

    # Exibindo resultados
    print(f'Rodada: {rodada} - seed: {seed}\n')

    print(classification_report(y_test, y_pred, target_names=TARGET_LABELS))
    
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=TARGET_LABELS
    )
    plt.show()
# Out:
# seeds: [4347  692  286 6477 7337 5325 3363  327 5003 4366 7633 3283 2704 4028
#  5298 4821   40 3797 1171 5049]
# Rodada: 0 - seed: 4347
#
#               precision    recall  f1-score   support
#
#       Normal       0.99      1.00      1.00       108
#         HI-1       0.95      0.86      0.90       125
#         HI-2       0.99      0.91      0.95       116
#         HI-3       0.92      0.99      0.95       102
#         LI-1       0.84      0.93      0.88        99
#         LI-2       1.00      1.00      1.00       110
#         LI-3       1.00      1.00      1.00       118
#
#     accuracy                           0.96       778
#    macro avg       0.95      0.96      0.95       778
# weighted avg       0.96      0.96      0.96       778
# Rodada: 1 - seed: 692
#
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       115
#         HI-1       0.93      0.95      0.94       108
#         HI-2       0.94      0.93      0.93       107
#         HI-3       0.97      0.97      0.97       111
#         LI-1       0.91      0.92      0.91       111
#         LI-2       0.99      0.97      0.98       112
#         LI-3       1.00      1.00      1.00       114
#
#     accuracy                           0.96       778
#    macro avg       0.96      0.96      0.96       778
# weighted avg       0.96      0.96      0.96       778
# Rodada: 2 - seed: 286
#
#               precision    recall  f1-score   support
#
#       Normal       0.98      1.00      0.99        87
#         HI-1       0.93      0.93      0.93       120
#         HI-2       0.95      0.93      0.94       119
#         HI-3       0.97      0.92      0.94       108
#         LI-1       0.92      0.95      0.93       125
#         LI-2       0.98      1.00      0.99       107
#         LI-3       1.00      0.99      1.00       112
#
#     accuracy                           0.96       778
#    macro avg       0.96      0.96      0.96       778
# weighted avg       0.96      0.96      0.96       778
# Rodada: 3 - seed: 6477
#
#               precision    recall  f1-score   support
#
#       Normal       0.99      1.00      0.99        95
#         HI-1       0.91      0.96      0.93       118
#         HI-2       0.98      0.93      0.96       116
#         HI-3       0.95      0.97      0.96       120
#         LI-1       0.93      0.90      0.92       123
#         LI-2       0.98      0.99      0.99       106
#         LI-3       1.00      0.99      0.99       100
#
#     accuracy                           0.96       778
#    macro avg       0.96      0.96      0.96       778
# weighted avg       0.96      0.96      0.96       778
# Rodada: 4 - seed: 7337
#
#               precision    recall  f1-score   support
#
#       Normal       0.97      1.00      0.98       116
#         HI-1       0.94      0.93      0.93       115
#         HI-2       0.97      0.96      0.96       123
#         HI-3       0.98      0.97      0.97       115
#         LI-1       0.90      0.91      0.91       104
#         LI-2       0.98      0.98      0.98        97
#         LI-3       1.00      0.99      1.00       108
#
#     accuracy                           0.96       778
#    macro avg       0.96      0.96      0.96       778
# weighted avg       0.96      0.96      0.96       778
# Rodada: 5 - seed: 5325
#
#               precision    recall  f1-score   support
#
#       Normal       0.96      1.00      0.98       103
#         HI-1       0.93      0.96      0.94       116
#         HI-2       0.98      0.95      0.97       120
#         HI-3       0.97      0.97      0.97       119
#         LI-1       0.96      0.94      0.95       114
#         LI-2       0.99      0.98      0.99       113
#         LI-3       1.00      0.99      0.99        93
#
#     accuracy                           0.97       778
#    macro avg       0.97      0.97      0.97       778
# weighted avg       0.97      0.97      0.97       778
# Rodada: 6 - seed: 3363
#
#               precision    recall  f1-score   support
#
#       Normal       0.93      1.00      0.96       105
#         HI-1       0.96      0.88      0.92       111
#         HI-2       0.97      0.95      0.96       121
#         HI-3       1.00      0.94      0.97       122
#         LI-1       0.89      0.97      0.92       120
#         LI-2       0.99      0.99      0.99       100
#         LI-3       1.00      1.00      1.00        99
#
#     accuracy                           0.96       778
#    macro avg       0.96      0.96      0.96       778
# weighted avg       0.96      0.96      0.96       778
# Rodada: 7 - seed: 327
#
#               precision    recall  f1-score   support
#
#       Normal       0.99      1.00      0.99        92
#         HI-1       0.93      0.96      0.94       116
#         HI-2       0.96      0.92      0.94       103
#         HI-3       0.97      0.97      0.97       114
#         LI-1       0.92      0.94      0.93       116
#         LI-2       0.99      0.97      0.98       119
#         LI-3       1.00      1.00      1.00       118
#
#     accuracy                           0.97       778
#    macro avg       0.97      0.97      0.97       778
# weighted avg       0.97      0.97      0.97       778
# Rodada: 8 - seed: 5003
#
#               precision    recall  f1-score   support
#
#       Normal       0.98      1.00      0.99       122
#         HI-1       0.95      0.98      0.96       139
#         HI-2       0.99      0.97      0.98        93
#         HI-3       0.98      0.98      0.98       121
#         LI-1       0.97      0.95      0.96       115
#         LI-2       1.00      1.00      1.00       104
#         LI-3       1.00      1.00      1.00        84
#
#     accuracy                           0.98       778
#    macro avg       0.98      0.98      0.98       778
# weighted avg       0.98      0.98      0.98       778
# Rodada: 9 - seed: 4366
#
#               precision    recall  f1-score   support
#
#       Normal       0.98      1.00      0.99       102
#         HI-1       0.94      0.93      0.94       122
#         HI-2       0.99      0.93      0.96       116
#         HI-3       0.95      0.99      0.97       104
#         LI-1       0.92      0.93      0.92       109
#         LI-2       0.98      1.00      0.99       119
#         LI-3       1.00      0.99      1.00       106
#
#     accuracy                           0.97       778
#    macro avg       0.97      0.97      0.97       778
# weighted avg       0.97      0.97      0.97       778
# Rodada: 10 - seed: 7633
#
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.98      0.99       110
#         HI-1       0.91      0.94      0.92       132
#         HI-2       0.99      0.97      0.98       100
#         HI-3       0.97      0.98      0.98       113
#         LI-1       0.93      0.90      0.91       124
#         LI-2       0.98      0.99      0.98        94
#         LI-3       1.00      1.00      1.00       105
#
#     accuracy                           0.96       778
#    macro avg       0.97      0.97      0.97       778
# weighted avg       0.96      0.96      0.96       778
# Rodada: 11 - seed: 3283
#
#               precision    recall  f1-score   support
#
#       Normal       0.98      1.00      0.99       108
#         HI-1       0.92      0.96      0.94       115
#         HI-2       1.00      0.92      0.96       119
#         HI-3       0.93      1.00      0.96       107
#         LI-1       0.98      0.91      0.94        97
#         LI-2       0.98      1.00      0.99       114
#         LI-3       1.00      0.99      1.00       118
#
#     accuracy                           0.97       778
#    macro avg       0.97      0.97      0.97       778
# weighted avg       0.97      0.97      0.97       778
# Rodada: 12 - seed: 2704
#
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       104
#         HI-1       0.93      0.89      0.91       110
#         HI-2       0.97      0.94      0.96       105
#         HI-3       0.98      0.99      0.98       122
#         LI-1       0.89      0.93      0.91       115
#         LI-2       0.98      0.99      0.99       110
#         LI-3       1.00      1.00      1.00       112
#
#     accuracy                           0.96       778
#    macro avg       0.96      0.96      0.96       778
# weighted avg       0.96      0.96      0.96       778
# Rodada: 13 - seed: 4028
#
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       114
#         HI-1       0.92      0.93      0.92       116
#         HI-2       0.96      0.96      0.96       102
#         HI-3       0.98      0.97      0.98       127
#         LI-1       0.89      0.90      0.89        96
#         LI-2       1.00      0.99      1.00       112
#         LI-3       1.00      1.00      1.00       111
#
#     accuracy                           0.97       778
#    macro avg       0.96      0.96      0.96       778
# weighted avg       0.97      0.97      0.97       778
# Rodada: 14 - seed: 5298
#
#               precision    recall  f1-score   support
#
#       Normal       0.98      1.00      0.99       113
#         HI-1       0.96      0.88      0.92       126
#         HI-2       0.97      1.00      0.99       116
#         HI-3       1.00      0.97      0.99       104
#         LI-1       0.87      0.94      0.91       109
#         LI-2       1.00      0.99      0.99       100
#         LI-3       1.00      1.00      1.00       110
#
#     accuracy                           0.97       778
#    macro avg       0.97      0.97      0.97       778
# weighted avg       0.97      0.97      0.97       778
# Rodada: 15 - seed: 4821
#
#               precision    recall  f1-score   support
#
#       Normal       0.96      1.00      0.98       117
#         HI-1       0.93      0.87      0.90       123
#         HI-2       0.97      0.91      0.94       115
#         HI-3       0.96      0.93      0.95       102
#         LI-1       0.84      0.94      0.89       117
#         LI-2       0.99      0.98      0.99       105
#         LI-3       1.00      1.00      1.00        99
#
#     accuracy                           0.95       778
#    macro avg       0.95      0.95      0.95       778
# weighted avg       0.95      0.95      0.95       778
# Rodada: 16 - seed: 40
#
#               precision    recall  f1-score   support
#
#       Normal       0.96      1.00      0.98       105
#         HI-1       0.94      0.90      0.92       111
#         HI-2       0.98      0.97      0.98       122
#         HI-3       0.99      0.95      0.97       132
#         LI-1       0.87      0.95      0.91        98
#         LI-2       1.00      0.99      1.00       104
#         LI-3       1.00      1.00      1.00       106
#
#     accuracy                           0.97       778
#    macro avg       0.96      0.97      0.96       778
# weighted avg       0.97      0.97      0.97       778
# Rodada: 17 - seed: 3797
#
#               precision    recall  f1-score   support
#
#       Normal       0.96      1.00      0.98       113
#         HI-1       0.90      0.92      0.91       121
#         HI-2       0.98      0.91      0.94       119
#         HI-3       0.96      0.98      0.97       106
#         LI-1       0.91      0.89      0.90       118
#         LI-2       0.99      1.00      0.99        98
#         LI-3       1.00      1.00      1.00       103
#
#     accuracy                           0.95       778
#    macro avg       0.96      0.96      0.96       778
# weighted avg       0.95      0.95      0.95       778
# Rodada: 18 - seed: 1171
#
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       102
#         HI-1       0.88      0.93      0.91       103
#         HI-2       0.97      0.95      0.96       120
#         HI-3       0.97      0.98      0.97       116
#         LI-1       0.93      0.90      0.92       120
#         LI-2       1.00      0.99      1.00       111
#         LI-3       1.00      1.00      1.00       106
#
#     accuracy                           0.96       778
#    macro avg       0.96      0.97      0.96       778
# weighted avg       0.96      0.96      0.96       778
# Rodada: 19 - seed: 5049
#
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       119
#         HI-1       0.94      0.92      0.93       118
#         HI-2       0.99      0.98      0.98        96
#         HI-3       0.99      1.00      1.00       109
#         LI-1       0.91      0.93      0.92       109
#         LI-2       1.00      1.00      1.00       111
#         LI-3       1.00      1.00      1.00       116
#
#     accuracy                           0.98       778
#    macro avg       0.98      0.98      0.98       778
# weighted avg       0.98      0.98      0.98       778

# %%
acc_s = pd.Series(data=acc_scores, name='Acurácia')

acc_s.to_frame().style.hide_index().background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row0_col0{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row1_col0,#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row12_col0,#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row18_col0{
#             background-color:  #65aad4;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row2_col0{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row3_col0{
#             background-color:  #82bbdb;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row4_col0,#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row10_col0{
#             background-color:  #72b2d8;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row5_col0,#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row11_col0{
#             background-color:  #3787c0;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row6_col0{
#             background-color:  #91c3de;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row7_col0,#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row9_col0{
#             background-color:  #4d99ca;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row8_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row13_col0,#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row16_col0{
#             background-color:  #58a1cf;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row14_col0{
#             background-color:  #4090c5;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row15_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row17_col0{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row19_col0{
#             background-color:  #0c56a0;
#             color:  #f1f1f1;
#         }</style><table id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2" ><thead>    <tr>        <th class="col_heading level0 col0" >Acurácia</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row0_col0" class="data row0 col0" >0.955013</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row1_col0" class="data row1 col0" >0.964010</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row2_col0" class="data row2 col0" >0.957584</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row3_col0" class="data row3 col0" >0.961440</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row4_col0" class="data row4 col0" >0.962725</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row5_col0" class="data row5 col0" >0.969152</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row6_col0" class="data row6 col0" >0.960154</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row7_col0" class="data row7 col0" >0.966581</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row8_col0" class="data row8 col0" >0.980720</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row9_col0" class="data row9 col0" >0.966581</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row10_col0" class="data row10 col0" >0.962725</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row11_col0" class="data row11 col0" >0.969152</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row12_col0" class="data row12 col0" >0.964010</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row13_col0" class="data row13 col0" >0.965296</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row14_col0" class="data row14 col0" >0.967866</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row15_col0" class="data row15 col0" >0.946015</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row16_col0" class="data row16 col0" >0.965296</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row17_col0" class="data row17 col0" >0.953728</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row18_col0" class="data row18 col0" >0.964010</td>
#             </tr>
#             <tr>
#                                 <td id="T_294f8456_96c9_11eb_8e76_cf4eb936f2e2row19_col0" class="data row19 col0" >0.975578</td>
#             </tr>
#     </tbody></table>

# %%
sns.boxplot(data=acc_s)
acc_s.describe()
# Out:
# count    20.000000
# mean      0.963882
# std       0.007517
# min       0.946015
# 25%       0.961118
# 50%       0.964010
# 75%       0.966902
# max       0.980720
# Name: Acurácia, dtype: float64
