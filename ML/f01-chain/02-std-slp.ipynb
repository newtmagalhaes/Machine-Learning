# %% [markdown]
# # Standard SLP
#
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import Perceptron
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix, accuracy_score, recall_score

# %% [markdown]
# ## Carregando e preparando dados

# %%
# Carregando dados
chain_array = np.load('corrente1.npy')

# Carregando Rótulos das características
feature_names = [
    'DesvioD1','DesvioD2','DesvioD3','DesvioD4','DesvioD5','DesvioA5',
    'MeanAD1','MeanAD2','MeanAD3','MeanAD4','MeanAD5','MeanADA5',
    'MedianAD1','MedianAD2','MedianAD3','MedianAD4','MedianAD5','MedianADA5',
    'KurtosisD1','KurtosisD2','KurtosisD3','KurtosisD4','KurtosisD5','KurtosisA5',
    'SkewnessD1','SkewnessD2','SkewnessD3','SkewnessD4','SkewnessD5','SkewnessA5',
    'EnergiaD1','EnergiaD2','EnergiaD3','EnergiaD4','EnergiaD5','EnergiaA5',
    'frequencia','classe','carga'
]

# Carregando rótulos das classes
target_names = ['Normal', 'HI-1', 'HI-2', 'HI-3', 'LI-1', 'LI-2', 'LI-3']

# Gerando DataFrame
chainDF = pd.DataFrame(data=chain_array, columns=feature_names).fillna(value=0)

targetS = chainDF.pop('classe')

# Definindo variáveis
X, y = chainDF.to_numpy(), targetS.to_numpy()

# Definindo array de números aleatórios
seed_array = np.array([4054, 6284, 4916, 2297, 8262, 3342, 7440,  541, 1711, 6730, 8764, 6323, 7498,  885,  771])

# %% [markdown]
# ## 15 rodadas de classificação

# %%
acc, rec = [], []

for turn, seed in enumerate(seed_array):
    # Distribuindo os dados
    X_pre_train, X_pre_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Instanciando Standard Scaler
    sc = StandardScaler().fit(X_pre_train)

    # Pré-processando dados
    X_train = sc.transform(X_pre_train)
    X_test = sc.transform(X_pre_test)

    # Instanciando e treinando classificador
    classifier = Perceptron().fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Gerando resultados
    accuracy = accuracy_score(y_test, y_pred)

    # Adicionando resultados às respectivas listas
    acc.append(accuracy)
    rec.append(recall_score(y_test, y_pred, average=None))

    # Exibindo resultados
    print(f'Rodada: {turn} - seed: {seed} - acurácia: {accuracy}\n')

    print(classification_report(y_test, y_pred, target_names=target_names))
    
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=target_names
    )
    plt.show()
# Out:
# Rodada: 0 - seed: 4054 - acurácia: 0.4083969465648855
#
#               precision    recall  f1-score   support
#
#       Normal       0.23      0.29      0.26        92
#         HI-1       0.26      0.21      0.23       114
#         HI-2       0.42      0.32      0.36       110
#         HI-3       0.43      0.33      0.37       131
#         LI-1       0.26      0.36      0.30       106
#         LI-2       0.43      0.46      0.44       109
#         LI-3       0.79      0.84      0.82       124
#
#     accuracy                           0.41       786
#    macro avg       0.40      0.40      0.40       786
# weighted avg       0.42      0.41      0.41       786
# Rodada: 1 - seed: 6284 - acurácia: 0.31679389312977096
#
#               precision    recall  f1-score   support
#
#       Normal       0.48      0.09      0.16       107
#         HI-1       0.25      0.03      0.05       111
#         HI-2       0.25      0.54      0.34       118
#         HI-3       0.27      0.31      0.29       107
#         LI-1       0.26      0.14      0.18       116
#         LI-2       0.24      0.51      0.33       117
#         LI-3       0.91      0.57      0.70       110
#
#     accuracy                           0.32       786
#    macro avg       0.38      0.31      0.29       786
# weighted avg       0.38      0.32      0.29       786
# Rodada: 2 - seed: 4916 - acurácia: 0.27735368956743
#
#               precision    recall  f1-score   support
#
#       Normal       0.19      0.30      0.23       116
#         HI-1       0.14      0.25      0.18       118
#         HI-2       0.23      0.17      0.20       109
#         HI-3       0.25      0.05      0.08       106
#         LI-1       0.25      0.36      0.29       114
#         LI-2       0.66      0.18      0.28       119
#         LI-3       0.73      0.64      0.68       104
#
#     accuracy                           0.28       786
#    macro avg       0.35      0.28      0.28       786
# weighted avg       0.35      0.28      0.28       786
# Rodada: 3 - seed: 2297 - acurácia: 0.3422391857506361
#
#               precision    recall  f1-score   support
#
#       Normal       0.19      0.04      0.06       110
#         HI-1       0.24      0.39      0.30       115
#         HI-2       0.29      0.55      0.38       108
#         HI-3       0.38      0.21      0.27       133
#         LI-1       0.20      0.20      0.20       114
#         LI-2       0.51      0.37      0.43       101
#         LI-3       0.62      0.70      0.65       105
#
#     accuracy                           0.34       786
#    macro avg       0.35      0.35      0.33       786
# weighted avg       0.34      0.34      0.32       786
# Rodada: 4 - seed: 8262 - acurácia: 0.33587786259541985
#
#               precision    recall  f1-score   support
#
#       Normal       0.33      0.21      0.26        99
#         HI-1       0.26      0.14      0.18       118
#         HI-2       0.35      0.52      0.42       112
#         HI-3       0.44      0.30      0.36       123
#         LI-1       0.19      0.31      0.23       105
#         LI-2       0.41      0.27      0.32       119
#         LI-3       0.42      0.61      0.50       110
#
#     accuracy                           0.34       786
#    macro avg       0.34      0.34      0.32       786
# weighted avg       0.35      0.34      0.33       786
# Rodada: 5 - seed: 3342 - acurácia: 0.34987277353689566
#
#               precision    recall  f1-score   support
#
#       Normal       0.12      0.19      0.15       104
#         HI-1       0.17      0.30      0.22       110
#         HI-2       0.47      0.51      0.49       101
#         HI-3       0.32      0.43      0.37       123
#         LI-1       0.67      0.02      0.03       127
#         LI-2       0.72      0.37      0.48       104
#         LI-3       0.80      0.66      0.72       117
#
#     accuracy                           0.35       786
#    macro avg       0.47      0.35      0.35       786
# weighted avg       0.47      0.35      0.35       786
# Rodada: 6 - seed: 7440 - acurácia: 0.2786259541984733
#
#               precision    recall  f1-score   support
#
#       Normal       0.30      0.22      0.26       108
#         HI-1       0.31      0.04      0.06       114
#         HI-2       0.47      0.24      0.32       121
#         HI-3       0.30      0.28      0.29       109
#         LI-1       0.26      0.20      0.23       114
#         LI-2       0.29      0.45      0.35       118
#         LI-3       0.21      0.54      0.31       102
#
#     accuracy                           0.28       786
#    macro avg       0.31      0.28      0.26       786
# weighted avg       0.31      0.28      0.26       786
# Rodada: 7 - seed: 541 - acurácia: 0.3638676844783715
#
#               precision    recall  f1-score   support
#
#       Normal       0.29      0.20      0.24       109
#         HI-1       0.24      0.31      0.27       114
#         HI-2       0.46      0.45      0.45       112
#         HI-3       0.25      0.47      0.33       108
#         LI-1       0.16      0.06      0.09       104
#         LI-2       0.30      0.26      0.28       111
#         LI-3       0.80      0.73      0.76       128
#
#     accuracy                           0.36       786
#    macro avg       0.36      0.35      0.34       786
# weighted avg       0.37      0.36      0.36       786
# Rodada: 8 - seed: 1711 - acurácia: 0.3727735368956743
#
#               precision    recall  f1-score   support
#
#       Normal       0.32      0.22      0.26       119
#         HI-1       0.29      0.27      0.28       118
#         HI-2       0.52      0.37      0.43       114
#         HI-3       0.33      0.31      0.32       113
#         LI-1       0.20      0.24      0.22       111
#         LI-2       0.31      0.46      0.37       113
#         LI-3       0.76      0.81      0.78        98
#
#     accuracy                           0.37       786
#    macro avg       0.39      0.38      0.38       786
# weighted avg       0.38      0.37      0.37       786
# Rodada: 9 - seed: 6730 - acurácia: 0.36895674300254455
#
#               precision    recall  f1-score   support
#
#       Normal       0.33      0.11      0.16       111
#         HI-1       0.33      0.14      0.19       124
#         HI-2       0.67      0.43      0.52       117
#         HI-3       0.32      0.39      0.35       109
#         LI-1       0.26      0.48      0.33       124
#         LI-2       0.26      0.49      0.35        99
#         LI-3       0.79      0.60      0.68       102
#
#     accuracy                           0.37       786
#    macro avg       0.42      0.38      0.37       786
# weighted avg       0.42      0.37      0.36       786
# Rodada: 10 - seed: 8764 - acurácia: 0.36259541984732824
#
#               precision    recall  f1-score   support
#
#       Normal       0.54      0.13      0.21        97
#         HI-1       0.23      0.08      0.12       110
#         HI-2       0.42      0.55      0.48       123
#         HI-3       0.25      0.38      0.30       109
#         LI-1       0.23      0.20      0.22       104
#         LI-2       0.23      0.40      0.29       123
#         LI-3       0.88      0.70      0.78       120
#
#     accuracy                           0.36       786
#    macro avg       0.40      0.35      0.34       786
# weighted avg       0.40      0.36      0.35       786
# Rodada: 11 - seed: 6323 - acurácia: 0.36259541984732824
#
#               precision    recall  f1-score   support
#
#       Normal       0.35      0.12      0.18       104
#         HI-1       0.18      0.17      0.17       108
#         HI-2       0.49      0.59      0.54       122
#         HI-3       0.31      0.44      0.36       106
#         LI-1       0.25      0.20      0.22       107
#         LI-2       0.26      0.39      0.31       116
#         LI-3       0.74      0.56      0.64       123
#
#     accuracy                           0.36       786
#    macro avg       0.37      0.35      0.35       786
# weighted avg       0.38      0.36      0.36       786
# Rodada: 12 - seed: 7498 - acurácia: 0.35368956743002544
#
#               precision    recall  f1-score   support
#
#       Normal       0.33      0.01      0.02       108
#         HI-1       0.26      0.28      0.27       127
#         HI-2       0.49      0.29      0.37       119
#         HI-3       0.21      0.49      0.29       104
#         LI-1       0.24      0.32      0.28       113
#         LI-2       0.47      0.43      0.45       109
#         LI-3       0.82      0.68      0.74       106
#
#     accuracy                           0.35       786
#    macro avg       0.41      0.36      0.35       786
# weighted avg       0.40      0.35      0.34       786
# Rodada: 13 - seed: 885 - acurácia: 0.41603053435114506
#
#               precision    recall  f1-score   support
#
#       Normal       0.35      0.28      0.31       103
#         HI-1       0.27      0.28      0.27       116
#         HI-2       0.55      0.42      0.48       110
#         HI-3       0.32      0.33      0.32       112
#         LI-1       0.26      0.27      0.26       120
#         LI-2       0.55      0.53      0.54       122
#         LI-3       0.59      0.83      0.69       103
#
#     accuracy                           0.42       786
#    macro avg       0.41      0.42      0.41       786
# weighted avg       0.41      0.42      0.41       786
# Rodada: 14 - seed: 771 - acurácia: 0.3816793893129771
#
#               precision    recall  f1-score   support
#
#       Normal       0.39      0.16      0.22       103
#         HI-1       0.32      0.25      0.28       118
#         HI-2       0.40      0.35      0.37       123
#         HI-3       0.41      0.43      0.42       120
#         LI-1       0.22      0.32      0.26       110
#         LI-2       0.24      0.34      0.28       110
#         LI-3       0.84      0.86      0.85       102
#
#     accuracy                           0.38       786
#    macro avg       0.40      0.39      0.38       786
# weighted avg       0.40      0.38      0.38       786

# %% [markdown]
# ## Observando métricas de Acurácia e Sensibilidade

# %%
metricsDF = pd.DataFrame(data=rec, columns=[f'S - {classe}' for classe in target_names])
metricsDF['Acurácia'] = acc
metricsDF
# Out:
#     S - Normal  S - HI-1  S - HI-2  S - HI-3  S - LI-1  S - LI-2  S - LI-3  \
# 0     0.293478  0.210526  0.318182  0.328244  0.358491  0.458716  0.838710
# 1     0.093458  0.027027  0.542373  0.308411  0.137931  0.512821  0.572727
# 2     0.301724  0.254237  0.174312  0.047170  0.359649  0.176471  0.644231
# 3     0.036364  0.391304  0.546296  0.210526  0.201754  0.366337  0.695238
# 4     0.212121  0.135593  0.517857  0.300813  0.314286  0.268908  0.609091
# 5     0.192308  0.300000  0.514851  0.430894  0.015748  0.365385  0.658120
# 6     0.222222  0.035088  0.239669  0.284404  0.201754  0.449153  0.539216
# 7     0.201835  0.307018  0.446429  0.472222  0.057692  0.261261  0.726562
# 8     0.218487  0.271186  0.368421  0.309735  0.243243  0.460177  0.806122
# 9     0.108108  0.137097  0.427350  0.385321  0.475806  0.494949  0.598039
# 10    0.134021  0.081818  0.552846  0.376147  0.201923  0.398374  0.700000
# 11    0.125000  0.166667  0.590164  0.443396  0.196262  0.387931  0.560976
# 12    0.009259  0.283465  0.294118  0.490385  0.318584  0.431193  0.679245
# 13    0.281553  0.275862  0.418182  0.330357  0.266667  0.532787  0.834951
# 14    0.155340  0.245763  0.349593  0.433333  0.318182  0.336364  0.862745
#
#     Acurácia
# 0   0.408397
# 1   0.316794
# 2   0.277354
# 3   0.342239
# 4   0.335878
# 5   0.349873
# 6   0.278626
# 7   0.363868
# 8   0.372774
# 9   0.368957
# 10  0.362595
# 11  0.362595
# 12  0.353690
# 13  0.416031
# 14  0.381679

# %%
metricsDF.boxplot()
metricsDF.describe()
# Out:
#        S - Normal   S - HI-1   S - HI-2   S - HI-3   S - LI-1   S - LI-2  \
# count   15.000000  15.000000  15.000000  15.000000  15.000000  15.000000
# mean     0.172352   0.208177   0.420043   0.343424   0.244532   0.393388
# std      0.088738   0.106999   0.126370   0.113462   0.120241   0.100750
# min      0.009259   0.027027   0.174312   0.047170   0.015748   0.176471
# 25%      0.116554   0.136345   0.333888   0.304612   0.199008   0.350874
# 50%      0.192308   0.245763   0.427350   0.330357   0.243243   0.398374
# 75%      0.220355   0.279663   0.530115   0.432114   0.318383   0.459446
# max      0.301724   0.391304   0.590164   0.490385   0.475806   0.532787
#
#         S - LI-3   Acurácia
# count  15.000000  15.000000
# mean    0.688398   0.352757
# std     0.106651   0.039456
# min     0.539216   0.277354
# 25%     0.603565   0.339059
# 50%     0.679245   0.362595
# 75%     0.766342   0.370865
# max     0.862745   0.416031

# %% [markdown]
# ## Adicionando resultado ao csv

# %%
rodadasDF = pd.read_csv('15_rodadas.csv')
rodadasDF['SLP_acc'] = acc
rodadasDF.to_csv('15_rodadas.csv')
