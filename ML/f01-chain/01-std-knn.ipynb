# %% [markdown]
# # Standard KNN
#
# Explorando 15 rodadas de classificação com algoritmo **knn** e armazenando resultados em arquivo .csv.
#
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix, accuracy_score, recall_score

# %% [markdown]
# ## Carregando e preparando dados

# %%
# Carregando dados
chain_array = np.load('corrente1.npy')

# Carregando Rótulos das características
feature_names = [
    'DesvioD1','DesvioD2','DesvioD3','DesvioD4','DesvioD5','DesvioA5',
    'MeanAD1','MeanAD2','MeanAD3','MeanAD4','MeanAD5','MeanADA5',
    'MedianAD1','MedianAD2','MedianAD3','MedianAD4','MedianAD5','MedianADA5',
    'KurtosisD1','KurtosisD2','KurtosisD3','KurtosisD4','KurtosisD5','KurtosisA5',
    'SkewnessD1','SkewnessD2','SkewnessD3','SkewnessD4','SkewnessD5','SkewnessA5',
    'EnergiaD1','EnergiaD2','EnergiaD3','EnergiaD4','EnergiaD5','EnergiaA5',
    'frequencia','classe','carga'
]

# Carregando rótulos das classes
target_names = ['Normal', 'HI-1', 'HI-2', 'HI-3', 'LI-1', 'LI-2', 'LI-3']

# Gerando DataFrame
chainDF = pd.DataFrame(data=chain_array, columns=feature_names).fillna(value=0)

targetS = chainDF.pop('classe')

# Definindo variáveis
X, y = chainDF.to_numpy(), targetS.to_numpy()

# Definindo array de números aleatórios
seed_array = np.array([4054, 6284, 4916, 2297, 8262, 3342, 7440,  541, 1711, 6730, 8764, 6323, 7498,  885,  771])

# %% [markdown]
# ## 15 rodadas de classificação

# %%
acc, rec = [], []

for turn, seed in enumerate(seed_array):
    # Distribuindo os dados
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    classifier = KNeighborsClassifier()
    classifier.fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Gerando resultados
    accuracy = accuracy_score(y_test, y_pred)

    # Adicionando resultados às respectivas listas
    acc.append(accuracy)
    rec.append(recall_score(y_test, y_pred, average=None))

    # Exibindo resultados
    print(f'Rodada: {turn} - seed: {seed} - acurácia: {accuracy}\n')

    print(classification_report(y_test, y_pred, target_names=target_names))
    
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=target_names
    )
    plt.show()
# Out:
# Rodada: 0 - seed: 4054 - acurácia: 0.6615776081424937
#
#               precision    recall  f1-score   support
#
#       Normal       0.60      0.80      0.69        92
#         HI-1       0.47      0.53      0.50       114
#         HI-2       0.55      0.54      0.54       110
#         HI-3       0.77      0.58      0.66       131
#         LI-1       0.57      0.49      0.53       106
#         LI-2       0.75      0.84      0.79       109
#         LI-3       0.94      0.86      0.90       124
#
#     accuracy                           0.66       786
#    macro avg       0.66      0.66      0.66       786
# weighted avg       0.67      0.66      0.66       786
# Rodada: 1 - seed: 6284 - acurácia: 0.6793893129770993
#
#               precision    recall  f1-score   support
#
#       Normal       0.66      0.66      0.66       107
#         HI-1       0.47      0.50      0.49       111
#         HI-2       0.56      0.63      0.59       118
#         HI-3       0.70      0.75      0.72       107
#         LI-1       0.66      0.55      0.60       116
#         LI-2       0.82      0.79      0.81       117
#         LI-3       0.94      0.87      0.91       110
#
#     accuracy                           0.68       786
#    macro avg       0.69      0.68      0.68       786
# weighted avg       0.69      0.68      0.68       786
# Rodada: 2 - seed: 4916 - acurácia: 0.6463104325699746
#
#               precision    recall  f1-score   support
#
#       Normal       0.70      0.61      0.65       116
#         HI-1       0.48      0.49      0.48       118
#         HI-2       0.51      0.56      0.54       109
#         HI-3       0.63      0.72      0.67       106
#         LI-1       0.55      0.49      0.52       114
#         LI-2       0.81      0.76      0.79       119
#         LI-3       0.86      0.91      0.89       104
#
#     accuracy                           0.65       786
#    macro avg       0.65      0.65      0.65       786
# weighted avg       0.65      0.65      0.65       786
# Rodada: 3 - seed: 2297 - acurácia: 0.6539440203562341
#
#               precision    recall  f1-score   support
#
#       Normal       0.69      0.67      0.68       110
#         HI-1       0.45      0.47      0.46       115
#         HI-2       0.52      0.57      0.55       108
#         HI-3       0.73      0.67      0.70       133
#         LI-1       0.52      0.54      0.53       114
#         LI-2       0.83      0.82      0.83       101
#         LI-3       0.92      0.86      0.89       105
#
#     accuracy                           0.65       786
#    macro avg       0.67      0.66      0.66       786
# weighted avg       0.66      0.65      0.66       786
# Rodada: 4 - seed: 8262 - acurácia: 0.6692111959287532
#
#               precision    recall  f1-score   support
#
#       Normal       0.62      0.73      0.67        99
#         HI-1       0.45      0.46      0.45       118
#         HI-2       0.59      0.53      0.56       112
#         HI-3       0.73      0.73      0.73       123
#         LI-1       0.54      0.53      0.54       105
#         LI-2       0.81      0.85      0.83       119
#         LI-3       0.97      0.85      0.91       110
#
#     accuracy                           0.67       786
#    macro avg       0.67      0.67      0.67       786
# weighted avg       0.67      0.67      0.67       786
# Rodada: 5 - seed: 3342 - acurácia: 0.6564885496183206
#
#               precision    recall  f1-score   support
#
#       Normal       0.64      0.71      0.67       104
#         HI-1       0.47      0.63      0.54       110
#         HI-2       0.53      0.57      0.55       101
#         HI-3       0.73      0.59      0.65       123
#         LI-1       0.58      0.47      0.52       127
#         LI-2       0.78      0.80      0.79       104
#         LI-3       0.94      0.85      0.90       117
#
#     accuracy                           0.66       786
#    macro avg       0.67      0.66      0.66       786
# weighted avg       0.67      0.66      0.66       786
# Rodada: 6 - seed: 7440 - acurácia: 0.5826972010178118
#
#               precision    recall  f1-score   support
#
#       Normal       0.59      0.61      0.60       108
#         HI-1       0.41      0.39      0.40       114
#         HI-2       0.45      0.47      0.46       121
#         HI-3       0.62      0.63      0.63       109
#         LI-1       0.45      0.44      0.44       114
#         LI-2       0.73      0.77      0.75       118
#         LI-3       0.88      0.78      0.83       102
#
#     accuracy                           0.58       786
#    macro avg       0.59      0.59      0.59       786
# weighted avg       0.59      0.58      0.58       786
# Rodada: 7 - seed: 541 - acurácia: 0.6679389312977099
#
#               precision    recall  f1-score   support
#
#       Normal       0.70      0.69      0.69       109
#         HI-1       0.46      0.52      0.49       114
#         HI-2       0.60      0.57      0.59       112
#         HI-3       0.64      0.69      0.66       108
#         LI-1       0.53      0.53      0.53       104
#         LI-2       0.80      0.77      0.79       111
#         LI-3       0.95      0.88      0.91       128
#
#     accuracy                           0.67       786
#    macro avg       0.67      0.66      0.67       786
# weighted avg       0.68      0.67      0.67       786
# Rodada: 8 - seed: 1711 - acurácia: 0.6374045801526718
#
#               precision    recall  f1-score   support
#
#       Normal       0.68      0.66      0.67       119
#         HI-1       0.41      0.47      0.44       118
#         HI-2       0.57      0.52      0.54       114
#         HI-3       0.67      0.73      0.70       113
#         LI-1       0.49      0.47      0.48       111
#         LI-2       0.79      0.73      0.76       113
#         LI-3       0.90      0.92      0.91        98
#
#     accuracy                           0.64       786
#    macro avg       0.65      0.64      0.64       786
# weighted avg       0.64      0.64      0.64       786
# Rodada: 9 - seed: 6730 - acurácia: 0.6424936386768448
#
#               precision    recall  f1-score   support
#
#       Normal       0.61      0.68      0.64       111
#         HI-1       0.48      0.49      0.48       124
#         HI-2       0.56      0.54      0.55       117
#         HI-3       0.65      0.69      0.67       109
#         LI-1       0.58      0.51      0.54       124
#         LI-2       0.81      0.77      0.79        99
#         LI-3       0.88      0.90      0.89       102
#
#     accuracy                           0.64       786
#    macro avg       0.65      0.65      0.65       786
# weighted avg       0.64      0.64      0.64       786
# Rodada: 10 - seed: 8764 - acurácia: 0.6564885496183206
#
#               precision    recall  f1-score   support
#
#       Normal       0.58      0.70      0.63        97
#         HI-1       0.47      0.47      0.47       110
#         HI-2       0.58      0.49      0.53       123
#         HI-3       0.66      0.72      0.69       109
#         LI-1       0.52      0.49      0.50       104
#         LI-2       0.83      0.80      0.82       123
#         LI-3       0.91      0.90      0.90       120
#
#     accuracy                           0.66       786
#    macro avg       0.65      0.65      0.65       786
# weighted avg       0.66      0.66      0.66       786
# Rodada: 11 - seed: 6323 - acurácia: 0.6513994910941476
#
#               precision    recall  f1-score   support
#
#       Normal       0.61      0.65      0.63       104
#         HI-1       0.43      0.48      0.45       108
#         HI-2       0.55      0.52      0.54       122
#         HI-3       0.72      0.62      0.67       106
#         LI-1       0.51      0.49      0.50       107
#         LI-2       0.80      0.84      0.82       116
#         LI-3       0.94      0.92      0.93       123
#
#     accuracy                           0.65       786
#    macro avg       0.65      0.65      0.65       786
# weighted avg       0.66      0.65      0.65       786
# Rodada: 12 - seed: 7498 - acurácia: 0.6348600508905853
#
#               precision    recall  f1-score   support
#
#       Normal       0.57      0.61      0.59       108
#         HI-1       0.45      0.43      0.44       127
#         HI-2       0.54      0.53      0.54       119
#         HI-3       0.67      0.79      0.72       104
#         LI-1       0.53      0.46      0.49       113
#         LI-2       0.79      0.83      0.81       109
#         LI-3       0.93      0.86      0.89       106
#
#     accuracy                           0.63       786
#    macro avg       0.64      0.64      0.64       786
# weighted avg       0.63      0.63      0.63       786
# Rodada: 13 - seed: 885 - acurácia: 0.638676844783715
#
#               precision    recall  f1-score   support
#
#       Normal       0.60      0.76      0.67       103
#         HI-1       0.40      0.42      0.41       116
#         HI-2       0.50      0.47      0.49       110
#         HI-3       0.69      0.62      0.66       112
#         LI-1       0.51      0.47      0.49       120
#         LI-2       0.84      0.84      0.84       122
#         LI-3       0.95      0.91      0.93       103
#
#     accuracy                           0.64       786
#    macro avg       0.64      0.64      0.64       786
# weighted avg       0.64      0.64      0.64       786
# Rodada: 14 - seed: 771 - acurácia: 0.6615776081424937
#
#               precision    recall  f1-score   support
#
#       Normal       0.58      0.65      0.61       103
#         HI-1       0.52      0.53      0.52       118
#         HI-2       0.54      0.59      0.56       123
#         HI-3       0.69      0.68      0.69       120
#         LI-1       0.60      0.49      0.54       110
#         LI-2       0.83      0.84      0.83       110
#         LI-3       0.94      0.89      0.91       102
#
#     accuracy                           0.66       786
#    macro avg       0.67      0.67      0.67       786
# weighted avg       0.66      0.66      0.66       786

# %% [markdown]
# ## Observando métricas de Acurácia e sensibilidade

# %%
metricsDF = pd.DataFrame(data=rec, columns=[f'S - {classe}' for classe in target_names])
metricsDF['Acurácia'] = acc
metricsDF
# Out:
#     S - Normal  S - HI-1  S - HI-2  S - HI-3  S - LI-1  S - LI-2  S - LI-3  \
# 0     0.804348  0.526316  0.536364  0.580153  0.490566  0.844037  0.862903
# 1     0.663551  0.504505  0.627119  0.747664  0.551724  0.794872  0.872727
# 2     0.612069  0.491525  0.559633  0.716981  0.491228  0.764706  0.913462
# 3     0.672727  0.469565  0.574074  0.669173  0.543860  0.821782  0.857143
# 4     0.727273  0.457627  0.526786  0.731707  0.533333  0.848739  0.854545
# 5     0.711538  0.627273  0.574257  0.585366  0.472441  0.798077  0.854701
# 6     0.611111  0.394737  0.471074  0.633028  0.438596  0.771186  0.784314
# 7     0.688073  0.517544  0.571429  0.685185  0.528846  0.774775  0.875000
# 8     0.663866  0.466102  0.517544  0.734513  0.468468  0.734513  0.918367
# 9     0.675676  0.491935  0.538462  0.688073  0.508065  0.767677  0.901961
# 10    0.701031  0.472727  0.487805  0.715596  0.490385  0.804878  0.900000
# 11    0.653846  0.481481  0.524590  0.622642  0.485981  0.836207  0.918699
# 12    0.611111  0.425197  0.529412  0.788462  0.460177  0.834862  0.858491
# 13    0.757282  0.422414  0.472727  0.625000  0.475000  0.836066  0.912621
# 14    0.650485  0.525424  0.585366  0.683333  0.490909  0.836364  0.892157
#
#     Acurácia
# 0   0.661578
# 1   0.679389
# 2   0.646310
# 3   0.653944
# 4   0.669211
# 5   0.656489
# 6   0.582697
# 7   0.667939
# 8   0.637405
# 9   0.642494
# 10  0.656489
# 11  0.651399
# 12  0.634860
# 13  0.638677
# 14  0.661578

# %%
metricsDF.boxplot()
metricsDF.describe()
# Out:
#        S - Normal   S - HI-1   S - HI-2   S - HI-3   S - LI-1   S - LI-2  \
# count   15.000000  15.000000  15.000000  15.000000  15.000000  15.000000
# mean     0.680266   0.484958   0.539776   0.680458   0.495305   0.804583
# std      0.054402   0.054942   0.043424   0.061112   0.032237   0.035580
# min      0.611111   0.394737   0.471074   0.580153   0.438596   0.734513
# 25%      0.652166   0.461864   0.521067   0.629014   0.473720   0.772981
# 50%      0.672727   0.481481   0.536364   0.685185   0.490566   0.804878
# 75%      0.706285   0.511024   0.572751   0.724344   0.518455   0.836136
# max      0.804348   0.627273   0.627119   0.788462   0.551724   0.848739
#
#         S - LI-3   Acurácia
# count  15.000000  15.000000
# mean    0.878473   0.649364
# std     0.035805   0.022415
# min     0.784314   0.582697
# 25%     0.857817   0.640585
# 50%     0.875000   0.653944
# 75%     0.907291   0.661578
# max     0.918699   0.679389

# %% [markdown]
# ## Adicionando resultado ao csv

# %%
pd.DataFrame(data=acc, columns=['KNN_acc']).to_csv('15_rodadas.csv')
