# %% [markdown]
# # Standard KNN
#
# Explorando 15 rodadas de classificação com algoritmo **knn** e armazenando resultados em arquivo .csv.
#
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix, accuracy_score, recall_score

# %% [markdown]
# ## Carregando e preparando dados

# %%
# Gerando DataFrame
chainDF = pd.read_csv('./corrente.csv')

targetS = chainDF.pop('classe')

# Carregando Rótulos das características
feature_names = chainDF.columns

# Carregando rótulos das classes
target_names = ['Normal', 'HI-1', 'HI-2', 'HI-3', 'LI-1', 'LI-2', 'LI-3']

# Definindo variáveis
X, y = chainDF.to_numpy(), targetS.to_numpy()

# Definindo array de números aleatórios
seed_array = np.array([4054, 6284, 4916, 2297, 8262, 3342, 7440,  541, 1711, 6730, 8764, 6323, 7498,  885,  771])

# %% [markdown]
# ## 15 rodadas de classificação

# %%
acc, rec = [], []

for turn, seed in enumerate(seed_array):
    # Distribuindo os dados
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Instanciando e treinando classificador
    classifier = KNeighborsClassifier()
    classifier.fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Gerando resultados
    accuracy = accuracy_score(y_test, y_pred)

    # Adicionando resultados às respectivas listas
    acc.append(accuracy)
    rec.append(recall_score(y_test, y_pred, average=None))

    # Exibindo resultados
    print(f'Rodada: {turn} - seed: {seed} - acurácia: {accuracy}\n')

    print(classification_report(y_test, y_pred, target_names=target_names))
    
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=target_names
    )
    plt.show()
# Out:
# Rodada: 0 - seed: 4054 - acurácia: 0.7202558635394456
#
#               precision    recall  f1-score   support
#
#       Normal       0.73      0.70      0.71       339
#         HI-1       0.46      0.60      0.52       304
#         HI-2       0.69      0.67      0.68       357
#         HI-3       0.81      0.78      0.79       348
#         LI-1       0.59      0.54      0.56       326
#         LI-2       0.81      0.80      0.81       331
#         LI-3       0.99      0.94      0.96       340
#
#     accuracy                           0.72      2345
#    macro avg       0.73      0.72      0.72      2345
# weighted avg       0.73      0.72      0.72      2345
# Rodada: 1 - seed: 6284 - acurácia: 0.7040511727078891
#
#               precision    recall  f1-score   support
#
#       Normal       0.68      0.70      0.69       327
#         HI-1       0.50      0.56      0.53       363
#         HI-2       0.71      0.61      0.66       339
#         HI-3       0.78      0.80      0.79       329
#         LI-1       0.55      0.54      0.55       343
#         LI-2       0.80      0.80      0.80       323
#         LI-3       0.96      0.94      0.95       321
#
#     accuracy                           0.70      2345
#    macro avg       0.71      0.71      0.71      2345
# weighted avg       0.71      0.70      0.71      2345
# Rodada: 2 - seed: 4916 - acurácia: 0.7155650319829424
#
#               precision    recall  f1-score   support
#
#       Normal       0.69      0.70      0.69       310
#         HI-1       0.47      0.57      0.51       331
#         HI-2       0.69      0.70      0.70       340
#         HI-3       0.83      0.80      0.81       372
#         LI-1       0.58      0.52      0.55       343
#         LI-2       0.82      0.78      0.80       321
#         LI-3       1.00      0.94      0.97       328
#
#     accuracy                           0.72      2345
#    macro avg       0.72      0.72      0.72      2345
# weighted avg       0.72      0.72      0.72      2345
# Rodada: 3 - seed: 2297 - acurácia: 0.711727078891258
#
#               precision    recall  f1-score   support
#
#       Normal       0.67      0.71      0.69       321
#         HI-1       0.48      0.58      0.52       337
#         HI-2       0.65      0.69      0.67       308
#         HI-3       0.82      0.78      0.80       348
#         LI-1       0.60      0.52      0.56       344
#         LI-2       0.85      0.76      0.80       344
#         LI-3       0.98      0.94      0.96       343
#
#     accuracy                           0.71      2345
#    macro avg       0.72      0.71      0.71      2345
# weighted avg       0.72      0.71      0.72      2345
# Rodada: 4 - seed: 8262 - acurácia: 0.7164179104477612
#
#               precision    recall  f1-score   support
#
#       Normal       0.70      0.74      0.72       322
#         HI-1       0.49      0.55      0.52       345
#         HI-2       0.69      0.70      0.70       323
#         HI-3       0.84      0.78      0.81       375
#         LI-1       0.56      0.54      0.55       337
#         LI-2       0.81      0.79      0.80       329
#         LI-3       0.98      0.92      0.95       314
#
#     accuracy                           0.72      2345
#    macro avg       0.73      0.72      0.72      2345
# weighted avg       0.72      0.72      0.72      2345
# Rodada: 5 - seed: 3342 - acurácia: 0.7219616204690832
#
#               precision    recall  f1-score   support
#
#       Normal       0.68      0.72      0.70       309
#         HI-1       0.50      0.62      0.55       317
#         HI-2       0.70      0.66      0.68       339
#         HI-3       0.83      0.75      0.79       371
#         LI-1       0.63      0.54      0.58       335
#         LI-2       0.79      0.81      0.80       366
#         LI-3       0.97      0.96      0.96       308
#
#     accuracy                           0.72      2345
#    macro avg       0.73      0.72      0.72      2345
# weighted avg       0.73      0.72      0.72      2345
# Rodada: 6 - seed: 7440 - acurácia: 0.7164179104477612
#
#               precision    recall  f1-score   support
#
#       Normal       0.66      0.74      0.70       313
#         HI-1       0.47      0.60      0.53       314
#         HI-2       0.74      0.64      0.69       342
#         HI-3       0.81      0.78      0.79       343
#         LI-1       0.54      0.53      0.53       308
#         LI-2       0.84      0.78      0.81       377
#         LI-3       0.99      0.92      0.95       348
#
#     accuracy                           0.72      2345
#    macro avg       0.72      0.71      0.71      2345
# weighted avg       0.73      0.72      0.72      2345
# Rodada: 7 - seed: 541 - acurácia: 0.7049040511727079
#
#               precision    recall  f1-score   support
#
#       Normal       0.70      0.69      0.70       322
#         HI-1       0.47      0.58      0.52       329
#         HI-2       0.71      0.68      0.70       346
#         HI-3       0.81      0.72      0.76       353
#         LI-1       0.54      0.55      0.54       329
#         LI-2       0.80      0.80      0.80       336
#         LI-3       0.97      0.92      0.94       330
#
#     accuracy                           0.70      2345
#    macro avg       0.71      0.70      0.71      2345
# weighted avg       0.72      0.70      0.71      2345
# Rodada: 8 - seed: 1711 - acurácia: 0.7091684434968017
#
#               precision    recall  f1-score   support
#
#       Normal       0.67      0.66      0.67       328
#         HI-1       0.49      0.59      0.53       324
#         HI-2       0.66      0.65      0.66       344
#         HI-3       0.84      0.78      0.81       364
#         LI-1       0.55      0.54      0.55       348
#         LI-2       0.85      0.79      0.82       316
#         LI-3       0.97      0.95      0.96       321
#
#     accuracy                           0.71      2345
#    macro avg       0.72      0.71      0.71      2345
# weighted avg       0.72      0.71      0.71      2345
# Rodada: 9 - seed: 6730 - acurácia: 0.7078891257995735
#
#               precision    recall  f1-score   support
#
#       Normal       0.66      0.72      0.69       289
#         HI-1       0.53      0.56      0.54       366
#         HI-2       0.66      0.68      0.67       354
#         HI-3       0.78      0.78      0.78       345
#         LI-1       0.57      0.54      0.56       336
#         LI-2       0.83      0.77      0.80       335
#         LI-3       0.99      0.93      0.96       320
#
#     accuracy                           0.71      2345
#    macro avg       0.72      0.71      0.71      2345
# weighted avg       0.71      0.71      0.71      2345
# Rodada: 10 - seed: 8764 - acurácia: 0.7304904051172708
#
#               precision    recall  f1-score   support
#
#       Normal       0.72      0.75      0.74       311
#         HI-1       0.51      0.53      0.52       361
#         HI-2       0.72      0.71      0.71       346
#         HI-3       0.82      0.81      0.81       352
#         LI-1       0.58      0.59      0.58       333
#         LI-2       0.83      0.83      0.83       314
#         LI-3       0.98      0.93      0.95       328
#
#     accuracy                           0.73      2345
#    macro avg       0.74      0.73      0.74      2345
# weighted avg       0.73      0.73      0.73      2345
# Rodada: 11 - seed: 6323 - acurácia: 0.7159914712153518
#
#               precision    recall  f1-score   support
#
#       Normal       0.66      0.72      0.68       303
#         HI-1       0.46      0.57      0.51       315
#         HI-2       0.67      0.65      0.66       330
#         HI-3       0.84      0.76      0.80       338
#         LI-1       0.60      0.56      0.58       337
#         LI-2       0.83      0.77      0.80       355
#         LI-3       0.98      0.95      0.97       367
#
#     accuracy                           0.72      2345
#    macro avg       0.72      0.71      0.71      2345
# weighted avg       0.73      0.72      0.72      2345
# Rodada: 12 - seed: 7498 - acurácia: 0.7130063965884862
#
#               precision    recall  f1-score   support
#
#       Normal       0.67      0.74      0.70       299
#         HI-1       0.52      0.56      0.54       366
#         HI-2       0.69      0.70      0.70       322
#         HI-3       0.78      0.78      0.78       353
#         LI-1       0.58      0.53      0.56       347
#         LI-2       0.81      0.77      0.79       345
#         LI-3       0.99      0.95      0.97       313
#
#     accuracy                           0.71      2345
#    macro avg       0.72      0.72      0.72      2345
# weighted avg       0.72      0.71      0.71      2345
# Rodada: 13 - seed: 885 - acurácia: 0.715138592750533
#
#               precision    recall  f1-score   support
#
#       Normal       0.69      0.71      0.70       327
#         HI-1       0.50      0.58      0.54       332
#         HI-2       0.70      0.64      0.67       352
#         HI-3       0.79      0.76      0.78       338
#         LI-1       0.58      0.60      0.59       342
#         LI-2       0.83      0.79      0.81       344
#         LI-3       0.98      0.95      0.96       310
#
#     accuracy                           0.72      2345
#    macro avg       0.72      0.72      0.72      2345
# weighted avg       0.72      0.72      0.72      2345
# Rodada: 14 - seed: 771 - acurácia: 0.7185501066098081
#
#               precision    recall  f1-score   support
#
#       Normal       0.65      0.73      0.69       326
#         HI-1       0.49      0.58      0.53       339
#         HI-2       0.69      0.71      0.70       335
#         HI-3       0.84      0.78      0.81       363
#         LI-1       0.60      0.53      0.56       339
#         LI-2       0.85      0.75      0.79       307
#         LI-3       0.99      0.96      0.97       336
#
#     accuracy                           0.72      2345
#    macro avg       0.73      0.72      0.72      2345
# weighted avg       0.73      0.72      0.72      2345

# %% [markdown]
# ## Observando métricas de Acurácia e sensibilidade

# %%
metricsDF = pd.DataFrame(data=rec, columns=[f'S - {classe}' for classe in target_names])
metricsDF['Acurácia'] = acc
metricsDF
# Out:
#     S - Normal  S - HI-1  S - HI-2  S - HI-3  S - LI-1  S - LI-2  S - LI-3  \
# 0     0.699115  0.598684  0.672269  0.778736  0.536810  0.800604  0.938235
# 1     0.703364  0.561983  0.613569  0.802432  0.536443  0.801858  0.940810
# 2     0.700000  0.567976  0.702941  0.798387  0.521866  0.781931  0.935976
# 3     0.707165  0.578635  0.688312  0.784483  0.523256  0.755814  0.938776
# 4     0.736025  0.550725  0.699690  0.784000  0.543027  0.790274  0.923567
# 5     0.724919  0.615142  0.660767  0.752022  0.540299  0.806011  0.957792
# 6     0.741214  0.598726  0.643275  0.775510  0.525974  0.777188  0.916667
# 7     0.692547  0.577508  0.684971  0.716714  0.547112  0.797619  0.915152
# 8     0.664634  0.589506  0.651163  0.782967  0.540230  0.794304  0.953271
# 9     0.723183  0.557377  0.677966  0.782609  0.538690  0.773134  0.928125
# 10    0.752412  0.526316  0.705202  0.809659  0.585586  0.831210  0.926829
# 11    0.716172  0.565079  0.651515  0.763314  0.563798  0.766197  0.950954
# 12    0.735786  0.557377  0.704969  0.776204  0.533141  0.768116  0.948882
# 13    0.706422  0.575301  0.644886  0.760355  0.599415  0.787791  0.951613
# 14    0.726994  0.584071  0.710448  0.779614  0.525074  0.745928  0.958333
#
#     Acurácia
# 0   0.720256
# 1   0.704051
# 2   0.715565
# 3   0.711727
# 4   0.716418
# 5   0.721962
# 6   0.716418
# 7   0.704904
# 8   0.709168
# 9   0.707889
# 10  0.730490
# 11  0.715991
# 12  0.713006
# 13  0.715139
# 14  0.718550

# %%
metricsDF.boxplot()
metricsDF.describe()
# Out:
#        S - Normal   S - HI-1   S - HI-2   S - HI-3   S - LI-1   S - LI-2  \
# count   15.000000  15.000000  15.000000  15.000000  15.000000  15.000000
# mean     0.715330   0.573627   0.674130   0.776467   0.544048   0.785199
# std      0.022454   0.022228   0.028968   0.022479   0.022502   0.021735
# min      0.664634   0.526316   0.613569   0.716714   0.521866   0.745928
# 25%      0.701682   0.559680   0.651339   0.769412   0.529558   0.770625
# 50%      0.716172   0.575301   0.677966   0.779614   0.538690   0.787791
# 75%      0.731390   0.586788   0.701316   0.784241   0.545070   0.799112
# max      0.752412   0.615142   0.710448   0.809659   0.599415   0.831210
#
#         S - LI-3   Acurácia
# count  15.000000  15.000000
# mean    0.938999   0.714769
# std     0.014431   0.006836
# min     0.915152   0.704051
# 25%     0.927477   0.710448
# 50%     0.938776   0.715565
# 75%     0.951283   0.717484
# max     0.958333   0.730490

# %% [markdown]
# ## Adicionando resultado ao csv

# %%
pd.DataFrame(data=acc, columns=['KNN_acc']).to_csv(path_or_buf='15_rodadas.csv', index=False)
