# %% [markdown]
# # Standard SLP
#
# Explorando 15 rodadas de classificação com `MLPClassifier` e registrando resultados em arquivo .csv.
#
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix, accuracy_score, recall_score

# %% [markdown]
# ## Carregando e preparando dados

# %%
# Gerando DataFrame
chainDF = pd.read_csv('./corrente.csv')

targetS = chainDF.pop('classe')

# Carregando Rótulos das características
feature_names = chainDF.columns

# Carregando rótulos das classes
target_names = ['Normal', 'HI-1', 'HI-2', 'HI-3', 'LI-1', 'LI-2', 'LI-3']

# Definindo variáveis
X, y = chainDF.to_numpy(), targetS.to_numpy()

# Definindo array de números aleatórios
seed_array = np.array([4054, 6284, 4916, 2297, 8262, 3342, 7440,  541, 1711, 6730, 8764, 6323, 7498,  885,  771])

# %% [markdown]
# ## 15 rodadas de classificação

# %%
acc, rec = [], []

for turn, seed in enumerate(seed_array):
    # Distribuindo os dados
    X_pre_train, X_pre_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Instanciando Standard Scaler
    sc = StandardScaler().fit(X_pre_train)

    # Pré-processando dados
    X_train = sc.transform(X_pre_train)
    X_test = sc.transform(X_pre_test)

    # Instanciando e treinando classificador
    classifier = MLPClassifier().fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Gerando resultados
    accuracy = accuracy_score(y_test, y_pred)

    # Adicionando resultados às respectivas listas
    acc.append(accuracy)
    rec.append(recall_score(y_test, y_pred, average=None))

    # Exibindo resultados
    print(f'Rodada: {turn} - seed: {seed} - acurácia: {accuracy}\n')

    print(classification_report(y_test, y_pred, target_names=target_names))
    
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        normalize='true',
        display_labels=target_names
    )
    plt.show()
# Out:
# Rodada: 0 - seed: 4054 - acurácia: 0.6904051172707889
#
#               precision    recall  f1-score   support
#
#       Normal       0.70      0.59      0.64       339
#         HI-1       0.43      0.50      0.46       304
#         HI-2       0.71      0.81      0.75       357
#         HI-3       0.78      0.75      0.76       348
#         LI-1       0.51      0.47      0.49       326
#         LI-2       0.78      0.77      0.77       331
#         LI-3       0.94      0.92      0.93       340
#
#     accuracy                           0.69      2345
#    macro avg       0.69      0.69      0.69      2345
# weighted avg       0.69      0.69      0.69      2345
# Rodada: 1 - seed: 6284 - acurácia: 0.6865671641791045
#
#               precision    recall  f1-score   support
#
#       Normal       0.63      0.69      0.66       327
#         HI-1       0.46      0.54      0.49       363
#         HI-2       0.70      0.72      0.71       339
#         HI-3       0.86      0.75      0.80       329
#         LI-1       0.53      0.41      0.46       343
#         LI-2       0.76      0.79      0.77       323
#         LI-3       0.93      0.94      0.93       321
#
#     accuracy                           0.69      2345
#    macro avg       0.70      0.69      0.69      2345
# weighted avg       0.69      0.69      0.69      2345
# Rodada: 2 - seed: 4916 - acurácia: 0.679317697228145
#
#               precision    recall  f1-score   support
#
#       Normal       0.60      0.64      0.62       310
#         HI-1       0.49      0.47      0.48       331
#         HI-2       0.70      0.72      0.71       340
#         HI-3       0.83      0.74      0.78       372
#         LI-1       0.48      0.43      0.46       343
#         LI-2       0.70      0.83      0.76       321
#         LI-3       0.95      0.92      0.94       328
#
#     accuracy                           0.68      2345
#    macro avg       0.68      0.68      0.68      2345
# weighted avg       0.68      0.68      0.68      2345
# Rodada: 3 - seed: 2297 - acurácia: 0.693816631130064
#
#               precision    recall  f1-score   support
#
#       Normal       0.71      0.64      0.67       321
#         HI-1       0.45      0.40      0.43       337
#         HI-2       0.68      0.80      0.73       308
#         HI-3       0.80      0.79      0.80       348
#         LI-1       0.46      0.52      0.49       344
#         LI-2       0.81      0.78      0.80       344
#         LI-3       0.96      0.93      0.95       343
#
#     accuracy                           0.69      2345
#    macro avg       0.70      0.69      0.69      2345
# weighted avg       0.70      0.69      0.69      2345
# Rodada: 4 - seed: 8262 - acurácia: 0.6707889125799573
#
#               precision    recall  f1-score   support
#
#       Normal       0.67      0.61      0.64       322
#         HI-1       0.51      0.36      0.42       345
#         HI-2       0.62      0.74      0.67       323
#         HI-3       0.76      0.77      0.76       375
#         LI-1       0.47      0.57      0.51       337
#         LI-2       0.76      0.76      0.76       329
#         LI-3       0.95      0.89      0.92       314
#
#     accuracy                           0.67      2345
#    macro avg       0.68      0.67      0.67      2345
# weighted avg       0.67      0.67      0.67      2345
# Rodada: 5 - seed: 3342 - acurácia: 0.6823027718550106
#
#               precision    recall  f1-score   support
#
#       Normal       0.63      0.69      0.66       309
#         HI-1       0.42      0.45      0.44       317
#         HI-2       0.69      0.73      0.70       339
#         HI-3       0.80      0.77      0.78       371
#         LI-1       0.52      0.47      0.50       335
#         LI-2       0.82      0.70      0.76       366
#         LI-3       0.89      0.96      0.93       308
#
#     accuracy                           0.68      2345
#    macro avg       0.68      0.68      0.68      2345
# weighted avg       0.69      0.68      0.68      2345
# Rodada: 6 - seed: 7440 - acurácia: 0.6895522388059702
#
#               precision    recall  f1-score   support
#
#       Normal       0.64      0.70      0.67       313
#         HI-1       0.46      0.45      0.46       314
#         HI-2       0.66      0.76      0.71       342
#         HI-3       0.83      0.72      0.77       343
#         LI-1       0.48      0.50      0.49       308
#         LI-2       0.79      0.74      0.76       377
#         LI-3       0.94      0.91      0.93       348
#
#     accuracy                           0.69      2345
#    macro avg       0.69      0.68      0.68      2345
# weighted avg       0.70      0.69      0.69      2345
# Rodada: 7 - seed: 541 - acurácia: 0.6878464818763326
#
#               precision    recall  f1-score   support
#
#       Normal       0.65      0.61      0.63       322
#         HI-1       0.48      0.43      0.45       329
#         HI-2       0.71      0.73      0.72       346
#         HI-3       0.83      0.71      0.76       353
#         LI-1       0.47      0.56      0.51       329
#         LI-2       0.75      0.84      0.79       336
#         LI-3       0.93      0.92      0.93       330
#
#     accuracy                           0.69      2345
#    macro avg       0.69      0.69      0.69      2345
# weighted avg       0.69      0.69      0.69      2345
# Rodada: 8 - seed: 1711 - acurácia: 0.646908315565032
#
#               precision    recall  f1-score   support
#
#       Normal       0.63      0.60      0.61       328
#         HI-1       0.39      0.42      0.41       324
#         HI-2       0.67      0.68      0.68       344
#         HI-3       0.80      0.71      0.75       364
#         LI-1       0.42      0.46      0.44       348
#         LI-2       0.76      0.74      0.75       316
#         LI-3       0.90      0.93      0.91       321
#
#     accuracy                           0.65      2345
#    macro avg       0.65      0.65      0.65      2345
# weighted avg       0.65      0.65      0.65      2345
# Rodada: 9 - seed: 6730 - acurácia: 0.6835820895522388
#
#               precision    recall  f1-score   support
#
#       Normal       0.62      0.70      0.66       289
#         HI-1       0.49      0.47      0.48       366
#         HI-2       0.71      0.74      0.72       354
#         HI-3       0.79      0.77      0.78       345
#         LI-1       0.49      0.43      0.45       336
#         LI-2       0.74      0.78      0.76       335
#         LI-3       0.94      0.93      0.94       320
#
#     accuracy                           0.68      2345
#    macro avg       0.68      0.69      0.68      2345
# weighted avg       0.68      0.68      0.68      2345
# Rodada: 10 - seed: 8764 - acurácia: 0.6886993603411514
#
#               precision    recall  f1-score   support
#
#       Normal       0.62      0.73      0.67       311
#         HI-1       0.48      0.37      0.42       361
#         HI-2       0.70      0.79      0.74       346
#         HI-3       0.81      0.74      0.77       352
#         LI-1       0.49      0.54      0.51       333
#         LI-2       0.79      0.77      0.78       314
#         LI-3       0.96      0.91      0.93       328
#
#     accuracy                           0.69      2345
#    macro avg       0.69      0.69      0.69      2345
# weighted avg       0.69      0.69      0.69      2345
# Rodada: 11 - seed: 6323 - acurácia: 0.6797441364605543
#
#               precision    recall  f1-score   support
#
#       Normal       0.67      0.62      0.65       303
#         HI-1       0.43      0.48      0.46       315
#         HI-2       0.65      0.75      0.70       330
#         HI-3       0.78      0.80      0.79       338
#         LI-1       0.45      0.41      0.43       337
#         LI-2       0.82      0.71      0.76       355
#         LI-3       0.94      0.94      0.94       367
#
#     accuracy                           0.68      2345
#    macro avg       0.68      0.67      0.67      2345
# weighted avg       0.68      0.68      0.68      2345
# Rodada: 12 - seed: 7498 - acurácia: 0.6776119402985075
#
#               precision    recall  f1-score   support
#
#       Normal       0.64      0.63      0.63       299
#         HI-1       0.48      0.41      0.44       366
#         HI-2       0.69      0.71      0.70       322
#         HI-3       0.80      0.78      0.79       353
#         LI-1       0.46      0.47      0.46       347
#         LI-2       0.76      0.84      0.80       345
#         LI-3       0.92      0.94      0.93       313
#
#     accuracy                           0.68      2345
#    macro avg       0.68      0.68      0.68      2345
# weighted avg       0.67      0.68      0.67      2345
# Rodada: 13 - seed: 885 - acurácia: 0.6631130063965884
#
#               precision    recall  f1-score   support
#
#       Normal       0.60      0.70      0.65       327
#         HI-1       0.41      0.30      0.34       332
#         HI-2       0.71      0.76      0.73       352
#         HI-3       0.78      0.70      0.74       338
#         LI-1       0.43      0.51      0.47       342
#         LI-2       0.79      0.74      0.76       344
#         LI-3       0.93      0.95      0.94       310
#
#     accuracy                           0.66      2345
#    macro avg       0.66      0.67      0.66      2345
# weighted avg       0.66      0.66      0.66      2345
# Rodada: 14 - seed: 771 - acurácia: 0.6788912579957356
#
#               precision    recall  f1-score   support
#
#       Normal       0.76      0.58      0.66       326
#         HI-1       0.44      0.36      0.40       339
#         HI-2       0.67      0.76      0.71       335
#         HI-3       0.82      0.77      0.79       363
#         LI-1       0.43      0.55      0.48       339
#         LI-2       0.77      0.82      0.79       307
#         LI-3       0.95      0.93      0.94       336
#
#     accuracy                           0.68      2345
#    macro avg       0.69      0.68      0.68      2345
# weighted avg       0.69      0.68      0.68      2345

# %% [markdown]
# ## Observando métricas de Acurácia e Sensibilidade

# %%
metricsDF = pd.DataFrame(data=rec, columns=[f'S - {classe}' for classe in target_names])
metricsDF['Acurácia'] = acc
metricsDF
# Out:
#     S - Normal  S - HI-1  S - HI-2  S - HI-3  S - LI-1  S - LI-2  S - LI-3  \
# 0     0.587021  0.496711  0.806723  0.747126  0.466258  0.770393  0.923529
# 1     0.694190  0.539945  0.722714  0.747720  0.405248  0.792570  0.937695
# 2     0.641935  0.471299  0.717647  0.744624  0.434402  0.828660  0.920732
# 3     0.635514  0.400593  0.798701  0.790230  0.517442  0.781977  0.932945
# 4     0.611801  0.359420  0.739938  0.770667  0.572700  0.762918  0.891720
# 5     0.689320  0.454259  0.725664  0.765499  0.471642  0.704918  0.964286
# 6     0.699681  0.449045  0.760234  0.717201  0.500000  0.742706  0.910920
# 7     0.614907  0.428571  0.734104  0.705382  0.562310  0.839286  0.921212
# 8     0.597561  0.422840  0.677326  0.708791  0.462644  0.737342  0.931464
# 9     0.695502  0.469945  0.742938  0.768116  0.425595  0.779104  0.931250
# 10    0.729904  0.365651  0.789017  0.744318  0.537538  0.773885  0.911585
# 11    0.623762  0.479365  0.754545  0.798817  0.409496  0.709859  0.940054
# 12    0.628763  0.412568  0.714286  0.776204  0.466859  0.837681  0.942492
# 13    0.697248  0.298193  0.761364  0.701183  0.511696  0.735465  0.951613
# 14    0.576687  0.359882  0.761194  0.765840  0.548673  0.817590  0.928571
#
#     Acurácia
# 0   0.690405
# 1   0.686567
# 2   0.679318
# 3   0.693817
# 4   0.670789
# 5   0.682303
# 6   0.689552
# 7   0.687846
# 8   0.646908
# 9   0.683582
# 10  0.688699
# 11  0.679744
# 12  0.677612
# 13  0.663113
# 14  0.678891

# %%
metricsDF.boxplot()
metricsDF.describe()
# Out:
#        S - Normal   S - HI-1   S - HI-2   S - HI-3   S - LI-1   S - LI-2  \
# count   15.000000  15.000000  15.000000  15.000000  15.000000  15.000000
# mean     0.648253   0.427219   0.747093   0.750115   0.486167   0.774290
# std      0.048406   0.063102   0.034547   0.030656   0.054747   0.043481
# min      0.576687   0.298193   0.677326   0.701183   0.405248   0.704918
# 25%      0.613354   0.383122   0.724189   0.730760   0.448523   0.740024
# 50%      0.635514   0.428571   0.742938   0.747720   0.471642   0.773885
# 75%      0.694846   0.470622   0.761279   0.769391   0.527490   0.805080
# max      0.729904   0.539945   0.806723   0.798817   0.572700   0.839286
#
#         S - LI-3   Acurácia
# count  15.000000  15.000000
# mean    0.929338   0.679943
# std     0.017608   0.012134
# min     0.891720   0.646908
# 25%     0.920972   0.678252
# 50%     0.931250   0.682303
# 75%     0.938875   0.688273
# max     0.964286   0.693817

# %% [markdown]
# ## Adicionando resultado ao csv

# %%
rodadasDF = pd.read_csv('15_rodadas.csv')
rodadasDF['MLP_acc'] = acc
rodadasDF.to_csv(path_or_buf='15_rodadas.csv', index=False)
