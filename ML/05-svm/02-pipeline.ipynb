# %% [markdown]
# # Pipeline
#
# Experimentando classificação com `SVC` para explorar a implementação da `make_pipeline`
#
# ## Importando bibliotecas

# %%
from sklearn.svm import SVC
from sklearn.datasets import load_iris
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
iris = load_iris()

X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Teste sem normalização

# %%
model_1 = SVC(random_state=0).fit(X_train, y_train)

y1_pred = model_1.predict(X_test)

print("Teste sem normalização")

plot_confusion_matrix(model_1, X_test, y_test, normalize='true', display_labels=iris.target_names)

print(classification_report(y_test, y1_pred, target_names=iris.target_names, digits=4))
# Out:
# Teste sem normalização
#               precision    recall  f1-score   support
#
#       setosa     1.0000    1.0000    1.0000        19
#   versicolor     1.0000    1.0000    1.0000        13
#    virginica     1.0000    1.0000    1.0000        13
#
#     accuracy                         1.0000        45
#    macro avg     1.0000    1.0000    1.0000        45
# weighted avg     1.0000    1.0000    1.0000        45

# %% [markdown]
# ## Teste com Normalização

# %%
scaler = StandardScaler().fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

model_2 = SVC(random_state=0).fit(X_train_scaled, y_train)

y2_pred = model_2.predict(X_test_scaled)

print("Teste sem normalização")

plot_confusion_matrix(model_2, X_test_scaled, y_test, normalize='true', display_labels=iris.target_names)

print(classification_report(y_test, y2_pred, target_names=iris.target_names, digits=4))
# Out:
# Teste sem normalização
#               precision    recall  f1-score   support
#
#       setosa     1.0000    1.0000    1.0000        19
#   versicolor     1.0000    1.0000    1.0000        13
#    virginica     1.0000    1.0000    1.0000        13
#
#     accuracy                         1.0000        45
#    macro avg     1.0000    1.0000    1.0000        45
# weighted avg     1.0000    1.0000    1.0000        45

# %% [markdown]
# ## Teste com Pipeline

# %%
model_3 = make_pipeline(StandardScaler(), SVC(random_state=0)).fit(X_train, y_train)

y3_pred = model_3.predict(X_test)

print("Teste com Pipeline")

plot_confusion_matrix(model_3, X_test, y_test, normalize='true', display_labels=iris.target_names)

print(classification_report(y_test, y3_pred, target_names=iris.target_names, digits=4))
# Out:
# Teste com Pipeline
#               precision    recall  f1-score   support
#
#       setosa     1.0000    1.0000    1.0000        19
#   versicolor     1.0000    1.0000    1.0000        13
#    virginica     1.0000    1.0000    1.0000        13
#
#     accuracy                         1.0000        45
#    macro avg     1.0000    1.0000    1.0000        45
# weighted avg     1.0000    1.0000    1.0000        45
