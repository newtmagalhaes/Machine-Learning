# %% [markdown]
# # SVM Test
#
# Após o GridSearch, observei uma pequena diferença e ótimos resultados com o kernel `'rbf'` e o `'linear'`, então explorarei 15 rodadas com o `LinearSVC`
#
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
from sklearn.svm import SVC, LinearSVC
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix, recall_score, accuracy_score

# %% [markdown]
# ## Carregando dados

# %%
irisDS = load_iris()

X, y = load_iris(return_X_y=True)

seeds = np.random.randint(0, 9000, 15)

print(f'seeds: {seeds}')
# Out:
# seeds: [3802 7367 8556 1950 6271 3080 3959 2585 6997 4750 7961 8114 8473 8770
#  6011]

# %% [markdown]
# ## 15 rodadas com SVC no kernel `rbf`

# %%
rbf_acc, rbf_rec = [], []

for turn, seed in enumerate(seeds):
    # Separando dados
    X_pre_train, X_pre_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Pré-processando dados
    sc = StandardScaler().fit(X_pre_train)

    X_train = sc.transform(X_pre_train)
    X_test = sc.transform(X_pre_test)

    # Instanciando classificador
    classifier = SVC(
        kernel='rbf',
        decision_function_shape='ovo'
    ).fit(X_train, y_train)

    # Gerando predições e métricas
    y_pred = classifier.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, average=None)
    setosa, versicolor, virginica = rec

    rbf_acc.append(acc)
    rbf_rec.append(rec)

    # Plotando resultados
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        display_labels=irisDS.target_names,
        normalize='true'
    )

    print(f'Rodada {turn} - Semente {seed} - Acurácia {acc}')
    print(f'S. Setosa {setosa} - S. Versicolor {versicolor} - S. Virginica {virginica}\n')
    print(classification_report(y_test, y_pred, target_names=irisDS.target_names))
    plt.show()

rbfDF = pd.DataFrame(data=rbf_rec, columns=[f'S - {target}' for target in irisDS.target_names])
rbfDF['Acurácia'] = acc
# Out:
# Rodada 0 - Semente 3802 - Acurácia 0.9777777777777777
# S. Setosa 1.0 - S. Versicolor 1.0 - S. Virginica 0.9333333333333333
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       0.94      1.00      0.97        17
#    virginica       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada 1 - Semente 7367 - Acurácia 0.9333333333333333
# S. Setosa 1.0 - S. Versicolor 0.8888888888888888 - S. Virginica 0.9285714285714286
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       0.94      0.89      0.91        18
#    virginica       0.87      0.93      0.90        14
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.94      0.94        45
# weighted avg       0.93      0.93      0.93        45
# Rodada 2 - Semente 8556 - Acurácia 0.9555555555555556
# S. Setosa 1.0 - S. Versicolor 0.9285714285714286 - S. Virginica 0.9285714285714286
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.93      0.93      0.93        14
#    virginica       0.93      0.93      0.93        14
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45
# Rodada 3 - Semente 1950 - Acurácia 0.9555555555555556
# S. Setosa 1.0 - S. Versicolor 0.9444444444444444 - S. Virginica 0.9375
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       0.94      0.94      0.94        18
#    virginica       0.94      0.94      0.94        16
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
# Rodada 4 - Semente 6271 - Acurácia 0.9555555555555556
# S. Setosa 1.0 - S. Versicolor 1.0 - S. Virginica 0.875
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.86      1.00      0.92        12
#    virginica       1.00      0.88      0.93        16
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45
# Rodada 5 - Semente 3080 - Acurácia 0.9777777777777777
# S. Setosa 1.0 - S. Versicolor 0.9444444444444444 - S. Virginica 1.0
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       1.00      0.94      0.97        18
#    virginica       0.92      1.00      0.96        12
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada 6 - Semente 3959 - Acurácia 0.9333333333333333
# S. Setosa 1.0 - S. Versicolor 0.875 - S. Virginica 0.9375
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       0.93      0.88      0.90        16
#    virginica       0.88      0.94      0.91        16
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.94      0.94        45
# weighted avg       0.93      0.93      0.93        45
# Rodada 7 - Semente 2585 - Acurácia 0.9777777777777777
# S. Setosa 1.0 - S. Versicolor 1.0 - S. Virginica 0.9166666666666666
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.94      1.00      0.97        16
#    virginica       1.00      0.92      0.96        12
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada 8 - Semente 6997 - Acurácia 0.9777777777777777
# S. Setosa 1.0 - S. Versicolor 1.0 - S. Virginica 0.9333333333333333
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.94      1.00      0.97        15
#    virginica       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada 9 - Semente 4750 - Acurácia 1.0
# S. Setosa 1.0 - S. Versicolor 1.0 - S. Virginica 1.0
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        18
#   versicolor       1.00      1.00      1.00        11
#    virginica       1.00      1.00      1.00        16
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
# Rodada 10 - Semente 7961 - Acurácia 0.9555555555555556
# S. Setosa 0.9285714285714286 - S. Versicolor 0.9444444444444444 - S. Virginica 1.0
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      0.93      0.96        14
#   versicolor       0.94      0.94      0.94        18
#    virginica       0.93      1.00      0.96        13
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
# Rodada 11 - Semente 8114 - Acurácia 1.0
# S. Setosa 1.0 - S. Versicolor 1.0 - S. Virginica 1.0
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        16
#   versicolor       1.00      1.00      1.00        14
#    virginica       1.00      1.00      1.00        15
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
# Rodada 12 - Semente 8473 - Acurácia 0.9777777777777777
# S. Setosa 1.0 - S. Versicolor 0.9333333333333333 - S. Virginica 1.0
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      0.93      0.97        15
#    virginica       0.94      1.00      0.97        17
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada 13 - Semente 8770 - Acurácia 0.9555555555555556
# S. Setosa 1.0 - S. Versicolor 1.0 - S. Virginica 0.8571428571428571
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.88      1.00      0.93        14
#    virginica       1.00      0.86      0.92        14
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45
# Rodada 14 - Semente 6011 - Acurácia 0.9777777777777777
# S. Setosa 1.0 - S. Versicolor 1.0 - S. Virginica 0.9444444444444444
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       0.93      1.00      0.96        13
#    virginica       1.00      0.94      0.97        18
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ## 15 rodadas com LinearSVC

# %%
linear_acc, linear_rec = [], []

for turn, seed in enumerate(seeds):
    # Separando dados
    X_pre_train, X_pre_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Pré-processando dados
    sc = StandardScaler().fit(X_pre_train)

    X_train = sc.transform(X_pre_train)
    X_test = sc.transform(X_pre_test)

    # Instanciando classificador
    classifier = LinearSVC().fit(X_train, y_train)

    # Gerando predições e métricas
    y_pred = classifier.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, average=None)
    setosa, versicolor, virginica = rec

    linear_acc.append(acc)
    linear_rec.append(rec)

    # Plotando resultados
    plot_confusion_matrix(
        estimator=classifier,
        X=X_test,
        y_true=y_test,
        display_labels=irisDS.target_names,
        normalize='true'
    )

    print(f'Rodada {turn} - Semente {seed} - Acurácia {acc}')
    print(f'S. Setosa {setosa} - S. Versicolor {versicolor} - S. Virginica {virginica}\n')
    print(classification_report(y_test, y_pred, target_names=irisDS.target_names))
    plt.show()

linearDF = pd.DataFrame(data=linear_rec, columns=[f'S - {target}' for target in irisDS.target_names])
linearDF['Acurácia'] = acc
# Out:
# Rodada 0 - Semente 3802 - Acurácia 0.9555555555555556
# S. Setosa 1.0 - S. Versicolor 0.9411764705882353 - S. Virginica 0.9333333333333333
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       0.94      0.94      0.94        17
#    virginica       0.93      0.93      0.93        15
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
# Rodada 1 - Semente 7367 - Acurácia 0.9111111111111111
# S. Setosa 1.0 - S. Versicolor 0.8333333333333334 - S. Virginica 0.9285714285714286
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       0.94      0.83      0.88        18
#    virginica       0.81      0.93      0.87        14
#
#     accuracy                           0.91        45
#    macro avg       0.92      0.92      0.92        45
# weighted avg       0.92      0.91      0.91        45
# Rodada 2 - Semente 8556 - Acurácia 0.9555555555555556
# S. Setosa 1.0 - S. Versicolor 0.9285714285714286 - S. Virginica 0.9285714285714286
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.93      0.93      0.93        14
#    virginica       0.93      0.93      0.93        14
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45
# Rodada 3 - Semente 1950 - Acurácia 0.9333333333333333
# S. Setosa 1.0 - S. Versicolor 0.8888888888888888 - S. Virginica 0.9375
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       0.94      0.89      0.91        18
#    virginica       0.88      0.94      0.91        16
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.94      0.94        45
# weighted avg       0.93      0.93      0.93        45
# Rodada 4 - Semente 6271 - Acurácia 0.9777777777777777
# S. Setosa 1.0 - S. Versicolor 1.0 - S. Virginica 0.9375
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.92      1.00      0.96        12
#    virginica       1.00      0.94      0.97        16
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada 5 - Semente 3080 - Acurácia 0.9777777777777777
# S. Setosa 1.0 - S. Versicolor 0.9444444444444444 - S. Virginica 1.0
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       1.00      0.94      0.97        18
#    virginica       0.92      1.00      0.96        12
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada 6 - Semente 3959 - Acurácia 0.9777777777777777
# S. Setosa 1.0 - S. Versicolor 0.9375 - S. Virginica 1.0
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      0.94      0.97        16
#    virginica       0.94      1.00      0.97        16
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada 7 - Semente 2585 - Acurácia 0.9555555555555556
# S. Setosa 0.9411764705882353 - S. Versicolor 1.0 - S. Virginica 0.9166666666666666
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      0.94      0.97        17
#   versicolor       0.89      1.00      0.94        16
#    virginica       1.00      0.92      0.96        12
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.95      0.96        45
# weighted avg       0.96      0.96      0.96        45
# Rodada 8 - Semente 6997 - Acurácia 0.9777777777777777
# S. Setosa 1.0 - S. Versicolor 1.0 - S. Virginica 0.9333333333333333
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.94      1.00      0.97        15
#    virginica       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada 9 - Semente 4750 - Acurácia 0.9777777777777777
# S. Setosa 0.9444444444444444 - S. Versicolor 1.0 - S. Virginica 1.0
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      0.94      0.97        18
#   versicolor       0.92      1.00      0.96        11
#    virginica       1.00      1.00      1.00        16
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada 10 - Semente 7961 - Acurácia 0.9333333333333333
# S. Setosa 0.9285714285714286 - S. Versicolor 0.8888888888888888 - S. Virginica 1.0
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      0.93      0.96        14
#   versicolor       0.94      0.89      0.91        18
#    virginica       0.87      1.00      0.93        13
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.94      0.94        45
# weighted avg       0.94      0.93      0.93        45
# Rodada 11 - Semente 8114 - Acurácia 0.9777777777777777
# S. Setosa 0.9375 - S. Versicolor 1.0 - S. Virginica 1.0
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      0