# %% [markdown]
# # MLP Test 5
#
# Explorando 30 rodadas de Classificação com **MLP** utilizando hiperparâmetros de outros testes.
#
# ## Importando bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

from random import randint
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, recall_score, plot_confusion_matrix, confusion_matrix

# %% [markdown]
# ## Carregando dados

# %%
irisDS = load_iris()
X, y = load_iris(return_X_y=True)

acc_list = []
rec_list = []
mat_list = []
seed_list = []

# %% [markdown]
# ## 30 Rodadas de Classificação

# %%
for turn in range(30):
    # Gerando semente para distribuição dos dados
    seed = randint(0, 9000)

    while seed in seed_list:
        seed = randint(0, 9000)

    # Distribuindo os dados
    X_pre_train, X_pre_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

    # Instanciando Standard Scaler
    sc = StandardScaler().fit(X_pre_train)

    # Pré-processando dados
    X_train = sc.transform(X_pre_train)
    X_test = sc.transform(X_pre_test)

    # Instanciando e treinando classificador
    classifier = MLPClassifier(hidden_layer_sizes=(120), activation='tanh').fit(X_train, y_train)

    # Realizando predição
    y_pred = classifier.predict(X_test)

    # Gerando resultados
    acuracia = accuracy_score(y_test, y_pred)
    sensibilidade = recall_score(y_test, y_pred, average=None)
    matrix = confusion_matrix(y_test, y_pred, normalize='true')

    # Adicionando resultados às respectivas listas
    seed_list.append(seed)
    acc_list.append(acuracia)
    rec_list.append(sensibilidade)
    mat_list.append(matrix)

    # Exibindo resultados
    print(f'Rodada: {turn} - seed: {seed} - acurácia: {acuracia}\n')

    print(f'Sensibilidade: {sensibilidade}\n')

    print(classification_report(y_test, y_pred, target_names=irisDS.target_names))
    
    plot_confusion_matrix(classifier, X_test, y_test, normalize='true', display_labels=irisDS.target_names)
    plt.show()
# Out:
# Rodada: 0 - seed: 5045 - acurácia: 0.9333333333333333
#
# Sensibilidade: [1.         0.875      0.92857143]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.93      0.88      0.90        16
#    virginica       0.87      0.93      0.90        14
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.93      0.93        45
# weighted avg       0.93      0.93      0.93        45
# Rodada: 1 - seed: 7409 - acurácia: 0.9777777777777777
#
# Sensibilidade: [1.         0.90909091 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        16
#   versicolor       1.00      0.91      0.95        11
#    virginica       0.95      1.00      0.97        18
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada: 2 - seed: 4213 - acurácia: 0.9777777777777777
#
# Sensibilidade: [1.     0.9375 1.    ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       1.00      0.94      0.97        16
#    virginica       0.93      1.00      0.97        14
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada: 3 - seed: 3992 - acurácia: 1.0
#
# Sensibilidade: [1. 1. 1.]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       1.00      1.00      1.00        18
#    virginica       1.00      1.00      1.00        10
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
# Rodada: 4 - seed: 6421 - acurácia: 0.9333333333333333
#
# Sensibilidade: [1.         0.92307692 0.88888889]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       0.86      0.92      0.89        13
#    virginica       0.94      0.89      0.91        18
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.94      0.93        45
# weighted avg       0.94      0.93      0.93        45
# Rodada: 5 - seed: 6502 - acurácia: 0.9333333333333333
#
# Sensibilidade: [1.         0.94117647 0.88888889]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       0.89      0.94      0.91        17
#    virginica       0.94      0.89      0.91        18
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.94      0.94        45
# weighted avg       0.93      0.93      0.93        45
# Rodada: 6 - seed: 2295 - acurácia: 0.9777777777777777
#
# Sensibilidade: [1.         0.92857143 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       1.00      0.93      0.96        14
#    virginica       0.93      1.00      0.97        14
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada: 7 - seed: 639 - acurácia: 0.9555555555555556
#
# Sensibilidade: [1.         0.88235294 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      0.88      0.94        17
#    virginica       0.88      1.00      0.94        15
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
# Rodada: 8 - seed: 1419 - acurácia: 0.9555555555555556
#
# Sensibilidade: [1.         0.81818182 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      0.82      0.90        11
#    virginica       0.88      1.00      0.94        15
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.94      0.95        45
# weighted avg       0.96      0.96      0.95        45
# Rodada: 9 - seed: 3416 - acurácia: 0.9777777777777777
#
# Sensibilidade: [1.         0.94117647 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       1.00      0.94      0.97        17
#    virginica       0.93      1.00      0.97        14
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada: 10 - seed: 7644 - acurácia: 0.9555555555555556
#
# Sensibilidade: [1.         0.77777778 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      0.78      0.88         9
#    virginica       0.89      1.00      0.94        17
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.93      0.94        45
# weighted avg       0.96      0.96      0.95        45
# Rodada: 11 - seed: 2183 - acurácia: 0.9555555555555556
#
# Sensibilidade: [1.         1.         0.86666667]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.87      1.00      0.93        13
#    virginica       1.00      0.87      0.93        15
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45
# Rodada: 12 - seed: 4354 - acurácia: 0.9555555555555556
#
# Sensibilidade: [0.9375 1.     0.9375]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      0.94      0.97        16
#   versicolor       0.87      1.00      0.93        13
#    virginica       1.00      0.94      0.97        16
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45
# Rodada: 13 - seed: 4763 - acurácia: 0.9555555555555556
#
# Sensibilidade: [1.         0.88235294 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        16
#   versicolor       1.00      0.88      0.94        17
#    virginica       0.86      1.00      0.92        12
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45
# Rodada: 14 - seed: 6827 - acurácia: 0.9333333333333333
#
# Sensibilidade: [1.         0.85714286 0.89473684]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       0.75      0.86      0.80         7
#    virginica       0.94      0.89      0.92        19
#
#     accuracy                           0.93        45
#    macro avg       0.90      0.92      0.91        45
# weighted avg       0.94      0.93      0.93        45
# Rodada: 15 - seed: 370 - acurácia: 0.9777777777777777
#
# Sensibilidade: [1.         0.92857143 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        18
#   versicolor       1.00      0.93      0.96        14
#    virginica       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada: 16 - seed: 8447 - acurácia: 0.9333333333333333
#
# Sensibilidade: [1.         0.84615385 0.92307692]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       0.92      0.85      0.88        13
#    virginica       0.86      0.92      0.89        13
#
#     accuracy                           0.93        45
#    macro avg       0.92      0.92      0.92        45
# weighted avg       0.93      0.93      0.93        45
# Rodada: 17 - seed: 1773 - acurácia: 0.9555555555555556
#
# Sensibilidade: [1.         0.94444444 0.88888889]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        18
#   versicolor       0.94      0.94      0.94        18
#    virginica       0.89      0.89      0.89         9
#
#     accuracy                           0.96        45
#    macro avg       0.94      0.94      0.94        45
# weighted avg       0.96      0.96      0.96        45
# Rodada: 18 - seed: 7035 - acurácia: 0.9333333333333333
#
# Sensibilidade: [1.         0.92307692 0.88888889]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       0.86      0.92      0.89        13
#    virginica       0.94      0.89      0.91        18
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.94      0.93        45
# weighted avg       0.94      0.93      0.93        45
# Rodada: 19 - seed: 3551 - acurácia: 0.9555555555555556
#
# Sensibilidade: [1.         0.92307692 0.93333333]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.92      0.92      0.92        13
#    virginica       0.93      0.93      0.93        15
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45
# Rodada: 20 - seed: 8627 - acurácia: 0.9555555555555556
#
# Sensibilidade: [1.         0.88235294 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      0.88      0.94        17
#    virginica       0.88      1.00      0.94        15
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
# Rodada: 21 - seed: 3460 - acurácia: 0.9333333333333333
#
# Sensibilidade: [1.         0.85714286 0.92857143]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.92      0.86      0.89        14
#    virginica       0.87      0.93      0.90        14
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.93      0.93        45
# weighted avg       0.93      0.93      0.93        45
# Rodada: 22 - seed: 2052 - acurácia: 0.9333333333333333
#
# Sensibilidade: [0.94444444 0.85714286 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      0.94      0.97        18
#   versicolor       0.92      0.86      0.89        14
#    virginica       0.87      1.00      0.93        13
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45
# Rodada: 23 - seed: 8052 - acurácia: 0.9555555555555556
#
# Sensibilidade: [1.         0.88888889 0.9375    ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        20
#   versicolor       0.89      0.89      0.89         9
#    virginica       0.94      0.94      0.94        16
#
#     accuracy                           0.96        45
#    macro avg       0.94      0.94      0.94        45
# weighted avg       0.96      0.96      0.96        45
# Rodada: 24 - seed: 5902 - acurácia: 0.9777777777777777
#
# Sensibilidade: [1.         1.         0.94117647]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.93      1.00      0.96        13
#    virginica       1.00      0.94      0.97        17
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada: 25 - seed: 8041 - acurácia: 0.9555555555555556
#
# Sensibilidade: [1.         0.93333333 0.9375    ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       0.93      0.93      0.93        15
#    virginica       0.94      0.94      0.94        16
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
# Rodada: 26 - seed: 6834 - acurácia: 0.9333333333333333
#
# Sensibilidade: [1.  0.8 1. ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        12
#   versicolor       1.00      0.80      0.89        15
#    virginica       0.86      1.00      0.92        18
#
#     accuracy                           0.93        45
#    macro avg       0.95      0.93      0.94        45
# weighted avg       0.94      0.93      0.93        45
# Rodada: 27 - seed: 703 - acurácia: 0.9777777777777777
#
# Sensibilidade: [1.         0.94117647 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       1.00      0.94      0.97        17
#    virginica       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
# Rodada: 28 - seed: 835 - acurácia: 0.9777777777777777
#
# Sensibilidade: [1.         1.         0.91666667]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        20
#   versicolor       0.93      1.00      0.96        13
#    virginica       1.00      0.92      0.96        12
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.97        45
# weighted avg       0.98      0.98      0.98        45
# Rodada: 29 - seed: 2169 - acurácia: 0.9111111111111111
#
# Sensibilidade: [1.         0.76470588 1.        ]
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       1.00      0.76      0.87        17
#    virginica       0.78      1.00      0.88        14
#
#     accuracy                           0.91        45
#    macro avg       0.93      0.92      0.91        45
# weighted avg       0.93      0.91      0.91        45

# %%
metricsDF = pd.DataFrame(data=rec_list, columns=irisDS.target_names)
metricsDF['Acurácia'] = acc_list
metricsDF
# Out:
#       setosa  versicolor  virginica  Acurácia
# 0   1.000000    0.875000   0.928571  0.933333
# 1   1.000000    0.909091   1.000000  0.977778
# 2   1.000000    0.937500   1.000000  0.977778
# 3   1.000000    1.000000   1.000000  1.000000
# 4   1.000000    0.923077   0.888889  0.933333
# 5   1.000000    0.941176   0.888889  0.933333
# 6   1.000000    0.928571   1.000000  0.977778
# 7   1.000000    0.882353   1.000000  0.955556
# 8   1.000000    0.818182   1.000000  0.955556
# 9   1.000000    0.941176   1.000000  0.977778
# 10  1.000000    0.777778   1.000000  0.955556
# 11  1.000000    1.000000   0.866667  0.955556
# 12  0.937500    1.000000   0.937500  0.955556
# 13  1.000000    0.882353   1.000000  0.955556
# 14  1.000000    0.857143   0.894737  0.933333
# 15  1.000000    0.928571   1.000000  0.977778
# 16  1.000000    0.846154   0.923077  0.933333
# 17  1.000000    0.944444   0.888889  0.955556
# 18  1.000000    0.923077   0.888889  0.933333
# 19  1.000000    0.923077   0.933333  0.955556
# 20  1.000000    0.882353   1.000000  0.955556
# 21  1.000000    0.857143   0.928571  0.933333
# 22  0.944444    0.857143   1.000000  0.933333
# 23  1.000000    0.888889   0.937500  0.955556
# 24  1.000000    1.000000   0.941176  0.977778
# 25  1.000000    0.933333   0.937500  0.955556
# 26  1.000000    0.800000   1.000000  0.933333
# 27  1.000000    0.941176   1.000000  0.977778
# 28  1.000000    1.000000   0.916667  0.977778
# 29  1.000000    0.764706   1.000000  0.911111

# %%
metricsDF.describe()
# Out:
#           setosa  versicolor  virginica   Acurácia
# count  30.000000   30.000000  30.000000  30.000000
# mean    0.996065    0.905449   0.956695   0.954815
# std     0.015004    0.064869   0.047223   0.020619
# min     0.937500    0.764706   0.866667   0.911111
# 25%     1.000000    0.861607   0.924451   0.933333
# 50%     1.000000    0.923077   0.970588   0.955556
# 75%     1.000000    0.941176   1.000000   0.977778
# max     1.000000    1.000000   1.000000   1.000000

# %%
metricsDF.boxplot()
